# %%
import matplotlib.pyplot as plt
from matplotlib.colors import *
import seaborn as sns
import janitor as jn
from plotnine.data import *
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %%
plt.rcParams['figure.figsize'] = (10, 8)
plt.rcParams['font.size'] = 14
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 18

# %% [markdown]
#  ## First steps

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg = mpg.rename_column('class', '_class')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
#  ### Exercise

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy')
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %%
sns.scatterplot(data=mpg, x='cyl', y='hwy')
# Out:
# <AxesSubplot:xlabel='cyl', ylabel='hwy'>

# %%
sns.scatterplot(data=mpg, x='class', y='drv')
# Out:
# <AxesSubplot:xlabel='class', ylabel='drv'>

# %%
mpg_count = (
    mpg.groupby(['class', 'drv'])
    .size()
    .reset_index(name='count')
    )
mpg_count
# Out:
#          class drv  count
# 0      2seater   4      0
# 1      2seater   f      0
# 2      2seater   r      5
# 3      compact   4     12
# 4      compact   f     35
# 5      compact   r      0
# 6      midsize   4      3
# 7      midsize   f     38
# 8      midsize   r      0
# 9      minivan   4      0
# 10     minivan   f     11
# 11     minivan   r      0
# 12      pickup   4     33
# 13      pickup   f      0
# 14      pickup   r      0
# 15  subcompact   4      4
# 16  subcompact   f     22
# 17  subcompact   r      9
# 18         suv   4     51
# 19         suv   f      0
# 20         suv   r     11

# %%
sns.scatterplot(
    data=mpg_count, x='class', y='drv', 
    size='count')
# Out:
# <AxesSubplot:xlabel='class', ylabel='drv'>

# %%
mpg_count_map = (
    mpg_count
    .pivot_table(
        index='class', 
        columns='drv', 
        values='count'))
mpg_count_map
# Out:
# drv          4   f   r
# class
# 2seater      0   0   5
# compact     12  35   0
# midsize      3  38   0
# minivan      0  11   0
# pickup      33   0   0
# subcompact   4  22   9
# suv         51   0  11

# %%
sns.heatmap(mpg_count_map.transpose(), cmap='Blues')
# Out:
# <AxesSubplot:xlabel='class', ylabel='drv'>

# %% [markdown]
#  ## Aesthetic mappings

# %%
mpg_1 = mpg.query('displ > 5 and hwy > 20')

# %%
_, ax = plt.subplots(figsize=(8, 6))

sns.scatterplot(
    data=mpg, x='displ', y='hwy', 
    color='blue', 
    ax=ax)
sns.scatterplot(
    data=mpg_1, x='displ', y='hwy', 
    color='red', size=2.2, 
    ax=ax)
ax.legend('')

# %%
sns.scatterplot(
    data=mpg, x='displ', y='hwy', 
    hue='class')
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %%
sns.scatterplot(
    data=mpg, x='displ', y='hwy', 
    size='class')
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %% [markdown]
#  Seaborn can not accept categorical values in `alpha` of `scatterplot()`

# %%
cat_list = mpg['class'].unique()
cat_num = len(cat_list)
color_dict = {}

for i in range(cat_num):
    color_dict[cat_list[i]] = to_rgba('cornflowerblue', i/10)

_, axes = plt.subplots(1, 2, figsize=(16, 8))

sns.scatterplot(
    data=mpg, x='displ', y='hwy', 
    hue='class', palette=color_dict, 
    ax=axes[0])
sns.scatterplot(
    data=mpg, x='displ', y='hwy', 
    style='class', 
    ax=axes[1])
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %% [markdown]
#  ### Exercise

# %%
sns.scatterplot(
    data=mpg, x='displ', y='hwy', 
    color='blue')
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %%
sns.scatterplot(
    data=mpg, x='displ', y='hwy', 
    hue='cty', cmap='Blues')
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %%
sns.scatterplot(
    data=mpg, x='displ', y='hwy', 
    size='cty')
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %%
sns.scatterplot(
    data=mpg, x='displ', y='hwy', 
    hue='hwy', size='displ', cmap='Blues')
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %%
mtcars.shape
# Out:
# (32, 12)

# %% [markdown]
# Seaborn has no `stroke` property

# %%
sns.scatterplot(
    data=mpg.query('displ < 5'), x='displ', y='hwy', 
    color='blue')
sns.scatterplot(
    data=mpg.query('displ >= 5'), x='displ', y='hwy', 
    color='red')
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %% [markdown]
#  ## Facets

# %%
sns.relplot(
    data=mpg, x='displ', y='hwy', 
    col='cyl', row='drv')

# %%
sns.relplot(
    data=mpg, x='displ', y='hwy', 
    col='cty', col_wrap=4)

# %%
sns.scatterplot(
    data = mpg, x = 'drv', y = 'cyl')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='cyl'>

# %%
sns.relplot(
    data=mpg, x = 'hwy', y = 'cty', 
    col='cyl', row='drv')

# %%
sns.relplot(
    data=mpg, x = 'hwy', y = 'cty', 
    row='drv')

# %%
sns.relplot(
    data=mpg, x = 'hwy', y = 'cty', 
    col='cyl')

# %%
sns.relplot(
    data = mpg, x = 'displ', y = 'hwy', 
    col='class', col_wrap = 4)

# %% [markdown]
# ## Geometric objects

# %%
_, axes = plt.subplots(1, 2, figsize=(16, 8))

sns.scatterplot(
    data=mpg, x='displ', y='hwy',
    ax=axes[0])
sns.regplot(
    data=mpg, x='displ', y='hwy',
    order=2, ax=axes[1])
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %%
sns.lmplot(
    data=mpg, x='displ', y='hwy',
    hue='drv'
    )

# %%
_, ax = plt.subplots(figsize=(8, 8))


sns.scatterplot(
    data=mpg, x='displ', y='hwy',
    hue='drv',
    ax=ax
    )

drvs = mpg.drv.unique().to_list()
line_styles = ['-', '-.', '--']

for i in range(len(line_styles)):
    sns.regplot(
        data=mpg.query(f"drv=='{drvs[i]}'"), x='displ', y='hwy',
        line_kws={'linestyle': line_styles[i]}, 
        ax=ax)

# %%
_, ax = plt.subplots(figsize=(8, 8))


sns.scatterplot(
    data=mpg, x='displ', y='hwy',
    hue='_class',
    ax=ax
    )
sns.regplot(
    data=mpg.query(f"_class=='subcompact'"), x='displ', y='hwy',
    scatter=False, 
    ax=ax)
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %% [markdown]
# ## Statistical transformations
