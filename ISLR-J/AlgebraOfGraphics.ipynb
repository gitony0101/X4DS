# %%
begin
	using LinearAlgebra
	using StatsKit
	using AlgebraOfGraphics, GLMakie
end

# %%
income_df = CSV.File("../data-islr/Income1.csv") |> DataFrame;

# %%
income_df |> first
# Out:
# DataFrameRow
# │ Row │ Column1 │ Education │ Income  │
# │     │ Int64   │ Float64   │ Float64 │
# ├─────┼─────────┼───────────┼─────────┤
# │ 1   │ 1       │ 10.0      │ 26.6588 │

# %%
p1 = (
    data(income_df) * 
    mapping(:Education, :Income) * 
    (visual(Scatter, color="blue") + AlgebraOfGraphics.linear) |> 
draw)
# Out:
# Figure()

# %%
p2 = (
    data(income_df) * 
    mapping(:Education, :Income) * 
    visual(Scatter, color="blue") |> 
draw)
# Out:
# Figure()

# %%
f = Figure()
ax1 = Axis(f[1, 1])
ax2 = Axis(f[1, 2])
# Out:
# Axis with 0 plots:
