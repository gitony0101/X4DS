# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
data = pd.read_csv("./airbnb/Airbnb_Listings.csv")
pd.set_option('display.max_columns',200)
data
# Out:
#             id                            listing_url       scrape_id  \
# 0         4952      https://www.airbnb.com/rooms/4952  20200530151957
# 1        11464     https://www.airbnb.com/rooms/11464  20200530151957
# 2        17884     https://www.airbnb.com/rooms/17884  20200530151957
# 3        21373     https://www.airbnb.com/rooms/21373  20200530151957
# 4        37512     https://www.airbnb.com/rooms/37512  20200530151957
# ...        ...                                    ...             ...
# 7216  43567384  https://www.airbnb.com/rooms/43567384  20200530151957
# 7217  43568844  https://www.airbnb.com/rooms/43568844  20200530151957
# 7218  43579879  https://www.airbnb.com/rooms/43579879  20200530151957
# 7219  43580120  https://www.airbnb.com/rooms/43580120  20200530151957
# 7220  43591340  https://www.airbnb.com/rooms/43591340  20200530151957
#
#      last_scraped                                              name  \
# 0      2020-05-30                 Butterfly Inn - Graceful Living !
# 1      2020-05-31                 Deluxe Private Studio-custom int.
# 2      2020-05-31                              Silicon Valley Suite
# 3      2020-05-30               Bonsai Garden Inn in Professorville
# 4      2020-05-31                 Private  room - Parking 3 carport
# ...           ...                                               ...
# 7216   2020-05-31          Clean & Cozy Studio Naglee Park San Jose
# 7217   2020-05-31  Sophisticated, elegant, remodeled and furnished.
# 7218   2020-05-31                           Sunny room in Sunnyvale
# 7219   2020-05-30                         Affordable Rose Glen Home
# 7220   2020-05-31                             Cozy San Jose Two Bed
#
#                                                 summary  \
# 0     Lovely garden setting in a serene and art-fill...
# 1     Custom built Studio with exquisite design. Rea...
# 2     A guest suite for one or two, in a house in a ...
# 3     Room  in gracious home with beautiful garden. ...
# 4     We live in a safe community close to public tr...
# ...                                                 ...
# 7216  Clean and Cozy Studio in the heart of beautifu...
# 7217  Living Room Furniture: L-shape sopha with coff...
# 7218  Sunny room in a single family house of young p...
# 7219  Come stay in a comfortable two story home in W...
# 7220  Beautifully recently remodeled San Jose two be...
#
#                                                   space  \
# 0     Very comfortable Queen bed and small desk in b...
# 1     Description A favorite for international corpo...
# 2     This is a private suite at the rear of a house...
# 3     Bright, garden-facing room in beautiful home. ...
# 4     I have a really nice room in a quiet neighborh...
# ...                                                 ...
# 7216  Stay at this clean and affordable studio with ...
# 7217  Sophisticated, elegant, spacious, completely r...
# 7218                                                NaN
# 7219  -no smoking or drugs allowed on the property -...
# 7220  Close to fabulous local hikes (Big Basin State...
#
#                                             description experiences_offered  \
# 0     Lovely garden setting in a serene and art-fill...                none
# 1     Custom built Studio with exquisite design. Rea...                none
# 2     A guest suite for one or two, in a house in a ...                none
# 3     Room  in gracious home with beautiful garden. ...                none
# 4     We live in a safe community close to public tr...                none
# ...                                                 ...                 ...
# 7216  Clean and Cozy Studio in the heart of beautifu...                none
# 7217  Living Room Furniture: L-shape sopha with coff...                none
# 7218  Sunny room in a single family house of young p...                none
# 7219  Come stay in a comfortable two story home in W...                none
# 7220  Beautifully recently remodeled San Jose two be...                none
#
#                                   neighborhood_overview  \
# 0     Located in Professorville, Palo Alto, one of t...
# 1     10 min. to Lucky's and Starbucks at El Camino ...
# 2     This is a very quiet family neighborhood, but ...
# 3     This room is in an ultra convenient location i...
# 4     Our community is a safe environment and at nig...
# ...                                                 ...
# 7216  We are walking distance to SJUC and all the sh...
# 7217  Central location for Silicon Valley, 1.5 ml fr...
# 7218  in the heart of the Silicon Valley on a quiet ...
# 7219  Rose Glen is a quiet, residential neighborhood...
# 7220                                                NaN
#
#                                                   notes  \
# 0     Housekeeping every Monday, leave your door ope...
# 1     Pet Policy: - Well Behaved pet up to 25 lb. of...
# 2     I cannot accommodate cats, sorry. I can usuall...
# 3     The family room has a flat panel tv and desk f...
# 4     Please remember that you are in my home and re...
# ...                                                 ...
# 7216                                                NaN
# 7217  Additional closet in the hallway and outside p...
# 7218                                                NaN
# 7219                                                NaN
# 7220                                                NaN
#
#                                                 transit  \
# 0     Walking distance to Stanford University (30 mi...
# 1     Public transportation at Homestead and Pomeroy...
# 2     The CalTrain station is in walking distance, a...
# 3     The Stanford Shopping Center is 20 minutes wal...
# 4     We have a bus stop right outside our community...
# ...                                                 ...
# 7216  Convenient walking distance to SJSU, downtown ...
# 7217  Carport Parking space # 214 included at no cos...
# 7218  walk or a short drive to area employers, short...
# 7219  5 min walking distance to San Jose City Colleg...
# 7220                                                NaN
#
#                                                  access  \
# 0     Kitchen, laundry, family/TV room, garden, free...
# 1             Complimentary Wifi-internet + Basic Cable
# 2     Private outdoor patio. Shared washer/dryer on ...
# 3     Kitchen, Laundry, Garden, Family Room with TV,...
# 4     The kitchen and all that it offers.  The laund...
# ...                                                 ...
# 7216                                                NaN
# 7217  Condominium complex has 2 pools, hut tub, tenn...
# 7218                                                NaN
# 7219  Guests are welcome to use a fully furnished co...
# 7220                                                NaN
#
#                                             interaction  \
# 0     Welcome and Orientation. Shared kitchen, garde...
# 1     Available any time for support and problem res...
# 2     I am usually in town.  Guests have a private e...
# 3     We will see you everyday as we cook meals in t...
# 4     We follow our guests lead when it comes to soc...
# ...                                                 ...
# 7216  We're available to help you as needed. Our res...
# 7217  I am available for a meeting, email, phone and...
# 7218  Available by phone or email, but will not be o...
# 7219  -this is a 2-story house with 3-4 Co-ED renter...
# 7220                                                NaN
#
#                                             house_rules  thumbnail_url  \
# 0     No shoes in the house beyond the hall or laund...            NaN
# 1     Can house a couple- bed type is a full size be...            NaN
# 2     This is a quiet neighborhood, and the suite sh...            NaN
# 3     No shoes in the house beyond hall or laundry. ...            NaN
# 4     No drunk and disorderly conduct please.  You m...            NaN
# ...                                                 ...            ...
# 7216  We truly want you to feel at home. We also ask...            NaN
# 7217  No smoking, no drugs, no pets. Please wash dis...            NaN
# 7218                                                NaN            NaN
# 7219       quiet hours after 10pm no shoes in the house            NaN
# 7220                  Quiet hours between 10 pm to 8 am            NaN
#
#       medium_url                                        picture_url  \
# 0            NaN  https://a0.muscache.com/im/pictures/529448/3d7...
# 1            NaN  https://a0.muscache.com/im/pictures/121321/2c5...
# 2            NaN  https://a0.muscache.com/im/pictures/08c0f0aa-3...
# 3            NaN  https://a0.muscache.com/im/pictures/527285/0f9...
# 4            NaN  https://a0.muscache.com/im/pictures/47698055/3...
# ...          ...                                                ...
# 7216         NaN  https://a0.muscache.com/im/pictures/31b48d6d-b...
# 7217         NaN  https://a0.muscache.com/im/pictures/94397916-0...
# 7218         NaN  https://a0.muscache.com/im/pictures/2dc0867b-c...
# 7219         NaN  https://a0.muscache.com/im/pictures/e026b68f-9...
# 7220         NaN  https://a0.muscache.com/im/pictures/df7c6960-f...
#
#       xl_picture_url    host_id                                     host_url  \
# 0                NaN       7054       https://www.airbnb.com/users/show/7054
# 1                NaN      42458      https://www.airbnb.com/users/show/42458
# 2                NaN      69023      https://www.airbnb.com/users/show/69023
# 3                NaN       7054       https://www.airbnb.com/users/show/7054
# 4                NaN     161741     https://www.airbnb.com/users/show/161741
# ...              ...        ...                                          ...
# 7216             NaN    5974627    https://www.airbnb.com/users/show/5974627
# 7217             NaN  347799221  https://www.airbnb.com/users/show/347799221
# 7218             NaN  341673005  https://www.airbnb.com/users/show/341673005
# 7219             NaN   31314220   https://www.airbnb.com/users/show/31314220
# 7220             NaN    6202502    https://www.airbnb.com/users/show/6202502
#
#      host_name  host_since                             host_location  \
# 0      Mei Lin  2009-01-24      Palo Alto, California, United States
# 1         Emey  2009-09-30  Mountain View, California, United States
# 2        Janet  2010-01-08        Lynn Haven, Florida, United States
# 3      Mei Lin  2009-01-24      Palo Alto, California, United States
# 4        Maria  2010-07-09       San Jose, California, United States
# ...        ...         ...                                       ...
# 7216     Susan  2013-04-17                 California, United States
# 7217     Irene  2020-05-27    Santa Clara, California, United States
# 7218     Sunny  2020-03-15         New York, New York, United States
# 7219   Miranda  2015-04-15    Santa Clara, California, United States
# 7220  Isabelle  2013-05-02  San Francisco, California, United States
#
#                                              host_about  host_response_time  \
# 0     I have lived and worked in Asia, Europe, Austr...      within an hour
# 1     I pride myself on attention to details and cus...      within an hour
# 2     I am a software engineer, recently retired fro...        within a day
# 3     I have lived and worked in Asia, Europe, Austr...      within an hour
# 4      I am in a committed relationship with my live...  within a few hours
# ...                                                 ...                 ...
# 7216  I'm mature, responsible, non-smoker with no pe...  within a few hours
# 7217                                    Property owner                  NaN
# 7218                                                NaN                 NaN
# 7219     Startup entrepreneur based in Silicon Valley.                  NaN
# 7220  I am a travel nurse working with the U.S. mili...      within an hour
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 0                  100%                  98%                 t
# 1                  100%                  90%                 f
# 2                  100%                  50%                 f
# 3                  100%                  98%                 t
# 4                  100%                 100%                 t
# ...                 ...                  ...               ...
# 7216               100%                  90%                 t
# 7217                NaN                  NaN                 f
# 7218                NaN                  NaN                 f
# 7219                NaN                  NaN                 f
# 7220               100%                  99%                 f
#
#                                      host_thumbnail_url  \
# 0     https://a0.muscache.com/im/users/7054/profile_...
# 1     https://a0.muscache.com/im/users/42458/profile...
# 2     https://a0.muscache.com/im/users/69023/profile...
# 3     https://a0.muscache.com/im/users/7054/profile_...
# 4     https://a0.muscache.com/im/users/161741/profil...
# ...                                                 ...
# 7216  https://a0.muscache.com/im/pictures/user/62603...
# 7217  https://a0.muscache.com/im/pictures/user/aa59d...
# 7218  https://a0.muscache.com/im/pictures/user/881b6...
# 7219  https://a0.muscache.com/im/users/31314220/prof...
# 7220  https://a0.muscache.com/im/pictures/user/92735...
#
#                                        host_picture_url host_neighbourhood  \
# 0     https://a0.muscache.com/im/users/7054/profile_...          Palo Alto
# 1     https://a0.muscache.com/im/users/42458/profile...        Santa Clara
# 2     https://a0.muscache.com/im/users/69023/profile...          Palo Alto
# 3     https://a0.muscache.com/im/users/7054/profile_...          Palo Alto
# 4     https://a0.muscache.com/im/users/161741/profil...     South San Jose
# ...                                                 ...                ...
# 7216  https://a0.muscache.com/im/pictures/user/62603...        Naglee Park
# 7217  https://a0.muscache.com/im/pictures/user/aa59d...                NaN
# 7218  https://a0.muscache.com/im/pictures/user/881b6...              Snail
# 7219  https://a0.muscache.com/im/users/31314220/prof...          Rose Glen
# 7220  https://a0.muscache.com/im/pictures/user/92735...      Mountain View
#
#       host_listings_count  host_total_listings_count  \
# 0                     5.0                        5.0
# 1                    13.0                       13.0
# 2                     2.0                        2.0
# 3                     5.0                        5.0
# 4                     2.0                        2.0
# ...                   ...                        ...
# 7216                  2.0                        2.0
# 7217                  1.0                        1.0
# 7218                  0.0                        0.0
# 7219                  0.0                        0.0
# 7220                 71.0                       71.0
#
#                                      host_verifications host_has_profile_pic  \
# 0     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1                         ['email', 'phone', 'reviews']                    t
# 2                  ['email', 'phone', 'reviews', 'kba']                    t
# 3     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 4     ['email', 'phone', 'facebook', 'reviews', 'man...                    t
# ...                                                 ...                  ...
# 7216  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 7217                   ['email', 'phone', 'work_email']                    t
# 7218  ['phone', 'offline_government_id', 'selfie', '...                    t
# 7219  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 7220  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#      host_identity_verified                            street  \
# 0                         f      Palo Alto, CA, United States
# 1                         f    Santa Clara, CA, United States
# 2                         t  Mountain View, CA, United States
# 3                         f      Palo Alto, CA, United States
# 4                         t       San Jose, CA, United States
# ...                     ...                               ...
# 7216                      t       San Jose, CA, United States
# 7217                      f    Santa Clara, CA, United States
# 7218                      f      Sunnyvale, CA, United States
# 7219                      t       San Jose, CA, United States
# 7220                      f       San Jose, CA, United States
#
#           neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed  \
# 0             Palo Alto              Palo Alto                           NaN
# 1           Santa Clara            Santa Clara                           NaN
# 2         Mountain View          Mountain View                           NaN
# 3             Palo Alto              Palo Alto                           NaN
# 4        South San Jose               San Jose                           NaN
# ...                 ...                    ...                           ...
# 7216        Naglee Park               San Jose                           NaN
# 7217        Santa Clara            Santa Clara                           NaN
# 7218          Sunnyvale              Sunnyvale                           NaN
# 7219  Burbank/Del Monte               San Jose                           NaN
# 7220   Cambrian/Pioneer               San Jose                           NaN
#
#                city state zipcode         market     smart_location  \
# 0         Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA
# 1       Santa Clara    CA   95051  South Bay, CA    Santa Clara, CA
# 2     Mountain View    CA   94041  South Bay, CA  Mountain View, CA
# 3         Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA
# 4          San Jose    CA   95111  South Bay, CA       San Jose, CA
# ...             ...   ...     ...            ...                ...
# 7216       San Jose    CA   95112   South Bay CA       San Jose, CA
# 7217    Santa Clara    CA   95051   South Bay CA    Santa Clara, CA
# 7218      Sunnyvale    CA   94085   South Bay CA      Sunnyvale, CA
# 7219       San Jose    CA   95128   South Bay CA       San Jose, CA
# 7220       San Jose    CA   95118   South Bay CA       San Jose, CA
#
#      country_code        country  latitude  longitude is_location_exact  \
# 0              US  United States  37.43972 -122.15672                 t
# 1              US  United States  37.34342 -121.98829                 t
# 2              US  United States  37.38612 -122.07357                 t
# 3              US  United States  37.44001 -122.15667                 t
# 4              US  United States  37.30598 -121.84036                 t
# ...           ...            ...       ...        ...               ...
# 7216           US  United States  37.33794 -121.87189                 t
# 7217           US  United States  37.35473 -121.99940                 t
# 7218           US  United States  37.39309 -122.02541                 t
# 7219           US  United States  37.31209 -121.92103                 t
# 7220           US  United States  37.24502 -121.87745                 t
#
#      property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0            Villa     Private room             2        2.0       1.0   1.0
# 1        Apartment  Entire home/apt             1        1.0       NaN   1.0
# 2      Guest suite  Entire home/apt             2        1.0       1.0   1.0
# 3            Villa     Private room             1        2.0       1.0   1.0
# 4         Bungalow     Private room             2        1.0       1.0   1.0
# ...            ...              ...           ...        ...       ...   ...
# 7216   Guest suite  Entire home/apt             1        1.0       0.0   1.0
# 7217   Condominium  Entire home/apt             4        1.0       1.0   2.0
# 7218         House     Private room             1        1.0       1.0   1.0
# 7219         House     Private room             1        1.0       1.0   1.0
# 7220     Apartment  Entire home/apt             4        1.0       2.0   2.0
#
#       bed_type                                          amenities  \
# 0     Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...
# 1     Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 2     Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 3     Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...
# 4     Real Bed  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...
# ...        ...                                                ...
# 7216  Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,"Free par...
# 7217  Real Bed  {TV,"Cable TV",Wifi,"Air conditioning",Pool,Ki...
# 7218  Real Bed  {TV,Wifi,Kitchen,"Free parking on premises",Wa...
# 7219  Real Bed  {TV,Wifi,"Air conditioning",Kitchen,"Free park...
# 7220  Real Bed  {TV,Wifi,"Air conditioning",Kitchen,"Free park...
#
#       square_feet    price weekly_price monthly_price security_deposit  \
# 0             NaN   $90.00      $440.00     $1,428.00            $0.00
# 1           325.0   $85.00          NaN     $2,100.00          $700.00
# 2             NaN   $65.00    $1,400.00     $2,800.00        $1,000.00
# 3             NaN   $99.00      $600.00     $2,000.00            $0.00
# 4             NaN   $52.00      $393.00     $1,386.00              NaN
# ...           ...      ...          ...           ...              ...
# 7216          NaN   $49.00          NaN           NaN          $500.00
# 7217          NaN  $135.00          NaN           NaN          $500.00
# 7218          NaN   $85.00          NaN           NaN            $0.00
# 7219          NaN   $49.00          NaN           NaN        $1,000.00
# 7220          NaN  $145.00          NaN           NaN          $400.00
#
#      cleaning_fee  guests_included extra_people  minimum_nights  \
# 0          $35.00                1       $45.00               2
# 1         $250.00                1       $10.00              14
# 2             NaN                1        $0.00              30
# 3          $35.00                1       $50.00               2
# 4             NaN                1        $0.00               1
# ...           ...              ...          ...             ...
# 7216      $100.00                1       $50.00               3
# 7217      $135.00                2       $20.00              30
# 7218      $150.00                1       $25.00              30
# 7219      $150.00                1       $10.00              14
# 7220       $90.00                1        $0.00               1
#
#       maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0                365                       2                       2
# 1                365                      14                      14
# 2                180                      30                      30
# 3                730                       2                       2
# 4                  7                       1                       1
# ...              ...                     ...                     ...
# 7216            1125                       3                       3
# 7217            1125                      30                      30
# 7218            1125                      30                      30
# 7219             365                      14                      14
# 7220            1125                       1                       1
#
#       minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                        365                     365                     2.0
# 1                        365                     365                    14.0
# 2                        180                     180                    30.0
# 3                        730                     730                     2.0
# 4                          7                       7                     1.0
# ...                      ...                     ...                     ...
# 7216                    1125                    1125                     3.0
# 7217                    1125                    1125                    30.0
# 7218                    1125                    1125                    30.0
# 7219                    1125                    1125                    14.0
# 7220                    1125                    1125                     1.0
#
#       maximum_nights_avg_ntm calendar_updated has_availability  \
# 0                      365.0     2 months ago                t
# 1                      365.0     5 months ago                t
# 2                      180.0      4 weeks ago                t
# 3                      730.0      3 weeks ago                t
# 4                        7.0    23 months ago                t
# ...                      ...              ...              ...
# 7216                  1125.0       3 days ago                t
# 7217                  1125.0       3 days ago                t
# 7218                  1125.0       2 days ago                t
# 7219                  1125.0       2 days ago                t
# 7220                  1125.0            never                t
#
#       availability_30  availability_60  availability_90  availability_365  \
# 0                   0                0                0                 0
# 1                  30               60               90               179
# 2                  29               59               89               179
# 3                   0                0                0               212
# 4                   0                0               28               303
# ...               ...              ...              ...               ...
# 7216               29               30               30                30
# 7217               25               55               85               360
# 7218               14               44               46                46
# 7219               30               60               90               180
# 7220               25               55               85               360
#
#      calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# 0               2020-05-30                 75                      0
# 1               2020-05-31                  6                      1
# 2               2020-05-31                  2                      0
# 3               2020-05-30                264                     39
# 4               2020-05-31                183                      0
# ...                    ...                ...                    ...
# 7216            2020-05-31                  0                      0
# 7217            2020-05-31                  0                      0
# 7218            2020-05-31                  0                      0
# 7219            2020-05-30                  0                      0
# 7220            2020-05-31                  0                      0
#
#      first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0      2009-08-02  2019-01-12                  96.0                    10.0
# 1      2014-06-15  2019-10-11                  87.0                    10.0
# 2      2018-11-20  2019-04-27                  90.0                     8.0
# 3      2010-05-28  2020-03-14                  97.0                    10.0
# 4      2010-08-01  2017-03-14                  94.0                     9.0
# ...           ...         ...                   ...                     ...
# 7216          NaN         NaN                   NaN                     NaN
# 7217          NaN         NaN                   NaN                     NaN
# 7218          NaN         NaN                   NaN                     NaN
# 7219          NaN         NaN                   NaN                     NaN
# 7220          NaN         NaN                   NaN                     NaN
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                          10.0                   10.0
# 1                          10.0                   10.0
# 2                          10.0                   10.0
# 3                          10.0                   10.0
# 4                          10.0                   10.0
# ...                         ...                    ...
# 7216                        NaN                    NaN
# 7217                        NaN                    NaN
# 7218                        NaN                    NaN
# 7219                        NaN                    NaN
# 7220                        NaN                    NaN
#
#       review_scores_communication  review_scores_location  \
# 0                            10.0                    10.0
# 1                             9.0                     9.0
# 2                            10.0                    10.0
# 3                            10.0                    10.0
# 4                            10.0                     9.0
# ...                           ...                     ...
# 7216                          NaN                     NaN
# 7217                          NaN                     NaN
# 7218                          NaN                     NaN
# 7219                          NaN                     NaN
# 7220                          NaN                     NaN
#
#       review_scores_value requires_license  license       jurisdiction_names  \
# 0                    10.0                f      NaN            {"PALO ALTO"}
# 1                     9.0                f      NaN          {"SANTA CLARA"}
# 2                    10.0                f      NaN  {"Mountain View"," CA"}
# 3                    10.0                f      NaN            {"PALO ALTO"}
# 4                     9.0                f      NaN             {"SAN JOSE"}
# ...                   ...              ...      ...                      ...
# 7216                  NaN                f      NaN             {"SAN JOSE"}
# 7217                  NaN                f      NaN          {"SANTA CLARA"}
# 7218                  NaN                f      NaN        {Sunnyvale," CA"}
# 7219                  NaN                f      NaN             {"SAN JOSE"}
# 7220                  NaN                f      NaN             {"SAN JOSE"}
#
#      instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                   f                        f                     moderate
# 1                   f                        f                     moderate
# 2                   f                        f  strict_14_with_grace_period
# 3                   f                        f                     moderate
# 4                   f                        f                     moderate
# ...               ...                      ...                          ...
# 7216                f                        f                     moderate
# 7217                f                        f  strict_14_with_grace_period
# 7218                t                        f                     flexible
# 7219                f                        f                     moderate
# 7220                t                        f  strict_14_with_grace_period
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 0                                f                                f
# 1                                f                                t
# 2                                f                                f
# 3                                f                                f
# 4                                t                                t
# ...                            ...                              ...
# 7216                             f                                f
# 7217                             f                                f
# 7218                             f                                f
# 7219                             f                                f
# 7220                             f                                f
#
#       calculated_host_listings_count  \
# 0                                  5
# 1                                 12
# 2                                  2
# 3                                  5
# 4                                  2
# ...                              ...
# 7216                               2
# 7217                               1
# 7218                               1
# 7219                               1
# 7220                              21
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               0
# 1                                              12
# 2                                               2
# 3                                               0
# 4                                               0
# ...                                           ...
# 7216                                            2
# 7217                                            1
# 7218                                            0
# 7219                                            0
# 7220                                           19
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                5
# 1                                                0
# 2                                                0
# 3                                                5
# 4                                                2
# ...                                            ...
# 7216                                             0
# 7217                                             0
# 7218                                             1
# 7219                                             1
# 7220                                             2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               0.57
# 1                                               0               0.08
# 2                                               0               0.11
# 3                                               0               2.17
# 4                                               0               1.53
# ...                                           ...                ...
# 7216                                            0                NaN
# 7217                                            0                NaN
# 7218                                            0                NaN
# 7219                                            0                NaN
# 7220                                            0                NaN
#
# [7221 rows x 106 columns]

# %%
data.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  7.221000e+03  7.221000e+03            0.0         0.0             0.0
# mean   2.623922e+07  2.020053e+13            NaN         NaN             NaN
# std    1.236420e+07  0.000000e+00            NaN         NaN             NaN
# min    4.952000e+03  2.020053e+13            NaN         NaN             NaN
# 25%    1.624242e+07  2.020053e+13            NaN         NaN             NaN
# 50%    2.818432e+07  2.020053e+13            NaN         NaN             NaN
# 75%    3.749948e+07  2.020053e+13            NaN         NaN             NaN
# max    4.359134e+07  2.020053e+13            NaN         NaN             NaN
#
#             host_id  host_listings_count  host_total_listings_count  \
# count  7.221000e+03          7220.000000                7220.000000
# mean   8.886443e+07           139.588504                 139.588504
# std    9.390593e+07           472.674992                 472.674992
# min    7.054000e+03             0.000000                   0.000000
# 25%    1.697278e+07             1.000000                   1.000000
# 50%    4.800549e+07             3.000000                   3.000000
# 75%    1.429331e+08            10.000000                  10.000000
# max    3.477992e+08          2007.000000                2007.000000
#
#        neighbourhood_group_cleansed     latitude    longitude  accommodates  \
# count                           0.0  7221.000000  7221.000000   7221.000000
# mean                            NaN    37.352285  -121.966600      3.114804
# std                             NaN     0.064819     0.108587      2.370579
# min                             NaN    36.965600  -122.190350      1.000000
# 25%                             NaN    37.319770  -122.042450      2.000000
# 50%                             NaN    37.358260  -121.961940      2.000000
# 75%                             NaN    37.398250  -121.886340      4.000000
# max                             NaN    37.462980  -121.380120     16.000000
#
#          bathrooms     bedrooms         beds  square_feet  guests_included  \
# count  7220.000000  7215.000000  7153.000000    29.000000      7221.000000
# mean      1.383449     1.421760     1.817000   691.000000         1.699349
# std       0.688715     0.999833     1.633911   735.833492         1.620945
# min       0.000000     0.000000     0.000000    50.000000         1.000000
# 25%       1.000000     1.000000     1.000000   225.000000         1.000000
# 50%       1.000000     1.000000     1.000000   396.000000         1.000000
# 75%       2.000000     2.000000     2.000000   950.000000         2.000000
# max       8.000000     9.000000    54.000000  3600.000000        16.000000
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# count     7221.000000    7.221000e+03             7221.000000
# mean         9.756959    2.980880e+05                9.142916
# std         34.689846    2.527150e+07               35.027086
# min          1.000000    1.000000e+00                1.000000
# 25%          1.000000    6.000000e+01                1.000000
# 50%          2.000000    1.125000e+03                2.000000
# 75%          7.000000    1.125000e+03                5.000000
# max       1125.000000    2.147484e+09             1125.000000
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# count             7221.000000            7.221000e+03            7.221000e+03
# mean                14.247888            2.982325e+05            1.785205e+06
# std                 63.358607            2.527150e+07            6.188084e+07
# min                  1.000000            1.000000e+00            1.000000e+00
# 25%                  1.000000            3.650000e+02            3.650000e+02
# 50%                  2.000000            1.125000e+03            1.125000e+03
# 75%                  7.000000            1.125000e+03            1.125000e+03
# max               1125.000000            2.147484e+09            2.147484e+09
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  availability_30  \
# count             7221.000000            7.221000e+03      7221.000000
# mean                13.631505            1.538945e+06        13.689101
# std                 61.691820            5.347742e+07        13.616884
# min                  1.000000            1.000000e+00         0.000000
# 25%                  1.000000            3.650000e+02         0.000000
# 50%                  2.000000            1.125000e+03        10.000000
# 75%                  7.000000            1.125000e+03        29.000000
# max               1125.000000            2.147484e+09        30.000000
#
#        availability_60  availability_90  availability_365  number_of_reviews  \
# count      7221.000000      7221.000000       7221.000000        7221.000000
# mean         30.373494        48.260352        160.282648          29.853760
# std          26.501026        38.981316        141.746896          51.488761
# min           0.000000         0.000000          0.000000           0.000000
# 25%           0.000000         0.000000          1.000000           1.000000
# 50%          30.000000        59.000000        136.000000          10.000000
# 75%          59.000000        89.000000        323.000000          35.000000
# max          60.000000        90.000000        365.000000         488.000000
#
#        number_of_reviews_ltm  review_scores_rating  review_scores_accuracy  \
# count            7221.000000           5854.000000             5852.000000
# mean                9.369201             95.245473                9.723855
# std                15.188236              7.734005                0.741816
# min                 0.000000             20.000000                2.000000
# 25%                 0.000000             94.000000               10.000000
# 50%                 3.000000             98.000000               10.000000
# 75%                12.000000            100.000000               10.000000
# max               154.000000            100.000000               10.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                5852.000000            5851.000000
# mean                    9.572454               9.815074
# std                     0.848685               0.641301
# min                     2.000000               2.000000
# 25%                     9.000000              10.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                  5852.000000             5851.000000
# mean                      9.793233                9.796103
# std                       0.691503                0.583498
# min                       2.000000                2.000000
# 25%                      10.000000               10.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  license  calculated_host_listings_count  \
# count          5851.000000      0.0                     7221.000000
# mean              9.527773      NaN                       32.048608
# std               0.833306      NaN                       95.159193
# min               2.000000      NaN                        1.000000
# 25%               9.000000      NaN                        1.000000
# 50%              10.000000      NaN                        3.000000
# 75%              10.000000      NaN                        8.000000
# max              10.000000      NaN                      411.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  7221.000000
# mean                                     28.216729
# std                                      95.714488
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                     411.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   7221.000000
# mean                                       2.775793
# std                                        6.810433
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# 75%                                        3.000000
# max                                       62.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  7221.000000        5912.000000
# mean                                      1.029359           1.357124
# std                                       5.741521           1.530782
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.320000
# 50%                                       0.000000           0.830000
# 75%                                       0.000000           1.810000
# max                                      48.000000          13.120000

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#             id                            listing_url       scrape_id  \
# 0         4952      https://www.airbnb.com/rooms/4952  20200530151957
# 1        11464     https://www.airbnb.com/rooms/11464  20200530151957
# 2        17884     https://www.airbnb.com/rooms/17884  20200530151957
# 3        21373     https://www.airbnb.com/rooms/21373  20200530151957
# 4        37512     https://www.airbnb.com/rooms/37512  20200530151957
# ...        ...                                    ...             ...
# 7216  43567384  https://www.airbnb.com/rooms/43567384  20200530151957
# 7217  43568844  https://www.airbnb.com/rooms/43568844  20200530151957
# 7218  43579879  https://www.airbnb.com/rooms/43579879  20200530151957
# 7219  43580120  https://www.airbnb.com/rooms/43580120  20200530151957
# 7220  43591340  https://www.airbnb.com/rooms/43591340  20200530151957
#
#      last_scraped                                              name  \
# 0      2020-05-30                 Butterfly Inn - Graceful Living !
# 1      2020-05-31                 Deluxe Private Studio-custom int.
# 2      2020-05-31                              Silicon Valley Suite
# 3      2020-05-30               Bonsai Garden Inn in Professorville
# 4      2020-05-31                 Private  room - Parking 3 carport
# ...           ...                                               ...
# 7216   2020-05-31          Clean & Cozy Studio Naglee Park San Jose
# 7217   2020-05-31  Sophisticated, elegant, remodeled and furnished.
# 7218   2020-05-31                           Sunny room in Sunnyvale
# 7219   2020-05-30                         Affordable Rose Glen Home
# 7220   2020-05-31                             Cozy San Jose Two Bed
#
#                                                 summary  \
# 0     Lovely garden setting in a serene and art-fill...
# 1     Custom built Studio with exquisite design. Rea...
# 2     A guest suite for one or two, in a house in a ...
# 3     Room  in gracious home with beautiful garden. ...
# 4     We live in a safe community close to public tr...
# ...                                                 ...
# 7216  Clean and Cozy Studio in the heart of beautifu...
# 7217  Living Room Furniture: L-shape sopha with coff...
# 7218  Sunny room in a single family house of young p...
# 7219  Come stay in a comfortable two story home in W...
# 7220  Beautifully recently remodeled San Jose two be...
#
#                                                   space  \
# 0     Very comfortable Queen bed and small desk in b...
# 1     Description A favorite for international corpo...
# 2     This is a private suite at the rear of a house...
# 3     Bright, garden-facing room in beautiful home. ...
# 4     I have a really nice room in a quiet neighborh...
# ...                                                 ...
# 7216  Stay at this clean and affordable studio with ...
# 7217  Sophisticated, elegant, spacious, completely r...
# 7218                                                NaN
# 7219  -no smoking or drugs allowed on the property -...
# 7220  Close to fabulous local hikes (Big Basin State...
#
#                                             description experiences_offered  \
# 0     Lovely garden setting in a serene and art-fill...                none
# 1     Custom built Studio with exquisite design. Rea...                none
# 2     A guest suite for one or two, in a house in a ...                none
# 3     Room  in gracious home with beautiful garden. ...                none
# 4     We live in a safe community close to public tr...                none
# ...                                                 ...                 ...
# 7216  Clean and Cozy Studio in the heart of beautifu...                none
# 7217  Living Room Furniture: L-shape sopha with coff...                none
# 7218  Sunny room in a single family house of young p...                none
# 7219  Come stay in a comfortable two story home in W...                none
# 7220  Beautifully recently remodeled San Jose two be...                none
#
#                                   neighborhood_overview  \
# 0     Located in Professorville, Palo Alto, one of t...
# 1     10 min. to Lucky's and Starbucks at El Camino ...
# 2     This is a very quiet family neighborhood, but ...
# 3     This room is in an ultra convenient location i...
# 4     Our community is a safe environment and at nig...
# ...                                                 ...
# 7216  We are walking distance to SJUC and all the sh...
# 7217  Central location for Silicon Valley, 1.5 ml fr...
# 7218  in the heart of the Silicon Valley on a quiet ...
# 7219  Rose Glen is a quiet, residential neighborhood...
# 7220                                                NaN
#
#                                                   notes  \
# 0     Housekeeping every Monday, leave your door ope...
# 1     Pet Policy: - Well Behaved pet up to 25 lb. of...
# 2     I cannot accommodate cats, sorry. I can usuall...
# 3     The family room has a flat panel tv and desk f...
# 4     Please remember that you are in my home and re...
# ...                                                 ...
# 7216                                                NaN
# 7217  Additional closet in the hallway and outside p...
# 7218                                                NaN
# 7219                                                NaN
# 7220                                                NaN
#
#                                                 transit  \
# 0     Walking distance to Stanford University (30 mi...
# 1     Public transportation at Homestead and Pomeroy...
# 2     The CalTrain station is in walking distance, a...
# 3     The Stanford Shopping Center is 20 minutes wal...
# 4     We have a bus stop right outside our community...
# ...                                                 ...
# 7216  Convenient walking distance to SJSU, downtown ...
# 7217  Carport Parking space # 214 included at no cos...
# 7218  walk or a short drive to area employers, short...
# 7219  5 min walking distance to San Jose City Colleg...
# 7220                                                NaN
#
#                                                  access  \
# 0     Kitchen, laundry, family/TV room, garden, free...
# 1             Complimentary Wifi-internet + Basic Cable
# 2     Private outdoor patio. Shared washer/dryer on ...
# 3     Kitchen, Laundry, Garden, Family Room with TV,...
# 4     The kitchen and all that it offers.  The laund...
# ...                                                 ...
# 7216                                                NaN
# 7217  Condominium complex has 2 pools, hut tub, tenn...
# 7218                                                NaN
# 7219  Guests are welcome to use a fully furnished co...
# 7220                                                NaN
#
#                                             interaction  \
# 0     Welcome and Orientation. Shared kitchen, garde...
# 1     Available any time for support and problem res...
# 2     I am usually in town.  Guests have a private e...
# 3     We will see you everyday as we cook meals in t...
# 4     We follow our guests lead when it comes to soc...
# ...                                                 ...
# 7216  We're available to help you as needed. Our res...
# 7217  I am available for a meeting, email, phone and...
# 7218  Available by phone or email, but will not be o...
# 7219  -this is a 2-story house with 3-4 Co-ED renter...
# 7220                                                NaN
#
#                                             house_rules  thumbnail_url  \
# 0     No shoes in the house beyond the hall or laund...            NaN
# 1     Can house a couple- bed type is a full size be...            NaN
# 2     This is a quiet neighborhood, and the suite sh...            NaN
# 3     No shoes in the house beyond hall or laundry. ...            NaN
# 4     No drunk and disorderly conduct please.  You m...            NaN
# ...                                                 ...            ...
# 7216  We truly want you to feel at home. We also ask...            NaN
# 7217  No smoking, no drugs, no pets. Please wash dis...            NaN
# 7218                                                NaN            NaN
# 7219       quiet hours after 10pm no shoes in the house            NaN
# 7220                  Quiet hours between 10 pm to 8 am            NaN
#
#       medium_url                                        picture_url  \
# 0            NaN  https://a0.muscache.com/im/pictures/529448/3d7...
# 1            NaN  https://a0.muscache.com/im/pictures/121321/2c5...
# 2            NaN  https://a0.muscache.com/im/pictures/08c0f0aa-3...
# 3            NaN  https://a0.muscache.com/im/pictures/527285/0f9...
# 4            NaN  https://a0.muscache.com/im/pictures/47698055/3...
# ...          ...                                                ...
# 7216         NaN  https://a0.muscache.com/im/pictures/31b48d6d-b...
# 7217         NaN  https://a0.muscache.com/im/pictures/94397916-0...
# 7218         NaN  https://a0.muscache.com/im/pictures/2dc0867b-c...
# 7219         NaN  https://a0.muscache.com/im/pictures/e026b68f-9...
# 7220         NaN  https://a0.muscache.com/im/pictures/df7c6960-f...
#
#       xl_picture_url    host_id                                     host_url  \
# 0                NaN       7054       https://www.airbnb.com/users/show/7054
# 1                NaN      42458      https://www.airbnb.com/users/show/42458
# 2                NaN      69023      https://www.airbnb.com/users/show/69023
# 3                NaN       7054       https://www.airbnb.com/users/show/7054
# 4                NaN     161741     https://www.airbnb.com/users/show/161741
# ...              ...        ...                                          ...
# 7216             NaN    5974627    https://www.airbnb.com/users/show/5974627
# 7217             NaN  347799221  https://www.airbnb.com/users/show/347799221
# 7218             NaN  341673005  https://www.airbnb.com/users/show/341673005
# 7219             NaN   31314220   https://www.airbnb.com/users/show/31314220
# 7220             NaN    6202502    https://www.airbnb.com/users/show/6202502
#
#      host_name  host_since                             host_location  \
# 0      Mei Lin  2009-01-24      Palo Alto, California, United States
# 1         Emey  2009-09-30  Mountain View, California, United States
# 2        Janet  2010-01-08        Lynn Haven, Florida, United States
# 3      Mei Lin  2009-01-24      Palo Alto, California, United States
# 4        Maria  2010-07-09       San Jose, California, United States
# ...        ...         ...                                       ...
# 7216     Susan  2013-04-17                 California, United States
# 7217     Irene  2020-05-27    Santa Clara, California, United States
# 7218     Sunny  2020-03-15         New York, New York, United States
# 7219   Miranda  2015-04-15    Santa Clara, California, United States
# 7220  Isabelle  2013-05-02  San Francisco, California, United States
#
#                                              host_about  host_response_time  \
# 0     I have lived and worked in Asia, Europe, Austr...      within an hour
# 1     I pride myself on attention to details and cus...      within an hour
# 2     I am a software engineer, recently retired fro...        within a day
# 3     I have lived and worked in Asia, Europe, Austr...      within an hour
# 4      I am in a committed relationship with my live...  within a few hours
# ...                                                 ...                 ...
# 7216  I'm mature, responsible, non-smoker with no pe...  within a few hours
# 7217                                    Property owner                  NaN
# 7218                                                NaN                 NaN
# 7219     Startup entrepreneur based in Silicon Valley.                  NaN
# 7220  I am a travel nurse working with the U.S. mili...      within an hour
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 0                  100%                  98%                 t
# 1                  100%                  90%                 f
# 2                  100%                  50%                 f
# 3                  100%                  98%                 t
# 4                  100%                 100%                 t
# ...                 ...                  ...               ...
# 7216               100%                  90%                 t
# 7217                NaN                  NaN                 f
# 7218                NaN                  NaN                 f
# 7219                NaN                  NaN                 f
# 7220               100%                  99%                 f
#
#                                      host_thumbnail_url  \
# 0     https://a0.muscache.com/im/users/7054/profile_...
# 1     https://a0.muscache.com/im/users/42458/profile...
# 2     https://a0.muscache.com/im/users/69023/profile...
# 3     https://a0.muscache.com/im/users/7054/profile_...
# 4     https://a0.muscache.com/im/users/161741/profil...
# ...                                                 ...
# 7216  https://a0.muscache.com/im/pictures/user/62603...
# 7217  https://a0.muscache.com/im/pictures/user/aa59d...
# 7218  https://a0.muscache.com/im/pictures/user/881b6...
# 7219  https://a0.muscache.com/im/users/31314220/prof...
# 7220  https://a0.muscache.com/im/pictures/user/92735...
#
#                                        host_picture_url host_neighbourhood  \
# 0     https://a0.muscache.com/im/users/7054/profile_...          Palo Alto
# 1     https://a0.muscache.com/im/users/42458/profile...        Santa Clara
# 2     https://a0.muscache.com/im/users/69023/profile...          Palo Alto
# 3     https://a0.muscache.com/im/users/7054/profile_...          Palo Alto
# 4     https://a0.muscache.com/im/users/161741/profil...     South San Jose
# ...                                                 ...                ...
# 7216  https://a0.muscache.com/im/pictures/user/62603...        Naglee Park
# 7217  https://a0.muscache.com/im/pictures/user/aa59d...                NaN
# 7218  https://a0.muscache.com/im/pictures/user/881b6...              Snail
# 7219  https://a0.muscache.com/im/users/31314220/prof...          Rose Glen
# 7220  https://a0.muscache.com/im/pictures/user/92735...      Mountain View
#
#       host_listings_count  host_total_listings_count  \
# 0                     5.0                        5.0
# 1                    13.0                       13.0
# 2                     2.0                        2.0
# 3                     5.0                        5.0
# 4                     2.0                        2.0
# ...                   ...                        ...
# 7216                  2.0                        2.0
# 7217                  1.0                        1.0
# 7218                  0.0                        0.0
# 7219                  0.0                        0.0
# 7220                 71.0                       71.0
#
#                                      host_verifications host_has_profile_pic  \
# 0     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1                         ['email', 'phone', 'reviews']                    t
# 2                  ['email', 'phone', 'reviews', 'kba']                    t
# 3     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 4     ['email', 'phone', 'facebook', 'reviews', 'man...                    t
# ...                                                 ...                  ...
# 7216  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 7217                   ['email', 'phone', 'work_email']                    t
# 7218  ['phone', 'offline_government_id', 'selfie', '...                    t
# 7219  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 7220  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#      host_identity_verified                            street  \
# 0                         f      Palo Alto, CA, United States
# 1                         f    Santa Clara, CA, United States
# 2                         t  Mountain View, CA, United States
# 3                         f      Palo Alto, CA, United States
# 4                         t       San Jose, CA, United States
# ...                     ...                               ...
# 7216                      t       San Jose, CA, United States
# 7217                      f    Santa Clara, CA, United States
# 7218                      f      Sunnyvale, CA, United States
# 7219                      t       San Jose, CA, United States
# 7220                      f       San Jose, CA, United States
#
#           neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed  \
# 0             Palo Alto              Palo Alto                           NaN
# 1           Santa Clara            Santa Clara                           NaN
# 2         Mountain View          Mountain View                           NaN
# 3             Palo Alto              Palo Alto                           NaN
# 4        South San Jose               San Jose                           NaN
# ...                 ...                    ...                           ...
# 7216        Naglee Park               San Jose                           NaN
# 7217        Santa Clara            Santa Clara                           NaN
# 7218          Sunnyvale              Sunnyvale                           NaN
# 7219  Burbank/Del Monte               San Jose                           NaN
# 7220   Cambrian/Pioneer               San Jose                           NaN
#
#                city state zipcode         market     smart_location  \
# 0         Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA
# 1       Santa Clara    CA   95051  South Bay, CA    Santa Clara, CA
# 2     Mountain View    CA   94041  South Bay, CA  Mountain View, CA
# 3         Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA
# 4          San Jose    CA   95111  South Bay, CA       San Jose, CA
# ...             ...   ...     ...            ...                ...
# 7216       San Jose    CA   95112   South Bay CA       San Jose, CA
# 7217    Santa Clara    CA   95051   South Bay CA    Santa Clara, CA
# 7218      Sunnyvale    CA   94085   South Bay CA      Sunnyvale, CA
# 7219       San Jose    CA   95128   South Bay CA       San Jose, CA
# 7220       San Jose    CA   95118   South Bay CA       San Jose, CA
#
#      country_code        country  latitude  longitude is_location_exact  \
# 0              US  United States  37.43972 -122.15672                 t
# 1              US  United States  37.34342 -121.98829                 t
# 2              US  United States  37.38612 -122.07357                 t
# 3              US  United States  37.44001 -122.15667                 t
# 4              US  United States  37.30598 -121.84036                 t
# ...           ...            ...       ...        ...               ...
# 7216           US  United States  37.33794 -121.87189                 t
# 7217           US  United States  37.35473 -121.99940                 t
# 7218           US  United States  37.39309 -122.02541                 t
# 7219           US  United States  37.31209 -121.92103                 t
# 7220           US  United States  37.24502 -121.87745                 t
#
#      property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0            Villa     Private room             2        2.0       1.0   1.0
# 1        Apartment  Entire home/apt             1        1.0       NaN   1.0
# 2      Guest suite  Entire home/apt             2        1.0       1.0   1.0
# 3            Villa     Private room             1        2.0       1.0   1.0
# 4         Bungalow     Private room             2        1.0       1.0   1.0
# ...            ...              ...           ...        ...       ...   ...
# 7216   Guest suite  Entire home/apt             1        1.0       0.0   1.0
# 7217   Condominium  Entire home/apt             4        1.0       1.0   2.0
# 7218         House     Private room             1        1.0       1.0   1.0
# 7219         House     Private room             1        1.0       1.0   1.0
# 7220     Apartment  Entire home/apt             4        1.0       2.0   2.0
#
#       bed_type                                          amenities  \
# 0     Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...
# 1     Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 2     Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 3     Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...
# 4     Real Bed  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...
# ...        ...                                                ...
# 7216  Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,"Free par...
# 7217  Real Bed  {TV,"Cable TV",Wifi,"Air conditioning",Pool,Ki...
# 7218  Real Bed  {TV,Wifi,Kitchen,"Free parking on premises",Wa...
# 7219  Real Bed  {TV,Wifi,"Air conditioning",Kitchen,"Free park...
# 7220  Real Bed  {TV,Wifi,"Air conditioning",Kitchen,"Free park...
#
#       square_feet    price weekly_price monthly_price security_deposit  \
# 0             NaN   $90.00      $440.00     $1,428.00            $0.00
# 1           325.0   $85.00          NaN     $2,100.00          $700.00
# 2             NaN   $65.00    $1,400.00     $2,800.00        $1,000.00
# 3             NaN   $99.00      $600.00     $2,000.00            $0.00
# 4             NaN   $52.00      $393.00     $1,386.00              NaN
# ...           ...      ...          ...           ...              ...
# 7216          NaN   $49.00          NaN           NaN          $500.00
# 7217          NaN  $135.00          NaN           NaN          $500.00
# 7218          NaN   $85.00          NaN           NaN            $0.00
# 7219          NaN   $49.00          NaN           NaN        $1,000.00
# 7220          NaN  $145.00          NaN           NaN          $400.00
#
#      cleaning_fee  guests_included extra_people  minimum_nights  \
# 0          $35.00                1       $45.00               2
# 1         $250.00                1       $10.00              14
# 2             NaN                1        $0.00              30
# 3          $35.00                1       $50.00               2
# 4             NaN                1        $0.00               1
# ...           ...              ...          ...             ...
# 7216      $100.00                1       $50.00               3
# 7217      $135.00                2       $20.00              30
# 7218      $150.00                1       $25.00              30
# 7219      $150.00                1       $10.00              14
# 7220       $90.00                1        $0.00               1
#
#       maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0                365                       2                       2
# 1                365                      14                      14
# 2                180                      30                      30
# 3                730                       2                       2
# 4                  7                       1                       1
# ...              ...                     ...                     ...
# 7216            1125                       3                       3
# 7217            1125                      30                      30
# 7218            1125                      30                      30
# 7219             365                      14                      14
# 7220            1125                       1                       1
#
#       minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                        365                     365                     2.0
# 1                        365                     365                    14.0
# 2                        180                     180                    30.0
# 3                        730                     730                     2.0
# 4                          7                       7                     1.0
# ...                      ...                     ...                     ...
# 7216                    1125                    1125                     3.0
# 7217                    1125                    1125                    30.0
# 7218                    1125                    1125                    30.0
# 7219                    1125                    1125                    14.0
# 7220                    1125                    1125                     1.0
#
#       maximum_nights_avg_ntm calendar_updated has_availability  \
# 0                      365.0     2 months ago                t
# 1                      365.0     5 months ago                t
# 2                      180.0      4 weeks ago                t
# 3                      730.0      3 weeks ago                t
# 4                        7.0    23 months ago                t
# ...                      ...              ...              ...
# 7216                  1125.0       3 days ago                t
# 7217                  1125.0       3 days ago                t
# 7218                  1125.0       2 days ago                t
# 7219                  1125.0       2 days ago                t
# 7220                  1125.0            never                t
#
#       availability_30  availability_60  availability_90  availability_365  \
# 0                   0                0                0                 0
# 1                  30               60               90               179
# 2                  29               59               89               179
# 3                   0                0                0               212
# 4                   0                0               28               303
# ...               ...              ...              ...               ...
# 7216               29               30               30                30
# 7217               25               55               85               360
# 7218               14               44               46                46
# 7219               30               60               90               180
# 7220               25               55               85               360
#
#      calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# 0               2020-05-30                 75                      0
# 1               2020-05-31                  6                      1
# 2               2020-05-31                  2                      0
# 3               2020-05-30                264                     39
# 4               2020-05-31                183                      0
# ...                    ...                ...                    ...
# 7216            2020-05-31                  0                      0
# 7217            2020-05-31                  0                      0
# 7218            2020-05-31                  0                      0
# 7219            2020-05-30                  0                      0
# 7220            2020-05-31                  0                      0
#
#      first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0      2009-08-02  2019-01-12                  96.0                    10.0
# 1      2014-06-15  2019-10-11                  87.0                    10.0
# 2      2018-11-20  2019-04-27                  90.0                     8.0
# 3      2010-05-28  2020-03-14                  97.0                    10.0
# 4      2010-08-01  2017-03-14                  94.0                     9.0
# ...           ...         ...                   ...                     ...
# 7216          NaN         NaN                   NaN                     NaN
# 7217          NaN         NaN                   NaN                     NaN
# 7218          NaN         NaN                   NaN                     NaN
# 7219          NaN         NaN                   NaN                     NaN
# 7220          NaN         NaN                   NaN                     NaN
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                          10.0                   10.0
# 1                          10.0                   10.0
# 2                          10.0                   10.0
# 3                          10.0                   10.0
# 4                          10.0                   10.0
# ...                         ...                    ...
# 7216                        NaN                    NaN
# 7217                        NaN                    NaN
# 7218                        NaN                    NaN
# 7219                        NaN                    NaN
# 7220                        NaN                    NaN
#
#       review_scores_communication  review_scores_location  \
# 0                            10.0                    10.0
# 1                             9.0                     9.0
# 2                            10.0                    10.0
# 3                            10.0                    10.0
# 4                            10.0                     9.0
# ...                           ...                     ...
# 7216                          NaN                     NaN
# 7217                          NaN                     NaN
# 7218                          NaN                     NaN
# 7219                          NaN                     NaN
# 7220                          NaN                     NaN
#
#       review_scores_value requires_license  license       jurisdiction_names  \
# 0                    10.0                f      NaN            {"PALO ALTO"}
# 1                     9.0                f      NaN          {"SANTA CLARA"}
# 2                    10.0                f      NaN  {"Mountain View"," CA"}
# 3                    10.0                f      NaN            {"PALO ALTO"}
# 4                     9.0                f      NaN             {"SAN JOSE"}
# ...                   ...              ...      ...                      ...
# 7216                  NaN                f      NaN             {"SAN JOSE"}
# 7217                  NaN                f      NaN          {"SANTA CLARA"}
# 7218                  NaN                f      NaN        {Sunnyvale," CA"}
# 7219                  NaN                f      NaN             {"SAN JOSE"}
# 7220                  NaN                f      NaN             {"SAN JOSE"}
#
#      instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                   f                        f                     moderate
# 1                   f                        f                     moderate
# 2                   f                        f  strict_14_with_grace_period
# 3                   f                        f                     moderate
# 4                   f                        f                     moderate
# ...               ...                      ...                          ...
# 7216                f                        f                     moderate
# 7217                f                        f  strict_14_with_grace_period
# 7218                t                        f                     flexible
# 7219                f                        f                     moderate
# 7220                t                        f  strict_14_with_grace_period
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 0                                f                                f
# 1                                f                                t
# 2                                f                                f
# 3                                f                                f
# 4                                t                                t
# ...                            ...                              ...
# 7216                             f                                f
# 7217                             f                                f
# 7218                             f                                f
# 7219                             f                                f
# 7220                             f                                f
#
#       calculated_host_listings_count  \
# 0                                  5
# 1                                 12
# 2                                  2
# 3                                  5
# 4                                  2
# ...                              ...
# 7216                               2
# 7217                               1
# 7218                               1
# 7219                               1
# 7220                              21
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               0
# 1                                              12
# 2                                               2
# 3                                               0
# 4                                               0
# ...                                           ...
# 7216                                            2
# 7217                                            1
# 7218                                            0
# 7219                                            0
# 7220                                           19
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                5
# 1                                                0
# 2                                                0
# 3                                                5
# 4                                                2
# ...                                            ...
# 7216                                             0
# 7217                                             0
# 7218                                             1
# 7219                                             1
# 7220                                             2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               0.57
# 1                                               0               0.08
# 2                                               0               0.11
# 3                                               0               2.17
# 4                                               0               1.53
# ...                                           ...                ...
# 7216                                            0                NaN
# 7217                                            0                NaN
# 7218                                            0                NaN
# 7219                                            0                NaN
# 7220                                            0                NaN
#
# [7221 rows x 106 columns]

# %%
dup=data.isnull().sum()/data.shape[0]
pd.set_option('display.max_rows', dup.shape[0]+1)


print(dup)
# Out:
# id                                              0.000000
# listing_url                                     0.000000
# scrape_id                                       0.000000
# last_scraped                                    0.000000
# name                                            0.000138
# summary                                         0.041407
# space                                           0.236394
# description                                     0.032959
# experiences_offered                             0.000000
# neighborhood_overview                           0.370724
# notes                                           0.488713
# transit                                         0.427226
# access                                          0.431658
# interaction                                     0.411023
# house_rules                                     0.313530
# thumbnail_url                                   1.000000
# medium_url                                      1.000000
# picture_url                                     0.000000
# xl_picture_url                                  1.000000
# host_id                                         0.000000
# host_url                                        0.000000
# host_name                                       0.000138
# host_since                                      0.000138
# host_location                                   0.003185
# host_about                                      0.323224
# host_response_time                              0.250242
# host_response_rate                              0.250242
# host_acceptance_rate                            0.098878
# host_is_superhost                               0.000138
# host_thumbnail_url                              0.000138
# host_picture_url                                0.000138
# host_neighbourhood                              0.163551
# host_listings_count                             0.000138
# host_total_listings_count                       0.000138
# host_verifications                              0.000000
# host_has_profile_pic                            0.000138
# host_identity_verified                          0.000138
# street                                          0.000000
# neighbourhood                                   0.066888
# neighbourhood_cleansed                          0.000000
# neighbourhood_group_cleansed                    1.000000
# city                                            0.000138
# state                                           0.000138
# zipcode                                         0.007617
# market                                          0.001523
# smart_location                                  0.000000
# country_code                                    0.000000
# country                                         0.000000
# latitude                                        0.000000
# longitude                                       0.000000
# is_location_exact                               0.000000
# property_type                                   0.000000
# room_type                                       0.000000
# accommodates                                    0.000000
# bathrooms                                       0.000138
# bedrooms                                        0.000831
# beds                                            0.009417
# bed_type                                        0.000000
# amenities                                       0.000000
# square_feet                                     0.995984
# price                                           0.000000
# weekly_price                                    0.920510
# monthly_price                                   0.918017
# security_deposit                                0.201773
# cleaning_fee                                    0.110788
# guests_included                                 0.000000
# extra_people                                    0.000000
# minimum_nights                                  0.000000
# maximum_nights                                  0.000000
# minimum_minimum_nights                          0.000000
# maximum_minimum_nights                          0.000000
# minimum_maximum_nights                          0.000000
# maximum_maximum_nights                          0.000000
# minimum_nights_avg_ntm                          0.000000
# maximum_nights_avg_ntm                          0.000000
# calendar_updated                                0.000000
# has_availability                                0.000000
# availability_30                                 0.000000
# availability_60                                 0.000000
# availability_90                                 0.000000
# availability_365                                0.000000
# calendar_last_scraped                           0.000000
# number_of_reviews                               0.000000
# number_of_reviews_ltm                           0.000000
# first_review                                    0.181277
# last_review                                     0.181277
# review_scores_rating                            0.189309
# review_scores_accuracy                          0.189586
# review_scores_cleanliness                       0.189586
# review_scores_checkin                           0.189724
# review_scores_communication                     0.189586
# review_scores_location                          0.189724
# review_scores_value                             0.189724
# requires_license                                0.000000
# license                                         1.000000
# jurisdiction_names                              0.135577
# instant_bookable                                0.000000
# is_business_travel_ready                        0.000000
# cancellation_policy                             0.000000
# require_guest_profile_picture                   0.000000
# require_guest_phone_verification                0.000000
# calculated_host_listings_count                  0.000000
# calculated_host_listings_count_entire_homes     0.000000
# calculated_host_listings_count_private_rooms    0.000000
# calculated_host_listings_count_shared_rooms     0.000000
# reviews_per_month                               0.181277
# dtype: float64

# %%
data.drop(['listing_url','scrape_id','last_scraped','name','summary','space','description','experiences_offered','neighborhood_overview','notes','transit','access','interaction','house_rules','thumbnail_url','medium_url','picture_url','xl_picture_url','host_url','host_name','host_location','host_about','host_response_time','host_thumbnail_url','host_picture_url'], axis = 1)
# Out:
#             id    host_id  host_since host_response_rate host_acceptance_rate  \
# 0         4952       7054  2009-01-24               100%                  98%
# 1        11464      42458  2009-09-30               100%                  90%
# 2        17884      69023  2010-01-08               100%                  50%
# 3        21373       7054  2009-01-24               100%                  98%
# 4        37512     161741  2010-07-09               100%                 100%
# ...        ...        ...         ...                ...                  ...
# 7216  43567384    5974627  2013-04-17               100%                  90%
# 7217  43568844  347799221  2020-05-27                NaN                  NaN
# 7218  43579879  341673005  2020-03-15                NaN                  NaN
# 7219  43580120   31314220  2015-04-15                NaN                  NaN
# 7220  43591340    6202502  2013-05-02               100%                  99%
#
#      host_is_superhost host_neighbourhood  host_listings_count  \
# 0                    t          Palo Alto                  5.0
# 1                    f        Santa Clara                 13.0
# 2                    f          Palo Alto                  2.0
# 3                    t          Palo Alto                  5.0
# 4                    t     South San Jose                  2.0
# ...                ...                ...                  ...
# 7216                 t        Naglee Park                  2.0
# 7217                 f                NaN                  1.0
# 7218                 f              Snail                  0.0
# 7219                 f          Rose Glen                  0.0
# 7220                 f      Mountain View                 71.0
#
#       host_total_listings_count  \
# 0                           5.0
# 1                          13.0
# 2                           2.0
# 3                           5.0
# 4                           2.0
# ...                         ...
# 7216                        2.0
# 7217                        1.0
# 7218                        0.0
# 7219                        0.0
# 7220                       71.0
#
#                                      host_verifications host_has_profile_pic  \
# 0     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1                         ['email', 'phone', 'reviews']                    t
# 2                  ['email', 'phone', 'reviews', 'kba']                    t
# 3     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 4     ['email', 'phone', 'facebook', 'reviews', 'man...                    t
# ...                                                 ...                  ...
# 7216  ['email', 'phone', 'reviews', 'offline_governm...                    t
# 7217                   ['email', 'phone', 'work_email']                    t
# 7218  ['phone', 'offline_government_id', 'selfie', '...                    t
# 7219  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 7220  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#      host_identity_verified                            street  \
# 0                         f      Palo Alto, CA, United States
# 1                         f    Santa Clara, CA, United States
# 2                         t  Mountain View, CA, United States
# 3                         f      Palo Alto, CA, United States
# 4                         t       San Jose, CA, United States
# ...                     ...                               ...
# 7216                      t       San Jose, CA, United States
# 7217                      f    Santa Clara, CA, United States
# 7218                      f      Sunnyvale, CA, United States
# 7219                      t       San Jose, CA, United States
# 7220                      f       San Jose, CA, United States
#
#           neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed  \
# 0             Palo Alto              Palo Alto                           NaN
# 1           Santa Clara            Santa Clara                           NaN
# 2         Mountain View          Mountain View                           NaN
# 3             Palo Alto              Palo Alto                           NaN
# 4        South San Jose               San Jose                           NaN
# ...                 ...                    ...                           ...
# 7216        Naglee Park               San Jose                           NaN
# 7217        Santa Clara            Santa Clara                           NaN
# 7218          Sunnyvale              Sunnyvale                           NaN
# 7219  Burbank/Del Monte               San Jose                           NaN
# 7220   Cambrian/Pioneer               San Jose                           NaN
#
#                city state zipcode         market     smart_location  \
# 0         Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA
# 1       Santa Clara    CA   95051  South Bay, CA    Santa Clara, CA
# 2     Mountain View    CA   94041  South Bay, CA  Mountain View, CA
# 3         Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA
# 4          San Jose    CA   95111  South Bay, CA       San Jose, CA
# ...             ...   ...     ...            ...                ...
# 7216       San Jose    CA   95112   South Bay CA       San Jose, CA
# 7217    Santa Clara    CA   95051   South Bay CA    Santa Clara, CA
# 7218      Sunnyvale    CA   94085   South Bay CA      Sunnyvale, CA
# 7219       San Jose    CA   95128   South Bay CA       San Jose, CA
# 7220       San Jose    CA   95118   South Bay CA       San Jose, CA
#
#      country_code        country  latitude  longitude is_location_exact  \
# 0              US  United States  37.43972 -122.15672                 t
# 1              US  United States  37.34342 -121.98829                 t
# 2              US  United States  37.38612 -122.07357                 t
# 3              US  United States  37.44001 -122.15667                 t
# 4              US  United States  37.30598 -121.84036                 t
# ...           ...            ...       ...        ...               ...
# 7216           US  United States  37.33794 -121.87189                 t
# 7217           US  United States  37.35473 -121.99940                 t
# 7218           US  United States  37.39309 -122.02541                 t
# 7219           US  United States  37.31209 -121.92103                 t
# 7220           US  United States  37.24502 -121.87745                 t
#
#      property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0            Villa     Private room             2        2.0       1.0   1.0
# 1        Apartment  Entire home/apt             1        1.0       NaN   1.0
# 2      Guest suite  Entire home/apt             2        1.0       1.0   1.0
# 3            Villa     Private room             1        2.0       1.0   1.0
# 4         Bungalow     Private room             2        1.0       1.0   1.0
# ...            ...              ...           ...        ...       ...   ...
# 7216   Guest suite  Entire home/apt             1        1.0       0.0   1.0
# 7217   Condominium  Entire home/apt             4        1.0       1.0   2.0
# 7218         House     Private room             1        1.0       1.0   1.0
# 7219         House     Private room             1        1.0       1.0   1.0
# 7220     Apartment  Entire home/apt             4        1.0       2.0   2.0
#
#       bed_type                                          amenities  \
# 0     Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...
# 1     Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 2     Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 3     Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...
# 4     Real Bed  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...
# ...        ...                                                ...
# 7216  Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,"Free par...
# 7217  Real Bed  {TV,"Cable TV",Wifi,"Air conditioning",Pool,Ki...
# 7218  Real Bed  {TV,Wifi,Kitchen,"Free parking on premises",Wa...
# 7219  Real Bed  {TV,Wifi,"Air conditioning",Kitchen,"Free park...
# 7220  Real Bed  {TV,Wifi,"Air conditioning",Kitchen,"Free park...
#
#       square_feet    price weekly_price monthly_price security_deposit  \
# 0             NaN   $90.00      $440.00     $1,428.00            $0.00
# 1           325.0   $85.00          NaN     $2,100.00          $700.00
# 2             NaN   $65.00    $1,400.00     $2,800.00        $1,000.00
# 3             NaN   $99.00      $600.00     $2,000.00            $0.00
# 4             NaN   $52.00      $393.00     $1,386.00              NaN
# ...           ...      ...          ...           ...              ...
# 7216          NaN   $49.00          NaN           NaN          $500.00
# 7217          NaN  $135.00          NaN           NaN          $500.00
# 7218          NaN   $85.00          NaN           NaN            $0.00
# 7219          NaN   $49.00          NaN           NaN        $1,000.00
# 7220          NaN  $145.00          NaN           NaN          $400.00
#
#      cleaning_fee  guests_included extra_people  minimum_nights  \
# 0          $35.00                1       $45.00               2
# 1         $250.00                1       $10.00              14
# 2             NaN                1        $0.00              30
# 3          $35.00                1       $50.00               2
# 4             NaN                1        $0.00               1
# ...           ...              ...          ...             ...
# 7216      $100.00                1       $50.00               3
# 7217      $135.00                2       $20.00              30
# 7218      $150.00                1       $25.00              30
# 7219      $150.00                1       $10.00              14
# 7220       $90.00                1        $0.00               1
#
#       maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0                365                       2                       2
# 1                365                      14                      14
# 2                180                      30                      30
# 3                730                       2                       2
# 4                  7                       1                       1
# ...              ...                     ...                     ...
# 7216            1125                       3                       3
# 7217            1125                      30                      30
# 7218            1125                      30                      30
# 7219             365                      14                      14
# 7220            1125                       1                       1
#
#       minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                        365                     365                     2.0
# 1                        365                     365                    14.0
# 2                        180                     180                    30.0
# 3                        730                     730                     2.0
# 4                          7                       7                     1.0
# ...                      ...                     ...                     ...
# 7216                    1125                    1125                     3.0
# 7217                    1125                    1125                    30.0
# 7218                    1125                    1125                    30.0
# 7219                    1125                    1125                    14.0
# 7220                    1125                    1125                     1.0
#
#       maximum_nights_avg_ntm calendar_updated has_availability  \
# 0                      365.0     2 months ago                t
# 1                      365.0     5 months ago                t
# 2                      180.0      4 weeks ago                t
# 3                      730.0      3 weeks ago                t
# 4                        7.0    23 months ago                t
# ...                      ...              ...              ...
# 7216                  1125.0       3 days ago                t
# 7217                  1125.0       3 days ago                t
# 7218                  1125.0       2 days ago                t
# 7219                  1125.0       2 days ago                t
# 7220                  1125.0            never                t
#
#       availability_30  availability_60  availability_90  availability_365  \
# 0                   0                0                0                 0
# 1                  30               60               90               179
# 2                  29               59               89               179
# 3                   0                0                0               212
# 4                   0                0               28               303
# ...               ...              ...              ...               ...
# 7216               29               30               30                30
# 7217               25               55               85               360
# 7218               14               44               46                46
# 7219               30               60               90               180
# 7220               25               55               85               360
#
#      calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# 0               2020-05-30                 75                      0
# 1               2020-05-31                  6                      1
# 2               2020-05-31                  2                      0
# 3               2020-05-30                264                     39
# 4               2020-05-31                183                      0
# ...                    ...                ...                    ...
# 7216            2020-05-31                  0                      0
# 7217            2020-05-31                  0                      0
# 7218            2020-05-31                  0                      0
# 7219            2020-05-30                  0                      0
# 7220            2020-05-31                  0                      0
#
#      first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0      2009-08-02  2019-01-12                  96.0                    10.0
# 1      2014-06-15  2019-10-11                  87.0                    10.0
# 2      2018-11-20  2019-04-27                  90.0                     8.0
# 3      2010-05-28  2020-03-14                  97.0                    10.0
# 4      2010-08-01  2017-03-14                  94.0                     9.0
# ...           ...         ...                   ...                     ...
# 7216          NaN         NaN                   NaN                     NaN
# 7217          NaN         NaN                   NaN                     NaN
# 7218          NaN         NaN                   NaN                     NaN
# 7219          NaN         NaN                   NaN                     NaN
# 7220          NaN         NaN                   NaN                     NaN
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                          10.0                   10.0
# 1                          10.0                   10.0
# 2                          10.0                   10.0
# 3                          10.0                   10.0
# 4                          10.0                   10.0
# ...                         ...                    ...
# 7216                        NaN                    NaN
# 7217                        NaN                    NaN
# 7218                        NaN                    NaN
# 7219                        NaN                    NaN
# 7220                        NaN                    NaN
#
#       review_scores_communication  review_scores_location  \
# 0                            10.0                    10.0
# 1                             9.0                     9.0
# 2                            10.0                    10.0
# 3                            10.0                    10.0
# 4                            10.0                     9.0
# ...                           ...                     ...
# 7216                          NaN                     NaN
# 7217                          NaN                     NaN
# 7218                          NaN                     NaN
# 7219                          NaN                     NaN
# 7220                          NaN                     NaN
#
#       review_scores_value requires_license  license       jurisdiction_names  \
# 0                    10.0                f      NaN            {"PALO ALTO"}
# 1                     9.0                f      NaN          {"SANTA CLARA"}
# 2                    10.0                f      NaN  {"Mountain View"," CA"}
# 3                    10.0                f      NaN            {"PALO ALTO"}
# 4                     9.0                f      NaN             {"SAN JOSE"}
# ...                   ...              ...      ...                      ...
# 7216                  NaN                f      NaN             {"SAN JOSE"}
# 7217                  NaN                f      NaN          {"SANTA CLARA"}
# 7218                  NaN                f      NaN        {Sunnyvale," CA"}
# 7219                  NaN                f      NaN             {"SAN JOSE"}
# 7220                  NaN                f      NaN             {"SAN JOSE"}
#
#      instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                   f                        f                     moderate
# 1                   f                        f                     moderate
# 2                   f                        f  strict_14_with_grace_period
# 3                   f                        f                     moderate
# 4                   f                        f                     moderate
# ...               ...                      ...                          ...
# 7216                f                        f                     moderate
# 7217                f                        f  strict_14_with_grace_period
# 7218                t                        f                     flexible
# 7219                f                        f                     moderate
# 7220                t                        f  strict_14_with_grace_period
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 0                                f                                f
# 1                                f                                t
# 2                                f                                f
# 3                                f                                f
# 4                                t                                t
# ...                            ...                              ...
# 7216                             f                                f
# 7217                             f                                f
# 7218                             f                                f
# 7219                             f                                f
# 7220                             f                                f
#
#       calculated_host_listings_count  \
# 0                                  5
# 1                                 12
# 2                                  2
# 3                                  5
# 4                                  2
# ...                              ...
# 7216                               2
# 7217                               1
# 7218                               1
# 7219                               1
# 7220                              21
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               0
# 1                                              12
# 2                                               2
# 3                                               0
# 4                                               0
# ...                                           ...
# 7216                                            2
# 7217                                            1
# 7218                                            0
# 7219                                            0
# 7220                                           19
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                5
# 1                                                0
# 2                                                0
# 3                                                5
# 4                                                2
# ...                                            ...
# 7216                                             0
# 7217                                             0
# 7218                                             1
# 7219                                             1
# 7220                                             2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               0.57
# 1                                               0               0.08
# 2                                               0               0.11
# 3                                               0               2.17
# 4                                               0               1.53
# ...                                           ...                ...
# 7216                                            0                NaN
# 7217                                            0                NaN
# 7218                                            0                NaN
# 7219                                            0                NaN
# 7220                                            0                NaN
#
# [7221 rows x 81 columns]

# %%
thresh = len(data)*0.6
data1 = data.dropna(thresh=thresh,axis=1)
dedup=data1.isnull().sum()/data1.shape[0]
dedup = dedup.sort_values(0)
print(dedup)
# Out:
# id                                              0.000000
# minimum_nights_avg_ntm                          0.000000
# maximum_maximum_nights                          0.000000
# street                                          0.000000
# minimum_maximum_nights                          0.000000
# neighbourhood_cleansed                          0.000000
# maximum_minimum_nights                          0.000000
# minimum_minimum_nights                          0.000000
# maximum_nights                                  0.000000
# minimum_nights                                  0.000000
# smart_location                                  0.000000
# host_verifications                              0.000000
# country_code                                    0.000000
# latitude                                        0.000000
# longitude                                       0.000000
# is_location_exact                               0.000000
# property_type                                   0.000000
# room_type                                       0.000000
# accommodates                                    0.000000
# calculated_host_listings_count_shared_rooms     0.000000
# extra_people                                    0.000000
# guests_included                                 0.000000
# bed_type                                        0.000000
# country                                         0.000000
# maximum_nights_avg_ntm                          0.000000
# calendar_updated                                0.000000
# has_availability                                0.000000
# listing_url                                     0.000000
# scrape_id                                       0.000000
# last_scraped                                    0.000000
# calculated_host_listings_count_private_rooms    0.000000
# calculated_host_listings_count_entire_homes     0.000000
# calculated_host_listings_count                  0.000000
# require_guest_phone_verification                0.000000
# experiences_offered                             0.000000
# require_guest_profile_picture                   0.000000
# cancellation_policy                             0.000000
# picture_url                                     0.000000
# host_id                                         0.000000
# host_url                                        0.000000
# is_business_travel_ready                        0.000000
# instant_bookable                                0.000000
# requires_license                                0.000000
# number_of_reviews_ltm                           0.000000
# number_of_reviews                               0.000000
# calendar_last_scraped                           0.000000
# availability_365                                0.000000
# availability_90                                 0.000000
# availability_60                                 0.000000
# availability_30                                 0.000000
# amenities                                       0.000000
# price                                           0.000000
# bathrooms                                       0.000138
# host_listings_count                             0.000138
# host_since                                      0.000138
# host_name                                       0.000138
# state                                           0.000138
# city                                            0.000138
# name                                            0.000138
# host_identity_verified                          0.000138
# host_has_profile_pic                            0.000138
# host_total_listings_count                       0.000138
# host_is_superhost                               0.000138
# host_thumbnail_url                              0.000138
# host_picture_url                                0.000138
# bedrooms                                        0.000831
# market                                          0.001523
# host_location                                   0.003185
# zipcode                                         0.007617
# beds                                            0.009417
# description                                     0.032959
# summary                                         0.041407
# neighbourhood                                   0.066888
# host_acceptance_rate                            0.098878
# cleaning_fee                                    0.110788
# jurisdiction_names                              0.135577
# host_neighbourhood                              0.163551
# first_review                                    0.181277
# last_review                                     0.181277
# reviews_per_month                               0.181277
# review_scores_rating                            0.189309
# review_scores_communication                     0.189586
# review_scores_accuracy                          0.189586
# review_scores_cleanliness                       0.189586
# review_scores_checkin                           0.189724
# review_scores_location                          0.189724
# review_scores_value                             0.189724
# security_deposit                                0.201773
# space                                           0.236394
# host_response_time                              0.250242
# host_response_rate                              0.250242
# house_rules                                     0.313530
# host_about                                      0.323224
# neighborhood_overview                           0.370724
# dtype: float64
# /var/folders/bz/8yf5rf0s1yzd3gl6nw6xvclw0000gn/T/ipykernel_4078/3183320570.py:4: FutureWarning: In a future version of pandas all arguments of Series.sort_values will be keyword-only.
#   dedup = dedup.sort_values(0)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7221 entries, 0 to 7220
# Data columns (total 94 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7221 non-null   int64
#  1   listing_url                                   7221 non-null   object
#  2   scrape_id                                     7221 non-null   int64
#  3   last_scraped                                  7221 non-null   object
#  4   name                                          7220 non-null   object
#  5   summary                                       6922 non-null   object
#  6   space                                         5514 non-null   object
#  7   description                                   6983 non-null   object
#  8   experiences_offered                           7221 non-null   object
#  9   neighborhood_overview                         4544 non-null   object
#  10  house_rules                                   4957 non-null   object
#  11  picture_url                                   7221 non-null   object
#  12  host_id                                       7221 non-null   int64
#  13  host_url                                      7221 non-null   object
#  14  host_name                                     7220 non-null   object
#  15  host_since                                    7220 non-null   object
#  16  host_location                                 7198 non-null   object
#  17  host_about                                    4887 non-null   object
#  18  host_response_time                            5414 non-null   object
#  19  host_response_rate                            5414 non-null   object
#  20  host_acceptance_rate                          6507 non-null   object
#  21  host_is_superhost                             7220 non-null   object
#  22  host_thumbnail_url                            7220 non-null   object
#  23  host_picture_url                              7220 non-null   object
#  24  host_neighbourhood                            6040 non-null   object
#  25  host_listings_count                           7220 non-null   float64
#  26  host_total_listings_count                     7220 non-null   float64
#  27  host_verifications                            7221 non-null   object
#  28  host_has_profile_pic                          7220 non-null   object
#  29  host_identity_verified                        7220 non-null   object
#  30  street                                        7221 non-null   object
#  31  neighbourhood                                 6738 non-null   object
#  32  neighbourhood_cleansed                        7221 non-null   object
#  33  city                                          7220 non-null   object
#  34  state                                         7220 non-null   object
#  35  zipcode                                       7166 non-null   object
#  36  market                                        7210 non-null   object
#  37  smart_location                                7221 non-null   object
#  38  country_code                                  7221 non-null   object
#  39  country                                       7221 non-null   object
#  40  latitude                                      7221 non-null   float64
#  41  longitude                                     7221 non-null   float64
#  42  is_location_exact                             7221 non-null   object
#  43  property_type                                 7221 non-null   object
#  44  room_type                                     7221 non-null   object
#  45  accommodates                                  7221 non-null   int64
#  46  bathrooms                                     7220 non-null   float64
#  47  bedrooms                                      7215 non-null   float64
#  48  beds                                          7153 non-null   float64
#  49  bed_type                                      7221 non-null   object
#  50  amenities                                     7221 non-null   object
#  51  price                                         7221 non-null   object
#  52  security_deposit                              5764 non-null   object
#  53  cleaning_fee                                  6421 non-null   object
#  54  guests_included                               7221 non-null   int64
#  55  extra_people                                  7221 non-null   object
#  56  minimum_nights                                7221 non-null   int64
#  57  maximum_nights                                7221 non-null   int64
#  58  minimum_minimum_nights                        7221 non-null   int64
#  59  maximum_minimum_nights                        7221 non-null   int64
#  60  minimum_maximum_nights                        7221 non-null   int64
#  61  maximum_maximum_nights                        7221 non-null   int64
#  62  minimum_nights_avg_ntm                        7221 non-null   float64
#  63  maximum_nights_avg_ntm                        7221 non-null   float64
#  64  calendar_updated                              7221 non-null   object
#  65  has_availability                              7221 non-null   object
#  66  availability_30                               7221 non-null   int64
#  67  availability_60                               7221 non-null   int64
#  68  availability_90                               7221 non-null   int64
#  69  availability_365                              7221 non-null   int64
#  70  calendar_last_scraped                         7221 non-null   object
#  71  number_of_reviews                             7221 non-null   int64
#  72  number_of_reviews_ltm                         7221 non-null   int64
#  73  first_review                                  5912 non-null   object
#  74  last_review                                   5912 non-null   object
#  75  review_scores_rating                          5854 non-null   float64
#  76  review_scores_accuracy                        5852 non-null   float64
#  77  review_scores_cleanliness                     5852 non-null   float64
#  78  review_scores_checkin                         5851 non-null   float64
#  79  review_scores_communication                   5852 non-null   float64
#  80  review_scores_location                        5851 non-null   float64
#  81  review_scores_value                           5851 non-null   float64
#  82  requires_license                              7221 non-null   object
#  83  jurisdiction_names                            6242 non-null   object
#  84  instant_bookable                              7221 non-null   object
#  85  is_business_travel_ready                      7221 non-null   object
#  86  cancellation_policy                           7221 non-null   object
#  87  require_guest_profile_picture                 7221 non-null   object
#  88  require_guest_phone_verification              7221 non-null   object
#  89  calculated_host_listings_count                7221 non-null   int64
#  90  calculated_host_listings_count_entire_homes   7221 non-null   int64
#  91  calculated_host_listings_count_private_rooms  7221 non-null   int64
#  92  calculated_host_listings_count_shared_rooms   7221 non-null   int64
#  93  reviews_per_month                             5912 non-null   float64
# dtypes: float64(17), int64(21), object(56)
# memory usage: 5.2+ MB

# %%
#data1.hist('price')

data1.price = data1.price.apply(lambda x:str(x).replace('$', '').strip())
data1.price.value_counts()
# Out:
# /var/folders/bz/8yf5rf0s1yzd3gl6nw6xvclw0000gn/T/ipykernel_4078/4285832369.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.price = data1.price.apply(lambda x:str(x).replace('$', '').strip())
# 100.00      205
# 50.00       199
# 75.00       188
# 60.00       183
# 55.00       183
#            ...
# 780.00        1
# 330.00        1
# 1,150.00      1
# 379.00        1
# 545.00        1
# Name: price, Length: 420, dtype: int64

# %%
data1.price = pd.to_numeric(data1.price,errors='coerce')
# Out:
# /var/folders/bz/8yf5rf0s1yzd3gl6nw6xvclw0000gn/T/ipykernel_4078/699166946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.price = pd.to_numeric(data1.price,errors='coerce')

# %%
data1.neighbourhood_cleansed.value_counts()
# Out:
# San Jose                2882
# Palo Alto                794
# Sunnyvale                768
# Santa Clara              711
# Mountain View            664
# Cupertino                325
# Milpitas                 301
# Unincorporated Areas     298
# Campbell                 131
# Los Gatos                 85
# Los Altos                 73
# Saratoga                  62
# Los Altos Hills           52
# Morgan Hill               42
# Gilroy                    20
# Monte Sereno              13
# Name: neighbourhood_cleansed, dtype: int64

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x="neighbourhood_cleansed", y="price", data=data1)
# Out:
# <AxesSubplot:xlabel='neighbourhood_cleansed', ylabel='price'>

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x="bedrooms", y="price", data=data1)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x="room_type", y="price", data=data1)
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='price'>

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(x="longitude", y="latitude",
            hue="price", size="price",data=data1)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
plt.figure(figsize=(10,10))
sns.distplot(data1['price'], fit=norm)
plt.title("Price Distribution Plot")
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/envs/p39/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Price Distribution Plot')

# %% [markdown]
# right-skewed distribution on price.  positive skewness
# Log transformation will be used

# %%
data1['price_log'] = np.log(data1.price+1)
# Out:
# /var/folders/bz/8yf5rf0s1yzd3gl6nw6xvclw0000gn/T/ipykernel_4078/1443486062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['price_log'] = np.log(data1.price+1)

# %%
plt.figure(figsize=(12,10))
sns.distplot(data1['price_log'], fit=norm)
plt.title("Log-Price Distribution Plot")
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/envs/p39/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Log-Price Distribution Plot')

# %%
plt.figure(figsize=(7,7))
stats.probplot(data1['price_log'], plot=plt)
plt.show()

# %%
dfprice = data1[['neighbourhood_cleansed', 'price','price_log','bedrooms','room_type','longitude', 'latitude','accommodates','bathrooms']]

# %%
dfprice
# Out:
#      neighbourhood_cleansed  price  price_log  bedrooms        room_type  \
# 0                 Palo Alto   90.0   4.510860       1.0     Private room
# 1               Santa Clara   85.0   4.454347       NaN  Entire home/apt
# 2             Mountain View   65.0   4.189655       1.0  Entire home/apt
# 3                 Palo Alto   99.0   4.605170       1.0     Private room
# 4                  San Jose   52.0   3.970292       1.0     Private room
# ...                     ...    ...        ...       ...              ...
# 7216               San Jose   49.0   3.912023       0.0  Entire home/apt
# 7217            Santa Clara  135.0   4.912655       1.0  Entire home/apt
# 7218              Sunnyvale   85.0   4.454347       1.0     Private room
# 7219               San Jose   49.0   3.912023       1.0     Private room
# 7220               San Jose  145.0   4.983607       2.0  Entire home/apt
#
#       longitude  latitude  accommodates  bathrooms
# 0    -122.15672  37.43972             2        2.0
# 1    -121.98829  37.34342             1        1.0
# 2    -122.07357  37.38612             2        1.0
# 3    -122.15667  37.44001             1        2.0
# 4    -121.84036  37.30598             2        1.0
# ...         ...       ...           ...        ...
# 7216 -121.87189  37.33794             1        1.0
# 7217 -121.99940  37.35473             4        1.0
# 7218 -122.02541  37.39309             1        1.0
# 7219 -121.92103  37.31209             1        1.0
# 7220 -121.87745  37.24502             4        1.0
#
# [7221 rows x 9 columns]

# %%
dfprice['room_type'].value_counts()
# Out:
# Private room       3454
# Entire home/apt    3431
# Shared room         334
# Hotel room            2
# Name: room_type, dtype: int64

# %%
    minimum=min(dfprice_encoded['price_log'])
    maximum=max(dfprice_encoded['price_log'])
    dfprice_encoded['price_log'] = (dfprice_encoded['price_log']-minimum)/(maximum-minimum)
    dfprice_encoded
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sagawithme/Documents/Github/Machine-Learning-Notes/project_bnb-kgl/airbnb project_JG.ipynb Cell 25' in <module>
# ----> <a href='vscode-notebook-cell:/Users/sagawithme/Documents/Github/Machine-Learning-Notes/project_bnb-kgl/airbnb%20project_JG.ipynb#ch0000024?line=0'>1</a> minimum=min(dfprice_encoded['price_log'])
#       <a href='vscode-notebook-cell:/Users/sagawithme/Documents/Github/Machine-Learning-Notes/project_bnb-kgl/airbnb%20project_JG.ipynb#ch0000024?line=1'>2</a> maximum=max(dfprice_encoded['price_log'])
#       <a href='vscode-notebook-cell:/Users/sagawithme/Documents/Github/Machine-Learning-Notes/project_bnb-kgl/airbnb%20project_JG.ipynb#ch0000024?line=2'>3</a> dfprice_encoded['price_log'] = (dfprice_encoded['price_log']-minimum)/(maximum-minimum)
#
# NameError: name 'dfprice_encoded' is not defined

# %%
dfprice_encoded = pd.get_dummies(dfprice,columns=['neighbourhood_cleansed','room_type'])
dfprice_encoded.head()

# %%
dup=dfprice_encoded.isnull().sum()/dfprice_encoded.shape[0]
pd.set_option('display.max_rows', dup.shape[0]+1)


print(dup)

# %%
dfprice_encoded.loc[(dfprice_encoded['bedrooms']==''),'bedrooms'] = 0

# %%
dup=dfprice_encoded.isnull().sum()/dfprice_encoded.shape[0]
pd.set_option('display.max_rows', dup.shape[0]+1)


print(dup)

# %%
dfprice_encoded.dtypes

# %%
fig, ax = plt.subplots(ncols=5, nrows=5, figsize=(30,30))
index=0
ax=ax.flatten()
for col, value in dfprice_encoded.items():
    sns.boxplot(y=col, data=dfprice_encoded, ax = ax[index])
    index +=1

# %%
fig, ax = plt.subplots(ncols=5, nrows=5, figsize=(30,30))
index=0
ax=ax.flatten()
for col, value in dfprice_encoded.items():
    sns.displot(value, ax = ax[index])
    index +=1

# %%
plt.figure(figsize=(15,12))
palette = sns.diverging_palette(20, 220, n=256)
corr=dfprice_encoded.corr(method='pearson')
sns.heatmap(corr, annot=True, fmt=".2f", cmap=palette, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}).set(ylim=(25, 0))
plt.title("Correlation Matrix",size=15, weight='bold')

# %%
dfprice_encoded.drop(['longitude','latitude'], axis = 1)

# %%
dfprice_encoded.isnull().sum()
dfprice_encoded.dropna(how='any',inplace=True)
dfprice_encoded.info() 
dup=dfprice_encoded.isnull().sum()/dfprice_encoded.shape[0]
pd.set_option('display.max_rows', dup.shape[0]+1)

dfprice_encoded

# %%
#X=dfprice_encoded.drop(columns=['price','price_log','latitude','longitude'])
X=dfprice_encoded[['bedrooms','accommodates','bathrooms','neighbourhood_cleansed_Palo Alto','neighbourhood_cleansed_San Jose','neighbourhood_cleansed_Mountain View','room_type_Entire home/apt','room_type_Private room']]
y=dfprice_encoded['price_log']

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
def train(model,X,y):
    x_train, x_test, y_train, y_test=train_test_split(X,y,random_state=42)
    model.fit(x_train,y_train)
    pred=model.predict(x_test)
    cv_score=cross_val_score(model,X,y,scoring='neg_mean_squared_error',cv=5)
    cv_score=np.abs(np.mean(cv_score))
    
    print("Model Report")
    print("MSE",mean_squared_error(y_test,pred))
    print('CV Score', cv_score)
    y_pred = model.predict(x_test)
    plt.scatter(y_test,y_pred,color='red')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(normalize=True)
train(model,X,y)
#coef = pd.Series(model.coef_, X.columns).sort_values()
#coef.plot(kind='bar',title='Model Coefficients')
coef
#y_pred = model.predict(x_test)
