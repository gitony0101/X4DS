# %% [markdown]
# <a href="https://colab.research.google.com/github/johnfcchan/crackdatescience/blob/master/Prediction_on_Kaggle_AirBnB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1 Import Libs

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 99)

# %% [markdown]
# #2 Load Datasets

# %%
data_dir = 'airbnb'
fnames = ['Airbnb_Listings.csv', 'neighbourhoods.csv', 'reviews.csv']
fname = fnames[0]
dfs = []

for fname in fnames:
    dfs.append(
        pd.read_csv(os.path.join(
            "../project_bnb-kgl",
            data_dir, fname),
                    index_col=0))
dfs[0].head()
# Out:
#                               listing_url       scrape_id last_scraped  \
# id
# 4952    https://www.airbnb.com/rooms/4952  20200530151957   2020-05-30
# 11464  https://www.airbnb.com/rooms/11464  20200530151957   2020-05-31
# 17884  https://www.airbnb.com/rooms/17884  20200530151957   2020-05-31
# 21373  https://www.airbnb.com/rooms/21373  20200530151957   2020-05-30
# 37512  https://www.airbnb.com/rooms/37512  20200530151957   2020-05-31
#
#                                       name  \
# id
# 4952     Butterfly Inn - Graceful Living !
# 11464    Deluxe Private Studio-custom int.
# 17884                 Silicon Valley Suite
# 21373  Bonsai Garden Inn in Professorville
# 37512    Private  room - Parking 3 carport
#
#                                                  summary  \
# id
# 4952   Lovely garden setting in a serene and art-fill...
# 11464  Custom built Studio with exquisite design. Rea...
# 17884  A guest suite for one or two, in a house in a ...
# 21373  Room  in gracious home with beautiful garden. ...
# 37512  We live in a safe community close to public tr...
#
#                                                    space  \
# id
# 4952   Very comfortable Queen bed and small desk in b...
# 11464  Description A favorite for international corpo...
# 17884  This is a private suite at the rear of a house...
# 21373  Bright, garden-facing room in beautiful home. ...
# 37512  I have a really nice room in a quiet neighborh...
#
#                                              description experiences_offered  \
# id
# 4952   Lovely garden setting in a serene and art-fill...                none
# 11464  Custom built Studio with exquisite design. Rea...                none
# 17884  A guest suite for one or two, in a house in a ...                none
# 21373  Room  in gracious home with beautiful garden. ...                none
# 37512  We live in a safe community close to public tr...                none
#
#                                    neighborhood_overview  \
# id
# 4952   Located in Professorville, Palo Alto, one of t...
# 11464  10 min. to Lucky's and Starbucks at El Camino ...
# 17884  This is a very quiet family neighborhood, but ...
# 21373  This room is in an ultra convenient location i...
# 37512  Our community is a safe environment and at nig...
#
#                                                    notes  \
# id
# 4952   Housekeeping every Monday, leave your door ope...
# 11464  Pet Policy: - Well Behaved pet up to 25 lb. of...
# 17884  I cannot accommodate cats, sorry. I can usuall...
# 21373  The family room has a flat panel tv and desk f...
# 37512  Please remember that you are in my home and re...
#
#                                                  transit  \
# id
# 4952   Walking distance to Stanford University (30 mi...
# 11464  Public transportation at Homestead and Pomeroy...
# 17884  The CalTrain station is in walking distance, a...
# 21373  The Stanford Shopping Center is 20 minutes wal...
# 37512  We have a bus stop right outside our community...
#
#                                                   access  \
# id
# 4952   Kitchen, laundry, family/TV room, garden, free...
# 11464          Complimentary Wifi-internet + Basic Cable
# 17884  Private outdoor patio. Shared washer/dryer on ...
# 21373  Kitchen, Laundry, Garden, Family Room with TV,...
# 37512  The kitchen and all that it offers.  The laund...
#
#                                              interaction  \
# id
# 4952   Welcome and Orientation. Shared kitchen, garde...
# 11464  Available any time for support and problem res...
# 17884  I am usually in town.  Guests have a private e...
# 21373  We will see you everyday as we cook meals in t...
# 37512  We follow our guests lead when it comes to soc...
#
#                                              house_rules  thumbnail_url  \
# id
# 4952   No shoes in the house beyond the hall or laund...            NaN
# 11464  Can house a couple- bed type is a full size be...            NaN
# 17884  This is a quiet neighborhood, and the suite sh...            NaN
# 21373  No shoes in the house beyond hall or laundry. ...            NaN
# 37512  No drunk and disorderly conduct please.  You m...            NaN
#
#        medium_url                                        picture_url  \
# id
# 4952          NaN  https://a0.muscache.com/im/pictures/529448/3d7...
# 11464         NaN  https://a0.muscache.com/im/pictures/121321/2c5...
# 17884         NaN  https://a0.muscache.com/im/pictures/08c0f0aa-3...
# 21373         NaN  https://a0.muscache.com/im/pictures/527285/0f9...
# 37512         NaN  https://a0.muscache.com/im/pictures/47698055/3...
#
#        xl_picture_url  host_id                                  host_url  \
# id
# 4952              NaN     7054    https://www.airbnb.com/users/show/7054
# 11464             NaN    42458   https://www.airbnb.com/users/show/42458
# 17884             NaN    69023   https://www.airbnb.com/users/show/69023
# 21373             NaN     7054    https://www.airbnb.com/users/show/7054
# 37512             NaN   161741  https://www.airbnb.com/users/show/161741
#
#       host_name  host_since                             host_location  \
# id
# 4952    Mei Lin  2009-01-24      Palo Alto, California, United States
# 11464      Emey  2009-09-30  Mountain View, California, United States
# 17884     Janet  2010-01-08        Lynn Haven, Florida, United States
# 21373   Mei Lin  2009-01-24      Palo Alto, California, United States
# 37512     Maria  2010-07-09       San Jose, California, United States
#
#                                               host_about  host_response_time  \
# id
# 4952   I have lived and worked in Asia, Europe, Austr...      within an hour
# 11464  I pride myself on attention to details and cus...      within an hour
# 17884  I am a software engineer, recently retired fro...        within a day
# 21373  I have lived and worked in Asia, Europe, Austr...      within an hour
# 37512   I am in a committed relationship with my live...  within a few hours
#
#       host_response_rate host_acceptance_rate host_is_superhost  \
# id
# 4952                100%                  98%                 t
# 11464               100%                  90%                 f
# 17884               100%                  50%                 f
# 21373               100%                  98%                 t
# 37512               100%                 100%                 t
#
#                                       host_thumbnail_url  \
# id
# 4952   https://a0.muscache.com/im/users/7054/profile_...
# 11464  https://a0.muscache.com/im/users/42458/profile...
# 17884  https://a0.muscache.com/im/users/69023/profile...
# 21373  https://a0.muscache.com/im/users/7054/profile_...
# 37512  https://a0.muscache.com/im/users/161741/profil...
#
#                                         host_picture_url host_neighbourhood  \
# id
# 4952   https://a0.muscache.com/im/users/7054/profile_...          Palo Alto
# 11464  https://a0.muscache.com/im/users/42458/profile...        Santa Clara
# 17884  https://a0.muscache.com/im/users/69023/profile...          Palo Alto
# 21373  https://a0.muscache.com/im/users/7054/profile_...          Palo Alto
# 37512  https://a0.muscache.com/im/users/161741/profil...     South San Jose
#
#        host_listings_count  host_total_listings_count  \
# id
# 4952                   5.0                        5.0
# 11464                 13.0                       13.0
# 17884                  2.0                        2.0
# 21373                  5.0                        5.0
# 37512                  2.0                        2.0
#
#                                       host_verifications host_has_profile_pic  \
# id
# 4952   ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 11464                      ['email', 'phone', 'reviews']                    t
# 17884               ['email', 'phone', 'reviews', 'kba']                    t
# 21373  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 37512  ['email', 'phone', 'facebook', 'reviews', 'man...                    t
#
#       host_identity_verified                            street  \
# id
# 4952                       f      Palo Alto, CA, United States
# 11464                      f    Santa Clara, CA, United States
# 17884                      t  Mountain View, CA, United States
# 21373                      f      Palo Alto, CA, United States
# 37512                      t       San Jose, CA, United States
#
#         neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed  \
# id
# 4952        Palo Alto              Palo Alto                           NaN
# 11464     Santa Clara            Santa Clara                           NaN
# 17884   Mountain View          Mountain View                           NaN
# 21373       Palo Alto              Palo Alto                           NaN
# 37512  South San Jose               San Jose                           NaN
#
#                 city state zipcode         market     smart_location  \
# id
# 4952       Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA
# 11464    Santa Clara    CA   95051  South Bay, CA    Santa Clara, CA
# 17884  Mountain View    CA   94041  South Bay, CA  Mountain View, CA
# 21373      Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA
# 37512       San Jose    CA   95111  South Bay, CA       San Jose, CA
#
#       country_code        country  latitude  longitude is_location_exact  \
# id
# 4952            US  United States  37.43972 -122.15672                 t
# 11464           US  United States  37.34342 -121.98829                 t
# 17884           US  United States  37.38612 -122.07357                 t
# 21373           US  United States  37.44001 -122.15667                 t
# 37512           US  United States  37.30598 -121.84036                 t
#
#       property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# id
# 4952          Villa     Private room             2        2.0       1.0   1.0
# 11464     Apartment  Entire home/apt             1        1.0       NaN   1.0
# 17884   Guest suite  Entire home/apt             2        1.0       1.0   1.0
# 21373         Villa     Private room             1        2.0       1.0   1.0
# 37512      Bungalow     Private room             2        1.0       1.0   1.0
#
#        bed_type                                          amenities  \
# id
# 4952   Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...
# 11464  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 17884  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 21373  Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...
# 37512  Real Bed  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...
#
#        square_feet   price weekly_price monthly_price security_deposit  \
# id
# 4952           NaN  $90.00      $440.00     $1,428.00            $0.00
# 11464        325.0  $85.00          NaN     $2,100.00          $700.00
# 17884          NaN  $65.00    $1,400.00     $2,800.00        $1,000.00
# 21373          NaN  $99.00      $600.00     $2,000.00            $0.00
# 37512          NaN  $52.00      $393.00     $1,386.00              NaN
#
#       cleaning_fee  guests_included extra_people  minimum_nights  \
# id
# 4952        $35.00                1       $45.00               2
# 11464      $250.00                1       $10.00              14
# 17884          NaN                1        $0.00              30
# 21373       $35.00                1       $50.00               2
# 37512          NaN                1        $0.00               1
#
#        maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# id
# 4952              365                       2                       2
# 11464             365                      14                      14
# 17884             180                      30                      30
# 21373             730                       2                       2
# 37512               7                       1                       1
#
#        minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# id
# 4952                      365                     365                     2.0
# 11464                     365                     365                    14.0
# 17884                     180                     180                    30.0
# 21373                     730                     730                     2.0
# 37512                       7                       7                     1.0
#
#        maximum_nights_avg_ntm calendar_updated has_availability  \
# id
# 4952                    365.0     2 months ago                t
# 11464                   365.0     5 months ago                t
# 17884                   180.0      4 weeks ago                t
# 21373                   730.0      3 weeks ago                t
# 37512                     7.0    23 months ago                t
#
#        availability_30  availability_60  availability_90  availability_365  \
# id
# 4952                 0                0                0                 0
# 11464               30               60               90               179
# 17884               29               59               89               179
# 21373                0                0                0               212
# 37512                0                0               28               303
#
#       calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# id
# 4952             2020-05-30                 75                      0
# 11464            2020-05-31                  6                      1
# 17884            2020-05-31                  2                      0
# 21373            2020-05-30                264                     39
# 37512            2020-05-31                183                      0
#
#       first_review last_review  review_scores_rating  review_scores_accuracy  \
# id
# 4952    2009-08-02  2019-01-12                  96.0                    10.0
# 11464   2014-06-15  2019-10-11                  87.0                    10.0
# 17884   2018-11-20  2019-04-27                  90.0                     8.0
# 21373   2010-05-28  2020-03-14                  97.0                    10.0
# 37512   2010-08-01  2017-03-14                  94.0                     9.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# id
# 4952                        10.0                   10.0
# 11464                       10.0                   10.0
# 17884                       10.0                   10.0
# 21373                       10.0                   10.0
# 37512                       10.0                   10.0
#
#        review_scores_communication  review_scores_location  \
# id
# 4952                          10.0                    10.0
# 11464                          9.0                     9.0
# 17884                         10.0                    10.0
# 21373                         10.0                    10.0
# 37512                         10.0                     9.0
#
#        review_scores_value requires_license  license       jurisdiction_names  \
# id
# 4952                  10.0                f      NaN            {"PALO ALTO"}
# 11464                  9.0                f      NaN          {"SANTA CLARA"}
# 17884                 10.0                f      NaN  {"Mountain View"," CA"}
# 21373                 10.0                f      NaN            {"PALO ALTO"}
# 37512                  9.0                f      NaN             {"SAN JOSE"}
#
#       instant_bookable is_business_travel_ready          cancellation_policy  \
# id
# 4952                 f                        f                     moderate
# 11464                f                        f                     moderate
# 17884                f                        f  strict_14_with_grace_period
# 21373                f                        f                     moderate
# 37512                f                        f                     moderate
#
#       require_guest_profile_picture require_guest_phone_verification  \
# id
# 4952                              f                                f
# 11464                             f                                t
# 17884                             f                                f
# 21373                             f                                f
# 37512                             t                                t
#
#        calculated_host_listings_count  \
# id
# 4952                                5
# 11464                              12
# 17884                               2
# 21373                               5
# 37512                               2
#
#        calculated_host_listings_count_entire_homes  \
# id
# 4952                                             0
# 11464                                           12
# 17884                                            2
# 21373                                            0
# 37512                                            0
#
#        calculated_host_listings_count_private_rooms  \
# id
# 4952                                              5
# 11464                                             0
# 17884                                             0
# 21373                                             5
# 37512                                             2
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 4952                                             0               0.57
# 11464                                            0               0.08
# 17884                                            0               0.11
# 21373                                            0               2.17
# 37512                                            0               1.53

# %%
dfs[1].head()
# Out:
#                        neighbourhood
# neighbourhood_group
# NaN                         Campbell
# NaN                        Cupertino
# NaN                           Gilroy
# NaN                        Los Altos
# NaN                  Los Altos Hills

# %%
dfs[2].head()
# Out:
#                   date
# listing_id
# 4952        2009-08-02
# 4952        2009-09-04
# 4952        2009-10-16
# 4952        2009-12-10
# 4952        2010-06-08

# %% [markdown]
# #3 EDA - Drop & Impute

# %% [markdown]
# ##3.1 df-Listing

# %% [markdown]
# ### 3.1.0 Transform price, weekly_price, & monthly_price

# %%
from re import sub
from decimal import Decimal

money = '$6,150,593.22'
value = Decimal(sub(r'[^\d.]', '', money))

# %%
# dfs[0].weekly_price.notnull()

# %%
def parse_price(p): 
    # print(type(p))
    # if p:
    # if not np.isnan(p):
    # p = str(p)
    if not pd.isna(p):
        # return float(p.split('$')[-1].replace(',', ''))
        return Decimal(sub(r'[^\d.]', '', p))
        # return float(sub(r'[^\d.]', '', p))
# dfs[0].monthly_price.map(parse_price)
# dfs[0].monthly_price.map(parse_price).astype(np.float)
dfs[0]['price'] = dfs[0].price.map(parse_price)
dfs[0]['weekly_price'] = dfs[0].weekly_price.map(parse_price)
dfs[0]['monthly_price'] = dfs[0].monthly_price.map(parse_price)
dfs[0] = dfs[0].astype({'price': np.float, 'weekly_price': np.float, 'monthly_price': np.float})
# Out:
# /var/folders/bz/8yf5rf0s1yzd3gl6nw6xvclw0000gn/T/ipykernel_20681/2097678152.py:15: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dfs[0] = dfs[0].astype({'price': np.float, 'weekly_price': np.float, 'monthly_price': np.float})

# %%
dfs[0].info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7221 entries, 4952 to 43591340
# Data columns (total 105 columns):
#  #    Column                                        Dtype
# ---   ------                                        -----
#  0    listing_url                                   object
#  1    scrape_id                                     int64
#  2    last_scraped                                  object
#  3    name                                          object
#  4    summary                                       object
#  5    space                                         object
#  6    description                                   object
#  7    experiences_offered                           object
#  8    neighborhood_overview                         object
#  9    notes                                         object
#  10   transit                                       object
#  11   access                                        object
#  12   interaction                                   object
#  13   house_rules                                   object
#  14   thumbnail_url                                 float64
#  15   medium_url                                    float64
#  16   picture_url                                   object
#  17   xl_picture_url                                float64
#  18   host_id                                       int64
#  19   host_url                                      object
#  20   host_name                                     object
#  21   host_since                                    object
#  22   host_location                                 object
#  23   host_about                                    object
#  24   host_response_time                            object
#  25   host_response_rate                            object
#  26   host_acceptance_rate                          object
#  27   host_is_superhost                             object
#  28   host_thumbnail_url                            object
#  29   host_picture_url                              object
#  30   host_neighbourhood                            object
#  31   host_listings_count                           float64
#  32   host_total_listings_count                     float64
#  33   host_verifications                            object
#  34   host_has_profile_pic                          object
#  35   host_identity_verified                        object
#  36   street                                        object
#  37   neighbourhood                                 object
#  38   neighbourhood_cleansed                        object
#  39   neighbourhood_group_cleansed                  float64
#  40   city                                          object
#  41   state                                         object
#  42   zipcode                                       object
#  43   market                                        object
#  44   smart_location                                object
#  45   country_code                                  object
#  46   country                                       object
#  47   latitude                                      float64
#  48   longitude                                     float64
#  49   is_location_exact                             object
#  50   property_type                                 object
#  51   room_type                                     object
#  52   accommodates                                  int64
#  53   bathrooms                                     float64
#  54   bedrooms                                      float64
#  55   beds                                          float64
#  56   bed_type                                      object
#  57   amenities                                     object
#  58   square_feet                                   float64
#  59   price                                         float64
#  60   weekly_price                                  float64
#  61   monthly_price                                 float64
#  62   security_deposit                              object
#  63   cleaning_fee                                  object
#  64   guests_included                               int64
#  65   extra_people                                  object
#  66   minimum_nights                                int64
#  67   maximum_nights                                int64
#  68   minimum_minimum_nights                        int64
#  69   maximum_minimum_nights                        int64
#  70   minimum_maximum_nights                        int64
#  71   maximum_maximum_nights                        int64
#  72   minimum_nights_avg_ntm                        float64
#  73   maximum_nights_avg_ntm                        float64
#  74   calendar_updated                              object
#  75   has_availability                              object
#  76   availability_30                               int64
#  77   availability_60                               int64
#  78   availability_90                               int64
#  79   availability_365                              int64
#  80   calendar_last_scraped                         object
#  81   number_of_reviews                             int64
#  82   number_of_reviews_ltm                         int64
#  83   first_review                                  object
#  84   last_review                                   object
#  85   review_scores_rating                          float64
#  86   review_scores_accuracy                        float64
#  87   review_scores_cleanliness                     float64
#  88   review_scores_checkin                         float64
#  89   review_scores_communication                   float64
#  90   review_scores_location                        float64
#  91   review_scores_value                           float64
#  92   requires_license                              object
#  93   license                                       float64
#  94   jurisdiction_names                            object
#  95   instant_bookable                              object
#  96   is_business_travel_ready                      object
#  97   cancellation_policy                           object
#  98   require_guest_profile_picture                 object
#  99   require_guest_phone_verification              object
#  100  calculated_host_listings_count                int64
#  101  calculated_host_listings_count_entire_homes   int64
#  102  calculated_host_listings_count_private_rooms  int64
#  103  calculated_host_listings_count_shared_rooms   int64
#  104  reviews_per_month                             float64
# dtypes: float64(26), int64(20), object(59)
# memory usage: 5.8+ MB

# %% [markdown]
# ### 3.1.1Regular Drop

# %%
dfs[0].info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7221 entries, 4952 to 43591340
# Data columns (total 105 columns):
#  #    Column                                        Non-Null Count  Dtype
# ---   ------                                        --------------  -----
#  0    listing_url                                   7221 non-null   object
#  1    scrape_id                                     7221 non-null   int64
#  2    last_scraped                                  7221 non-null   object
#  3    name                                          7220 non-null   object
#  4    summary                                       6922 non-null   object
#  5    space                                         5514 non-null   object
#  6    description                                   6983 non-null   object
#  7    experiences_offered                           7221 non-null   object
#  8    neighborhood_overview                         4544 non-null   object
#  9    notes                                         3692 non-null   object
#  10   transit                                       4136 non-null   object
#  11   access                                        4104 non-null   object
#  12   interaction                                   4253 non-null   object
#  13   house_rules                                   4957 non-null   object
#  14   thumbnail_url                                 0 non-null      float64
#  15   medium_url                                    0 non-null      float64
#  16   picture_url                                   7221 non-null   object
#  17   xl_picture_url                                0 non-null      float64
#  18   host_id                                       7221 non-null   int64
#  19   host_url                                      7221 non-null   object
#  20   host_name                                     7220 non-null   object
#  21   host_since                                    7220 non-null   object
#  22   host_location                                 7198 non-null   object
#  23   host_about                                    4887 non-null   object
#  24   host_response_time                            5414 non-null   object
#  25   host_response_rate                            5414 non-null   object
#  26   host_acceptance_rate                          6507 non-null   object
#  27   host_is_superhost                             7220 non-null   object
#  28   host_thumbnail_url                            7220 non-null   object
#  29   host_picture_url                              7220 non-null   object
#  30   host_neighbourhood                            6040 non-null   object
#  31   host_listings_count                           7220 non-null   float64
#  32   host_total_listings_count                     7220 non-null   float64
#  33   host_verifications                            7221 non-null   object
#  34   host_has_profile_pic                          7220 non-null   object
#  35   host_identity_verified                        7220 non-null   object
#  36   street                                        7221 non-null   object
#  37   neighbourhood                                 6738 non-null   object
#  38   neighbourhood_cleansed                        7221 non-null   object
#  39   neighbourhood_group_cleansed                  0 non-null      float64
#  40   city                                          7220 non-null   object
#  41   state                                         7220 non-null   object
#  42   zipcode                                       7166 non-null   object
#  43   market                                        7210 non-null   object
#  44   smart_location                                7221 non-null   object
#  45   country_code                                  7221 non-null   object
#  46   country                                       7221 non-null   object
#  47   latitude                                      7221 non-null   float64
#  48   longitude                                     7221 non-null   float64
#  49   is_location_exact                             7221 non-null   object
#  50   property_type                                 7221 non-null   object
#  51   room_type                                     7221 non-null   object
#  52   accommodates                                  7221 non-null   int64
#  53   bathrooms                                     7220 non-null   float64
#  54   bedrooms                                      7215 non-null   float64
#  55   beds                                          7153 non-null   float64
#  56   bed_type                                      7221 non-null   object
#  57   amenities                                     7221 non-null   object
#  58   square_feet                                   29 non-null     float64
#  59   price                                         7221 non-null   float64
#  60   weekly_price                                  574 non-null    float64
#  61   monthly_price                                 592 non-null    float64
#  62   security_deposit                              5764 non-null   object
#  63   cleaning_fee                                  6421 non-null   object
#  64   guests_included                               7221 non-null   int64
#  65   extra_people                                  7221 non-null   object
#  66   minimum_nights                                7221 non-null   int64
#  67   maximum_nights                                7221 non-null   int64
#  68   minimum_minimum_nights                        7221 non-null   int64
#  69   maximum_minimum_nights                        7221 non-null   int64
#  70   minimum_maximum_nights                        7221 non-null   int64
#  71   maximum_maximum_nights                        7221 non-null   int64
#  72   minimum_nights_avg_ntm                        7221 non-null   float64
#  73   maximum_nights_avg_ntm                        7221 non-null   float64
#  74   calendar_updated                              7221 non-null   object
#  75   has_availability                              7221 non-null   object
#  76   availability_30                               7221 non-null   int64
#  77   availability_60                               7221 non-null   int64
#  78   availability_90                               7221 non-null   int64
#  79   availability_365                              7221 non-null   int64
#  80   calendar_last_scraped                         7221 non-null   object
#  81   number_of_reviews                             7221 non-null   int64
#  82   number_of_reviews_ltm                         7221 non-null   int64
#  83   first_review                                  5912 non-null   object
#  84   last_review                                   5912 non-null   object
#  85   review_scores_rating                          5854 non-null   float64
#  86   review_scores_accuracy                        5852 non-null   float64
#  87   review_scores_cleanliness                     5852 non-null   float64
#  88   review_scores_checkin                         5851 non-null   float64
#  89   review_scores_communication                   5852 non-null   float64
#  90   review_scores_location                        5851 non-null   float64
#  91   review_scores_value                           5851 non-null   float64
#  92   requires_license                              7221 non-null   object
#  93   license                                       0 non-null      float64
#  94   jurisdiction_names                            6242 non-null   object
#  95   instant_bookable                              7221 non-null   object
#  96   is_business_travel_ready                      7221 non-null   object
#  97   cancellation_policy                           7221 non-null   object
#  98   require_guest_profile_picture                 7221 non-null   object
#  99   require_guest_phone_verification              7221 non-null   object
#  100  calculated_host_listings_count                7221 non-null   int64
#  101  calculated_host_listings_count_entire_homes   7221 non-null   int64
#  102  calculated_host_listings_count_private_rooms  7221 non-null   int64
#  103  calculated_host_listings_count_shared_rooms   7221 non-null   int64
#  104  reviews_per_month                             5912 non-null   float64
# dtypes: float64(26), int64(20), object(59)
# memory usage: 5.8+ MB
# /var/folders/bz/8yf5rf0s1yzd3gl6nw6xvclw0000gn/T/ipykernel_20681/1100731088.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   dfs[0].info(verbose=True, null_counts=True)

# %%
dfs[0].columns[:30]
# Out:
# Index(['listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url',
#        'medium_url', 'picture_url', 'xl_picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url'],
#       dtype='object')

# %%
drops_NLP = ['listing_url', 'scrape_id', 'name', 'summary', 'space',
       'description', 'experiences_offered', 'neighborhood_overview', 'notes',
       'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url',
       'medium_url', 'picture_url', 'xl_picture_url', 'host_url',
       'host_location', 'host_about',
       'host_response_time', 
       'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 
       'host_verifications']
""" 
KEEP 
last_scraped, host_id, 'host_response_rate', 'host_acceptance_rate'
"""
drops_all_NA = ['thumbnail_url', 'medium_url', 'xl_picture_url', 'neighbourhood_group_cleansed', 'license']

dfs_0_dropped = dfs[0].drop(list(set(drops_NLP + drops_all_NA)), axis=1)
dfs_0_dropped.head(5)
# Out:
#       last_scraped  host_id host_name  host_since host_response_rate  \
# id
# 4952    2020-05-30     7054   Mei Lin  2009-01-24               100%
# 11464   2020-05-31    42458      Emey  2009-09-30               100%
# 17884   2020-05-31    69023     Janet  2010-01-08               100%
# 21373   2020-05-30     7054   Mei Lin  2009-01-24               100%
# 37512   2020-05-31   161741     Maria  2010-07-09               100%
#
#       host_acceptance_rate host_neighbourhood  host_listings_count  \
# id
# 4952                   98%          Palo Alto                  5.0
# 11464                  90%        Santa Clara                 13.0
# 17884                  50%          Palo Alto                  2.0
# 21373                  98%          Palo Alto                  5.0
# 37512                 100%     South San Jose                  2.0
#
#        host_total_listings_count host_has_profile_pic host_identity_verified  \
# id
# 4952                         5.0                    t                      f
# 11464                       13.0                    t                      f
# 17884                        2.0                    t                      t
# 21373                        5.0                    t                      f
# 37512                        2.0                    t                      t
#
#                                  street   neighbourhood  \
# id
# 4952       Palo Alto, CA, United States       Palo Alto
# 11464    Santa Clara, CA, United States     Santa Clara
# 17884  Mountain View, CA, United States   Mountain View
# 21373      Palo Alto, CA, United States       Palo Alto
# 37512       San Jose, CA, United States  South San Jose
#
#       neighbourhood_cleansed           city state zipcode         market  \
# id
# 4952               Palo Alto      Palo Alto    CA   94301  South Bay, CA
# 11464            Santa Clara    Santa Clara    CA   95051  South Bay, CA
# 17884          Mountain View  Mountain View    CA   94041  South Bay, CA
# 21373              Palo Alto      Palo Alto    CA   94301  South Bay, CA
# 37512               San Jose       San Jose    CA   95111  South Bay, CA
#
#           smart_location country_code        country  latitude  longitude  \
# id
# 4952       Palo Alto, CA           US  United States  37.43972 -122.15672
# 11464    Santa Clara, CA           US  United States  37.34342 -121.98829
# 17884  Mountain View, CA           US  United States  37.38612 -122.07357
# 21373      Palo Alto, CA           US  United States  37.44001 -122.15667
# 37512       San Jose, CA           US  United States  37.30598 -121.84036
#
#       is_location_exact property_type        room_type  accommodates  \
# id
# 4952                  t         Villa     Private room             2
# 11464                 t     Apartment  Entire home/apt             1
# 17884                 t   Guest suite  Entire home/apt             2
# 21373                 t         Villa     Private room             1
# 37512                 t      Bungalow     Private room             2
#
#        bathrooms  bedrooms  beds  bed_type  \
# id
# 4952         2.0       1.0   1.0  Real Bed
# 11464        1.0       NaN   1.0  Real Bed
# 17884        1.0       1.0   1.0  Real Bed
# 21373        2.0       1.0   1.0  Real Bed
# 37512        1.0       1.0   1.0  Real Bed
#
#                                                amenities  square_feet  price  \
# id
# 4952   {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...          NaN   90.0
# 11464  {TV,"Cable TV",Internet,Wifi,"Air conditioning...        325.0   85.0
# 17884  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN   65.0
# 21373  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...          NaN   99.0
# 37512  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...          NaN   52.0
#
#        weekly_price  monthly_price security_deposit cleaning_fee  \
# id
# 4952          440.0         1428.0            $0.00       $35.00
# 11464           NaN         2100.0          $700.00      $250.00
# 17884        1400.0         2800.0        $1,000.00          NaN
# 21373         600.0         2000.0            $0.00       $35.00
# 37512         393.0         1386.0              NaN          NaN
#
#        guests_included extra_people  minimum_nights  maximum_nights  \
# id
# 4952                 1       $45.00               2             365
# 11464                1       $10.00              14             365
# 17884                1        $0.00              30             180
# 21373                1       $50.00               2             730
# 37512                1        $0.00               1               7
#
#        minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# id
# 4952                        2                       2                     365
# 11464                      14                      14                     365
# 17884                      30                      30                     180
# 21373                       2                       2                     730
# 37512                       1                       1                       7
#
#        maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# id
# 4952                      365                     2.0                   365.0
# 11464                     365                    14.0                   365.0
# 17884                     180                    30.0                   180.0
# 21373                     730                     2.0                   730.0
# 37512                       7                     1.0                     7.0
#
#       calendar_updated has_availability  availability_30  availability_60  \
# id
# 4952      2 months ago                t                0                0
# 11464     5 months ago                t               30               60
# 17884      4 weeks ago                t               29               59
# 21373      3 weeks ago                t                0                0
# 37512    23 months ago                t                0                0
#
#        availability_90  availability_365 calendar_last_scraped  \
# id
# 4952                 0                 0            2020-05-30
# 11464               90               179            2020-05-31
# 17884               89               179            2020-05-31
# 21373                0               212            2020-05-30
# 37512               28               303            2020-05-31
#
#        number_of_reviews  number_of_reviews_ltm first_review last_review  \
# id
# 4952                  75                      0   2009-08-02  2019-01-12
# 11464                  6                      1   2014-06-15  2019-10-11
# 17884                  2                      0   2018-11-20  2019-04-27
# 21373                264                     39   2010-05-28  2020-03-14
# 37512                183                      0   2010-08-01  2017-03-14
#
#        review_scores_rating  review_scores_accuracy  \
# id
# 4952                   96.0                    10.0
# 11464                  87.0                    10.0
# 17884                  90.0                     8.0
# 21373                  97.0                    10.0
# 37512                  94.0                     9.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# id
# 4952                        10.0                   10.0
# 11464                       10.0                   10.0
# 17884                       10.0                   10.0
# 21373                       10.0                   10.0
# 37512                       10.0                   10.0
#
#        review_scores_communication  review_scores_location  \
# id
# 4952                          10.0                    10.0
# 11464                          9.0                     9.0
# 17884                         10.0                    10.0
# 21373                         10.0                    10.0
# 37512                         10.0                     9.0
#
#        review_scores_value requires_license       jurisdiction_names  \
# id
# 4952                  10.0                f            {"PALO ALTO"}
# 11464                  9.0                f          {"SANTA CLARA"}
# 17884                 10.0                f  {"Mountain View"," CA"}
# 21373                 10.0                f            {"PALO ALTO"}
# 37512                  9.0                f             {"SAN JOSE"}
#
#       instant_bookable is_business_travel_ready          cancellation_policy  \
# id
# 4952                 f                        f                     moderate
# 11464                f                        f                     moderate
# 17884                f                        f  strict_14_with_grace_period
# 21373                f                        f                     moderate
# 37512                f                        f                     moderate
#
#       require_guest_profile_picture require_guest_phone_verification  \
# id
# 4952                              f                                f
# 11464                             f                                t
# 17884                             f                                f
# 21373                             f                                f
# 37512                             t                                t
#
#        calculated_host_listings_count  \
# id
# 4952                                5
# 11464                              12
# 17884                               2
# 21373                               5
# 37512                               2
#
#        calculated_host_listings_count_entire_homes  \
# id
# 4952                                             0
# 11464                                           12
# 17884                                            2
# 21373                                            0
# 37512                                            0
#
#        calculated_host_listings_count_private_rooms  \
# id
# 4952                                              5
# 11464                                             0
# 17884                                             0
# 21373                                             5
# 37512                                             2
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 4952                                             0               0.57
# 11464                                            0               0.08
# 17884                                            0               0.11
# 21373                                            0               2.17
# 37512                                            0               1.53

# %%
dfs_0_dropped.info(verbose=True, null_counts=True)
# Out:
# /var/folders/bz/8yf5rf0s1yzd3gl6nw6xvclw0000gn/T/ipykernel_20681/3673199569.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   dfs_0_dropped.info(verbose=True, null_counts=True)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7221 entries, 4952 to 43591340
# Data columns (total 78 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   last_scraped                                  7221 non-null   object
#  1   host_id                                       7221 non-null   int64
#  2   host_name                                     7220 non-null   object
#  3   host_since                                    7220 non-null   object
#  4   host_response_rate                            5414 non-null   object
#  5   host_acceptance_rate                          6507 non-null   object
#  6   host_neighbourhood                            6040 non-null   object
#  7   host_listings_count                           7220 non-null   float64
#  8   host_total_listings_count                     7220 non-null   float64
#  9   host_has_profile_pic                          7220 non-null   object
#  10  host_identity_verified                        7220 non-null   object
#  11  street                                        7221 non-null   object
#  12  neighbourhood                                 6738 non-null   object
#  13  neighbourhood_cleansed                        7221 non-null   object
#  14  city                                          7220 non-null   object
#  15  state                                         7220 non-null   object
#  16  zipcode                                       7166 non-null   object
#  17  market                                        7210 non-null   object
#  18  smart_location                                7221 non-null   object
#  19  country_code                                  7221 non-null   object
#  20  country                                       7221 non-null   object
#  21  latitude                                      7221 non-null   float64
#  22  longitude                                     7221 non-null   float64
#  23  is_location_exact                             7221 non-null   object
#  24  property_type                                 7221 non-null   object
#  25  room_type                                     7221 non-null   object
#  26  accommodates                                  7221 non-null   int64
#  27  bathrooms                                     7220 non-null   float64
#  28  bedrooms                                      7215 non-null   float64
#  29  beds                                          7153 non-null   float64
#  30  bed_type                                      7221 non-null   object
#  31  amenities                                     7221 non-null   object
#  32  square_feet                                   29 non-null     float64
#  33  price                                         7221 non-null   float64
#  34  weekly_price                                  574 non-null    float64
#  35  monthly_price                                 592 non-null    float64
#  36  security_deposit                              5764 non-null   object
#  37  cleaning_fee                                  6421 non-null   object
#  38  guests_included                               7221 non-null   int64
#  39  extra_people                                  7221 non-null   object
#  40  minimum_nights                                7221 non-null   int64
#  41  maximum_nights                                7221 non-null   int64
#  42  minimum_minimum_nights                        7221 non-null   int64
#  43  maximum_minimum_nights                        7221 non-null   int64
#  44  minimum_maximum_nights                        7221 non-null   int64
#  45  maximum_maximum_nights                        7221 non-null   int64
#  46  minimum_nights_avg_ntm                        7221 non-null   float64
#  47  maximum_nights_avg_ntm                        7221 non-null   float64
#  48  calendar_updated                              7221 non-null   object
#  49  has_availability                              7221 non-null   object
#  50  availability_30                               7221 non-null   int64
#  51  availability_60                               7221 non-null   int64
#  52  availability_90                               7221 non-null   int64
#  53  availability_365                              7221 non-null   int64
#  54  calendar_last_scraped                         7221 non-null   object
#  55  number_of_reviews                             7221 non-null   int64
#  56  number_of_reviews_ltm                         7221 non-null   int64
#  57  first_review                                  5912 non-null   object
#  58  last_review                                   5912 non-null   object
#  59  review_scores_rating                          5854 non-null   float64
#  60  review_scores_accuracy                        5852 non-null   float64
#  61  review_scores_cleanliness                     5852 non-null   float64
#  62  review_scores_checkin                         5851 non-null   float64
#  63  review_scores_communication                   5852 non-null   float64
#  64  review_scores_location                        5851 non-null   float64
#  65  review_scores_value                           5851 non-null   float64
#  66  requires_license                              7221 non-null   object
#  67  jurisdiction_names                            6242 non-null   object
#  68  instant_bookable                              7221 non-null   object
#  69  is_business_travel_ready                      7221 non-null   object
#  70  cancellation_policy                           7221 non-null   object
#  71  require_guest_profile_picture                 7221 non-null   object
#  72  require_guest_phone_verification              7221 non-null   object
#  73  calculated_host_listings_count                7221 non-null   int64
#  74  calculated_host_listings_count_entire_homes   7221 non-null   int64
#  75  calculated_host_listings_count_private_rooms  7221 non-null   int64
#  76  calculated_host_listings_count_shared_rooms   7221 non-null   int64
#  77  reviews_per_month                             5912 non-null   float64
# dtypes: float64(21), int64(19), object(38)
# memory usage: 4.4+ MB

# %%
df_imputation = dfs_0_dropped.copy(deep=True)

# %%
df_imputation
# Out:
#          last_scraped    host_id host_name  host_since host_response_rate  \
# id
# 4952       2020-05-30       7054   Mei Lin  2009-01-24               100%
# 11464      2020-05-31      42458      Emey  2009-09-30               100%
# 17884      2020-05-31      69023     Janet  2010-01-08               100%
# 21373      2020-05-30       7054   Mei Lin  2009-01-24               100%
# 37512      2020-05-31     161741     Maria  2010-07-09               100%
# ...               ...        ...       ...         ...                ...
# 43567384   2020-05-31    5974627     Susan  2013-04-17               100%
# 43568844   2020-05-31  347799221     Irene  2020-05-27                NaN
# 43579879   2020-05-31  341673005     Sunny  2020-03-15                NaN
# 43580120   2020-05-30   31314220   Miranda  2015-04-15                NaN
# 43591340   2020-05-31    6202502  Isabelle  2013-05-02               100%
#
#          host_acceptance_rate host_neighbourhood  host_listings_count  \
# id
# 4952                      98%          Palo Alto                  5.0
# 11464                     90%        Santa Clara                 13.0
# 17884                     50%          Palo Alto                  2.0
# 21373                     98%          Palo Alto                  5.0
# 37512                    100%     South San Jose                  2.0
# ...                       ...                ...                  ...
# 43567384                  90%        Naglee Park                  2.0
# 43568844                  NaN                NaN                  1.0
# 43579879                  NaN              Snail                  0.0
# 43580120                  NaN          Rose Glen                  0.0
# 43591340                  99%      Mountain View                 71.0
#
#           host_total_listings_count host_has_profile_pic  \
# id
# 4952                            5.0                    t
# 11464                          13.0                    t
# 17884                           2.0                    t
# 21373                           5.0                    t
# 37512                           2.0                    t
# ...                             ...                  ...
# 43567384                        2.0                    t
# 43568844                        1.0                    t
# 43579879                        0.0                    t
# 43580120                        0.0                    t
# 43591340                       71.0                    t
#
#          host_identity_verified                            street  \
# id
# 4952                          f      Palo Alto, CA, United States
# 11464                         f    Santa Clara, CA, United States
# 17884                         t  Mountain View, CA, United States
# 21373                         f      Palo Alto, CA, United States
# 37512                         t       San Jose, CA, United States
# ...                         ...                               ...
# 43567384                      t       San Jose, CA, United States
# 43568844                      f    Santa Clara, CA, United States
# 43579879                      f      Sunnyvale, CA, United States
# 43580120                      t       San Jose, CA, United States
# 43591340                      f       San Jose, CA, United States
#
#               neighbourhood neighbourhood_cleansed           city state  \
# id
# 4952              Palo Alto              Palo Alto      Palo Alto    CA
# 11464           Santa Clara            Santa Clara    Santa Clara    CA
# 17884         Mountain View          Mountain View  Mountain View    CA
# 21373             Palo Alto              Palo Alto      Palo Alto    CA
# 37512        South San Jose               San Jose       San Jose    CA
# ...                     ...                    ...            ...   ...
# 43567384        Naglee Park               San Jose       San Jose    CA
# 43568844        Santa Clara            Santa Clara    Santa Clara    CA
# 43579879          Sunnyvale              Sunnyvale      Sunnyvale    CA
# 43580120  Burbank/Del Monte               San Jose       San Jose    CA
# 43591340   Cambrian/Pioneer               San Jose       San Jose    CA
#
#          zipcode         market     smart_location country_code  \
# id
# 4952       94301  South Bay, CA      Palo Alto, CA           US
# 11464      95051  South Bay, CA    Santa Clara, CA           US
# 17884      94041  South Bay, CA  Mountain View, CA           US
# 21373      94301  South Bay, CA      Palo Alto, CA           US
# 37512      95111  South Bay, CA       San Jose, CA           US
# ...          ...            ...                ...          ...
# 43567384   95112   South Bay CA       San Jose, CA           US
# 43568844   95051   South Bay CA    Santa Clara, CA           US
# 43579879   94085   South Bay CA      Sunnyvale, CA           US
# 43580120   95128   South Bay CA       San Jose, CA           US
# 43591340   95118   South Bay CA       San Jose, CA           US
#
#                 country  latitude  longitude is_location_exact property_type  \
# id
# 4952      United States  37.43972 -122.15672                 t         Villa
# 11464     United States  37.34342 -121.98829                 t     Apartment
# 17884     United States  37.38612 -122.07357                 t   Guest suite
# 21373     United States  37.44001 -122.15667                 t         Villa
# 37512     United States  37.30598 -121.84036                 t      Bungalow
# ...                 ...       ...        ...               ...           ...
# 43567384  United States  37.33794 -121.87189                 t   Guest suite
# 43568844  United States  37.35473 -121.99940                 t   Condominium
# 43579879  United States  37.39309 -122.02541                 t         House
# 43580120  United States  37.31209 -121.92103                 t         House
# 43591340  United States  37.24502 -121.87745                 t     Apartment
#
#                 room_type  accommodates  bathrooms  bedrooms  beds  bed_type  \
# id
# 4952         Private room             2        2.0       1.0   1.0  Real Bed
# 11464     Entire home/apt             1        1.0       NaN   1.0  Real Bed
# 17884     Entire home/apt             2        1.0       1.0   1.0  Real Bed
# 21373        Private room             1        2.0       1.0   1.0  Real Bed
# 37512        Private room             2        1.0       1.0   1.0  Real Bed
# ...                   ...           ...        ...       ...   ...       ...
# 43567384  Entire home/apt             1        1.0       0.0   1.0  Real Bed
# 43568844  Entire home/apt             4        1.0       1.0   2.0  Real Bed
# 43579879     Private room             1        1.0       1.0   1.0  Real Bed
# 43580120     Private room             1        1.0       1.0   1.0  Real Bed
# 43591340  Entire home/apt             4        1.0       2.0   2.0  Real Bed
#
#                                                   amenities  square_feet  \
# id
# 4952      {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...          NaN
# 11464     {TV,"Cable TV",Internet,Wifi,"Air conditioning...        325.0
# 17884     {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN
# 21373     {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...          NaN
# 37512     {Internet,Wifi,"Air conditioning",Kitchen,"Fre...          NaN
# ...                                                     ...          ...
# 43567384  {TV,"Cable TV",Internet,Wifi,Kitchen,"Free par...          NaN
# 43568844  {TV,"Cable TV",Wifi,"Air conditioning",Pool,Ki...          NaN
# 43579879  {TV,Wifi,Kitchen,"Free parking on premises",Wa...          NaN
# 43580120  {TV,Wifi,"Air conditioning",Kitchen,"Free park...          NaN
# 43591340  {TV,Wifi,"Air conditioning",Kitchen,"Free park...          NaN
#
#           price  weekly_price  monthly_price security_deposit cleaning_fee  \
# id
# 4952       90.0         440.0         1428.0            $0.00       $35.00
# 11464      85.0           NaN         2100.0          $700.00      $250.00
# 17884      65.0        1400.0         2800.0        $1,000.00          NaN
# 21373      99.0         600.0         2000.0            $0.00       $35.00
# 37512      52.0         393.0         1386.0              NaN          NaN
# ...         ...           ...            ...              ...          ...
# 43567384   49.0           NaN            NaN          $500.00      $100.00
# 43568844  135.0           NaN            NaN          $500.00      $135.00
# 43579879   85.0           NaN            NaN            $0.00      $150.00
# 43580120   49.0           NaN            NaN        $1,000.00      $150.00
# 43591340  145.0           NaN            NaN          $400.00       $90.00
#
#           guests_included extra_people  minimum_nights  maximum_nights  \
# id
# 4952                    1       $45.00               2             365
# 11464                   1       $10.00              14             365
# 17884                   1        $0.00              30             180
# 21373                   1       $50.00               2             730
# 37512                   1        $0.00               1               7
# ...                   ...          ...             ...             ...
# 43567384                1       $50.00               3            1125
# 43568844                2       $20.00              30            1125
# 43579879                1       $25.00              30            1125
# 43580120                1       $10.00              14             365
# 43591340                1        $0.00               1            1125
#
#           minimum_minimum_nights  maximum_minimum_nights  \
# id
# 4952                           2                       2
# 11464                         14                      14
# 17884                         30                      30
# 21373                          2                       2
# 37512                          1                       1
# ...                          ...                     ...
# 43567384                       3                       3
# 43568844                      30                      30
# 43579879                      30                      30
# 43580120                      14                      14
# 43591340                       1                       1
#
#           minimum_maximum_nights  maximum_maximum_nights  \
# id
# 4952                         365                     365
# 11464                        365                     365
# 17884                        180                     180
# 21373                        730                     730
# 37512                          7                       7
# ...                          ...                     ...
# 43567384                    1125                    1125
# 43568844                    1125                    1125
# 43579879                    1125                    1125
# 43580120                    1125                    1125
# 43591340                    1125                    1125
#
#           minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# id
# 4952                         2.0                   365.0     2 months ago
# 11464                       14.0                   365.0     5 months ago
# 17884                       30.0                   180.0      4 weeks ago
# 21373                        2.0                   730.0      3 weeks ago
# 37512                        1.0                     7.0    23 months ago
# ...                          ...                     ...              ...
# 43567384                     3.0                  1125.0       3 days ago
# 43568844                    30.0                  1125.0       3 days ago
# 43579879                    30.0                  1125.0       2 days ago
# 43580120                    14.0                  1125.0       2 days ago
# 43591340                     1.0                  1125.0            never
#
#          has_availability  availability_30  availability_60  availability_90  \
# id
# 4952                    t                0                0                0
# 11464                   t               30               60               90
# 17884                   t               29               59               89
# 21373                   t                0                0                0
# 37512                   t                0                0               28
# ...                   ...              ...              ...              ...
# 43567384                t               29               30               30
# 43568844                t               25               55               85
# 43579879                t               14               44               46
# 43580120                t               30               60               90
# 43591340                t               25               55               85
#
#           availability_365 calendar_last_scraped  number_of_reviews  \
# id
# 4952                     0            2020-05-30                 75
# 11464                  179            2020-05-31                  6
# 17884                  179            2020-05-31                  2
# 21373                  212            2020-05-30                264
# 37512                  303            2020-05-31                183
# ...                    ...                   ...                ...
# 43567384                30            2020-05-31                  0
# 43568844               360            2020-05-31                  0
# 43579879                46            2020-05-31                  0
# 43580120               180            2020-05-30                  0
# 43591340               360            2020-05-31                  0
#
#           number_of_reviews_ltm first_review last_review  \
# id
# 4952                          0   2009-08-02  2019-01-12
# 11464                         1   2014-06-15  2019-10-11
# 17884                         0   2018-11-20  2019-04-27
# 21373                        39   2010-05-28  2020-03-14
# 37512                         0   2010-08-01  2017-03-14
# ...                         ...          ...         ...
# 43567384                      0          NaN         NaN
# 43568844                      0          NaN         NaN
# 43579879                      0          NaN         NaN
# 43580120                      0          NaN         NaN
# 43591340                      0          NaN         NaN
#
#           review_scores_rating  review_scores_accuracy  \
# id
# 4952                      96.0                    10.0
# 11464                     87.0                    10.0
# 17884                     90.0                     8.0
# 21373                     97.0                    10.0
# 37512                     94.0                     9.0
# ...                        ...                     ...
# 43567384                   NaN                     NaN
# 43568844                   NaN                     NaN
# 43579879                   NaN                     NaN
# 43580120                   NaN                     NaN
# 43591340                   NaN                     NaN
#
#           review_scores_cleanliness  review_scores_checkin  \
# id
# 4952                           10.0                   10.0
# 11464                          10.0                   10.0
# 17884                          10.0                   10.0
# 21373                          10.0                   10.0
# 37512                          10.0                   10.0
# ...                             ...                    ...
# 43567384                        NaN                    NaN
# 43568844                        NaN                    NaN
# 43579879                        NaN                    NaN
# 43580120                        NaN                    NaN
# 43591340                        NaN                    NaN
#
#           review_scores_communication  review_scores_location  \
# id
# 4952                             10.0                    10.0
# 11464                             9.0                     9.0
# 17884                            10.0                    10.0
# 21373                            10.0                    10.0
# 37512                            10.0                     9.0
# ...                               ...                     ...
# 43567384                          NaN                     NaN
# 43568844                          NaN                     NaN
# 43579879                          NaN                     NaN
# 43580120                          NaN                     NaN
# 43591340                          NaN                     NaN
#
#           review_scores_value requires_license       jurisdiction_names  \
# id
# 4952                     10.0                f            {"PALO ALTO"}
# 11464                     9.0                f          {"SANTA CLARA"}
# 17884                    10.0                f  {"Mountain View"," CA"}
# 21373                    10.0                f            {"PALO ALTO"}
# 37512                     9.0                f             {"SAN JOSE"}
# ...                       ...              ...                      ...
# 43567384                  NaN                f             {"SAN JOSE"}
# 43568844                  NaN                f          {"SANTA CLARA"}
# 43579879                  NaN                f        {Sunnyvale," CA"}
# 43580120                  NaN                f             {"SAN JOSE"}
# 43591340                  NaN                f             {"SAN JOSE"}
#
#          instant_bookable is_business_travel_ready  \
# id
# 4952                    f                        f
# 11464                   f                        f
# 17884                   f                        f
# 21373                   f                        f
# 37512                   f                        f
# ...                   ...                      ...
# 43567384                f                        f
# 43568844                f                        f
# 43579879                t                        f
# 43580120                f                        f
# 43591340                t                        f
#
#                   cancellation_policy require_guest_profile_picture  \
# id
# 4952                         moderate                             f
# 11464                        moderate                             f
# 17884     strict_14_with_grace_period                             f
# 21373                        moderate                             f
# 37512                        moderate                             t
# ...                               ...                           ...
# 43567384                     moderate                             f
# 43568844  strict_14_with_grace_period                             f
# 43579879                     flexible                             f
# 43580120                     moderate                             f
# 43591340  strict_14_with_grace_period                             f
#
#          require_guest_phone_verification  calculated_host_listings_count  \
# id
# 4952                                    f                               5
# 11464                                   t                              12
# 17884                                   f                               2
# 21373                                   f                               5
# 37512                                   t                               2
# ...                                   ...                             ...
# 43567384                                f                               2
# 43568844                                f                               1
# 43579879                                f                               1
# 43580120                                f                               1
# 43591340                                f                              21
#
#           calculated_host_listings_count_entire_homes  \
# id
# 4952                                                0
# 11464                                              12
# 17884                                               2
# 21373                                               0
# 37512                                               0
# ...                                               ...
# 43567384                                            2
# 43568844                                            1
# 43579879                                            0
# 43580120                                            0
# 43591340                                           19
#
#           calculated_host_listings_count_private_rooms  \
# id
# 4952                                                 5
# 11464                                                0
# 17884                                                0
# 21373                                                5
# 37512                                                2
# ...                                                ...
# 43567384                                             0
# 43568844                                             0
# 43579879                                             1
# 43580120                                             1
# 43591340                                             2
#
#           calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 4952                                                0               0.57
# 11464                                               0               0.08
# 17884                                               0               0.11
# 21373                                               0               2.17
# 37512                                               0               1.53
# ...                                               ...                ...
# 43567384                                            0                NaN
# 43568844                                            0                NaN
# 43579879                                            0                NaN
# 43580120                                            0                NaN
# 43591340                                            0                NaN
#
# [7221 rows x 78 columns]

# %% [markdown]
# ###3.1.2 Imputation

# %%
## 設定SimpleImputer
""" Numerical """
## 缺失值以均值填充
imp_mean = SimpleImputer(missing_values = np.nan, strategy = 'mean')
## 缺失值以中位數填充
imp_median = SimpleImputer(missing_values = np.nan, strategy = 'median')
## 缺失值以眾数填充
imp_most_frequent = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
## 缺失值以自定義的值填充
imp_constant_fill_w_0 = SimpleImputer(missing_values = np.nan, strategy = 'constant', fill_value = 0)
imp_constant_fill_w_1 = SimpleImputer(missing_values = np.nan, strategy = 'constant', fill_value = 1)
# imp_constant_fill_w_EMPTY = SimpleImputer(missing_values = np.nan, strategy = 'constant', fill_value = 'EMPTY')
""" Object """
imp_constant_fill_w_missingValue = SimpleImputer(missing_values = np.nan, strategy = 'constant', fill_value = 'MISSING')

# %%
for col in df_imputation.columns:
    if df_imputation[col].isnull().values.sum() > 0:
        if df_imputation[col].dtype != object:
            # print(col, 'nu')
            # df_imputation[[col]] = imp_constant_fill_w_0.fit_transform(df_imputation[[col]])
            df_imputation[[col]] = imp_mean.fit_transform(df_imputation[[col]])
        else:
            # df_imputation[[col]] = imp_most_frequent.fit_transform(df_imputation[[col]])
            df_imputation[[col]] = imp_constant_fill_w_missingValue.fit_transform(df_imputation[[col]])

# %%
df_imputations = [None] * 3
df_imputations[0] = df_imputation

# %% [markdown]
# <!-- ###3.1.4 Imbalance -->

# %% [markdown]
# ##3.2 df-Reviews

# %%
dfs[1]
# Out:
#                             neighbourhood
# neighbourhood_group
# NaN                              Campbell
# NaN                             Cupertino
# NaN                                Gilroy
# NaN                             Los Altos
# NaN                       Los Altos Hills
# NaN                             Los Gatos
# NaN                              Milpitas
# NaN                          Monte Sereno
# NaN                           Morgan Hill
# NaN                         Mountain View
# NaN                             Palo Alto
# NaN                              San Jose
# NaN                           Santa Clara
# NaN                              Saratoga
# NaN                             Sunnyvale
# NaN                  Unincorporated Areas

# %%
dfs[1].reset_index(inplace=True)

# %%
df_imputation_1 = dfs[1].drop('neighbourhood_group', axis=1)
# df_imputation_1
df_imputations[1] = df_imputation_1

# %% [markdown]
# ##3.3 df-Neighbourhoods

# %%
dfs[2]
# Out:
#                   date
# listing_id
# 4952        2009-08-02
# 4952        2009-09-04
# 4952        2009-10-16
# 4952        2009-12-10
# 4952        2010-06-08
# ...                ...
# 43557408    2020-06-08
# 43560334    2020-06-04
# 43624287    2020-06-04
# 43652101    2020-06-04
# 43652101    2020-06-07
#
# [212513 rows x 1 columns]

# %%
df_imputation_2 = dfs[2].reset_index()
df_imputations[2] = df_imputation_2

# %% [markdown]
# #4 Plotting

# %% [markdown]
# ##4.1 df-Listing

# %% [markdown]
# ##4.1.1 Cor Heatmaps

# %% [markdown]
# w/o Imputation

# %%
df = dfs_0_dropped[dfs_0_dropped.columns.to_list()[:]]
df_corr = df._get_numeric_data().astype(float).corr()
plt.figure(figsize=(20, 20))
sns.heatmap(df_corr,
            square=True, cmap='RdBu_r', linewidths=.5,
            annot=True, fmt='.2f').figure.tight_layout()
plt.show()

# %% [markdown]
# #### w/ Imputation

# %%
df_imputations[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7221 entries, 4952 to 43591340
# Data columns (total 78 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   last_scraped                                  7221 non-null   object
#  1   host_id                                       7221 non-null   int64
#  2   host_name                                     7221 non-null   object
#  3   host_since                                    7221 non-null   object
#  4   host_response_rate                            7221 non-null   object
#  5   host_acceptance_rate                          7221 non-null   object
#  6   host_neighbourhood                            7221 non-null   object
#  7   host_listings_count                           7221 non-null   float64
#  8   host_total_listings_count                     7221 non-null   float64
#  9   host_has_profile_pic                          7221 non-null   object
#  10  host_identity_verified                        7221 non-null   object
#  11  street                                        7221 non-null   object
#  12  neighbourhood                                 7221 non-null   object
#  13  neighbourhood_cleansed                        7221 non-null   object
#  14  city                                          7221 non-null   object
#  15  state                                         7221 non-null   object
#  16  zipcode                                       7221 non-null   object
#  17  market                                        7221 non-null   object
#  18  smart_location                                7221 non-null   object
#  19  country_code                                  7221 non-null   object
#  20  country                                       7221 non-null   object
#  21  latitude                                      7221 non-null   float64
#  22  longitude                                     7221 non-null   float64
#  23  is_location_exact                             7221 non-null   object
#  24  property_type                                 7221 non-null   object
#  25  room_type                                     7221 non-null   object
#  26  accommodates                                  7221 non-null   int64
#  27  bathrooms                                     7221 non-null   float64
#  28  bedrooms                                      7221 non-null   float64
#  29  beds                                          7221 non-null   float64
#  30  bed_type                                      7221 non-null   object
#  31  amenities                                     7221 non-null   object
#  32  square_feet                                   7221 non-null   float64
#  33  price                                         7221 non-null   float64
#  34  weekly_price                                  7221 non-null   float64
#  35  monthly_price                                 7221 non-null   float64
#  36  security_deposit                              7221 non-null   object
#  37  cleaning_fee                                  7221 non-null   object
#  38  guests_included                               7221 non-null   int64
#  39  extra_people                                  7221 non-null   object
#  40  minimum_nights                                7221 non-null   int64
#  41  maximum_nights                                7221 non-null   int64
#  42  minimum_minimum_nights                        7221 non-null   int64
#  43  maximum_minimum_nights                        7221 non-null   int64
#  44  minimum_maximum_nights                        7221 non-null   int64
#  45  maximum_maximum_nights                        7221 non-null   int64
#  46  minimum_nights_avg_ntm                        7221 non-null   float64
#  47  maximum_nights_avg_ntm                        7221 non-null   float64
#  48  calendar_updated                              7221 non-null   object
#  49  has_availability                              7221 non-null   object
#  50  availability_30                               7221 non-null   int64
#  51  availability_60                               7221 non-null   int64
#  52  availability_90                               7221 non-null   int64
#  53  availability_365                              7221 non-null   int64
#  54  calendar_last_scraped                         7221 non-null   object
#  55  number_of_reviews                             7221 non-null   int64
#  56  number_of_reviews_ltm                         7221 non-null   int64
#  57  first_review                                  7221 non-null   object
#  58  last_review                                   7221 non-null   object
#  59  review_scores_rating                          7221 non-null   float64
#  60  review_scores_accuracy                        7221 non-null   float64
#  61  review_scores_cleanliness                     7221 non-null   float64
#  62  review_scores_checkin                         7221 non-null   float64
#  63  review_scores_communication                   7221 non-null   float64
#  64  review_scores_location                        7221 non-null   float64
#  65  review_scores_value                           7221 non-null   float64
#  66  requires_license                              7221 non-null   object
#  67  jurisdiction_names                            7221 non-null   object
#  68  instant_bookable                              7221 non-null   object
#  69  is_business_travel_ready                      7221 non-null   object
#  70  cancellation_policy                           7221 non-null   object
#  71  require_guest_profile_picture                 7221 non-null   object
#  72  require_guest_phone_verification              7221 non-null   object
#  73  calculated_host_listings_count                7221 non-null   int64
#  74  calculated_host_listings_count_entire_homes   7221 non-null   int64
#  75  calculated_host_listings_count_private_rooms  7221 non-null   int64
#  76  calculated_host_listings_count_shared_rooms   7221 non-null   int64
#  77  reviews_per_month                             7221 non-null   float64
# dtypes: float64(21), int64(19), object(38)
# memory usage: 4.4+ MB

# %%
df = df_imputations[0][df_imputations[0].columns.to_list()[:]]
df_corr = df._get_numeric_data().astype(float).corr()

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df_corr,
            square=True, cmap='RdBu_r', linewidths=.5,
            annot=True, fmt='.2f').figure.tight_layout()
plt.show()

# %% [markdown]
# ###4.1.2 Xis value_counts() (already on kaggle)

# %% [markdown]
# #### w/o imputation

# %%
df = dfs_0_dropped
quan = list(df.loc[:, df.dtypes != 'object'].columns.values)
plt.figure(figsize=(30, 30))
# quan = list(df.loc[:, df.dtypes != 'object'].columns.values)
grid = sns.FacetGrid(pd.melt(df, value_vars=quan),
                     col='variable', col_wrap=4, height=3, aspect=1,
                     sharex=False, sharey=False)
grid.map(plt.hist, 'value', color="steelblue")
plt.show()

# %% [markdown]
# #### w/ Imputation

# %%
df = df_imputations[0]
quan = list(df.loc[:, df.dtypes != 'object'].columns.values)
plt.figure(figsize=(30, 30))
# quan = list(df.loc[:, df.dtypes != 'object'].columns.values)
grid = sns.FacetGrid(pd.melt(df, value_vars=quan),
                     col='variable', col_wrap=4, height=3, aspect=1,
                     sharex=False, sharey=False)
grid.map(plt.hist, 'value', color="steelblue")
plt.show()

# %% [markdown]
# ###4.1.3 Y vs Per Xi (any one has Tableau?)

# %% [markdown]
# #### w/o Imputation

# %%
df = dfs_0_dropped
# Visualize correlations between dependent and numerial independent variables
print(len(quan))
start = 0
leng = 10
for i in range(len(quan) // leng):
    if not quan[start:start + leng]: 
        break
    sns.pairplot(data=df, y_vars=['price'], x_vars=quan[start:start + leng], kind='reg',
            height=3, aspect=1.0)
    start += leng
    # print(start, start + leng)
    plt.show()
# Out:
# 40

# %% [markdown]
# #### w/ Imputation

# %%
# Visualize correlations between dependent and numerial independent variables
print(len(quan))
start = 0
leng = 10
for i in range(len(quan) // leng):
    if not quan[start:start + leng]: 
        break
    sns.pairplot(data=df, y_vars=['price'], x_vars=quan[start:start + leng], kind='reg',
            height=3, aspect=1.0)
    start += leng
    # print(start, start + leng)
    plt.show()
# Out:
# 40

# %%
quan
# Out:
# ['host_id',
#  'host_listings_count',
#  'host_total_listings_count',
#  'latitude',
#  'longitude',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'guests_included',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']
