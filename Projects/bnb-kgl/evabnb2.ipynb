# %%
# #importing necessery libraries for future analysis of the dataset
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# %matplotlib inline
# import seaborn as sns
# pd.set_option("display.max_rows", None, "display.max_columns", None)
# from pprint import pprint
# from IPython.display import display, HTML
# import matplotlib.pyplot as plt
# import pandas as pd
# import string
# from matplotlib import rcParams
# from nltk import WordNetLemmatizer
# from wordcloud import WordCloud, STOPWORDS
# from nltk.corpus import stopwords
# from nltk import pos_tag, sent_tokenize, word_tokenize, BigramAssocMeasures,\
#     BigramCollocationFinder, TrigramAssocMeasures, TrigramCollocationFinder
# from subprocess import check_output
# print(check_output(["ls", "../input"]).decode("utf8"))
# from collections import Counter
# #load libraries
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import Lasso
# from sklearn.feature_selection import SelectFromModel
# from sklearn.preprocessing import StandardScaler
# # Import libraries
# from sklearn import preprocessing
# from sklearn.preprocessing import LabelEncoder
# from sklearn.preprocessing import StandardScaler
# from sklearn.model_selection import train_test_split
# from sklearn import tree
# from sklearn.ensemble import RandomForestClassifier

# %%
# #using pandas library and 'read_csv' function to read BlackFriday csv file as file already formated for us from Kaggle
# airbnb=pd.read_csv("../input/bay-area-airbnb-data-updated-2020/Airbnb_Listings.csv")
# #examing head of BlackFriday csv file 
# airbnb.head(3)

# %%
# feature_df = airbnb[['id','listing_url','name']]

# %%
# feature_df.head()

# %%
# neighbourhoods = pd.read_csv("../input/bay-area-airbnb-data-updated-2020/neighbourhoods.csv")
# neighbourhoods.head(100)

# %%
#importing necessery libraries for future analysis of the dataset
from IPython.display import display, HTML
import string

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib.image as mpimg
from subprocess import check_output
from pprint import pprint
# from wordcloud import WordCloud, STOPWORDS

from collections import Counter

# %matplotlib inline
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
# from nltk.corpus import stopwords
# from nltk import WordNetLemmatizer
# from nltk import pos_tag,  sent_tokenize,word_tokenize, BigramAssocMeasures,\
#     BigramCollocationFinder, TrigramAssocMeasures, TrigramCollocationFinder
# print(check_output(["ls", "../input"]).decode("utf8"))

# %%
#using pandas library and 'read_csv' function to read BlackFriday csv file as file already formated for us from Kaggle
airbnb = pd.read_csv("./airbnb/Airbnb_Listings.csv")

# examing head of BlackFriday csv file

airbnb.head(3)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   4952   https://www.airbnb.com/rooms/4952  20200530151957   2020-05-30
# 1  11464  https://www.airbnb.com/rooms/11464  20200530151957   2020-05-31
# 2  17884  https://www.airbnb.com/rooms/17884  20200530151957   2020-05-31
#
#                                 name  \
# 0  Butterfly Inn - Graceful Living !
# 1  Deluxe Private Studio-custom int.
# 2               Silicon Valley Suite
#
#                                              summary  \
# 0  Lovely garden setting in a serene and art-fill...
# 1  Custom built Studio with exquisite design. Rea...
# 2  A guest suite for one or two, in a house in a ...
#
#                                                space  \
# 0  Very comfortable Queen bed and small desk in b...
# 1  Description A favorite for international corpo...
# 2  This is a private suite at the rear of a house...
#
#                                          description experiences_offered  \
# 0  Lovely garden setting in a serene and art-fill...                none
# 1  Custom built Studio with exquisite design. Rea...                none
# 2  A guest suite for one or two, in a house in a ...                none
#
#                                neighborhood_overview  \
# 0  Located in Professorville, Palo Alto, one of t...
# 1  10 min. to Lucky's and Starbucks at El Camino ...
# 2  This is a very quiet family neighborhood, but ...
#
#                                                notes  \
# 0  Housekeeping every Monday, leave your door ope...
# 1  Pet Policy: - Well Behaved pet up to 25 lb. of...
# 2  I cannot accommodate cats, sorry. I can usuall...
#
#                                              transit  \
# 0  Walking distance to Stanford University (30 mi...
# 1  Public transportation at Homestead and Pomeroy...
# 2  The CalTrain station is in walking distance, a...
#
#                                               access  \
# 0  Kitchen, laundry, family/TV room, garden, free...
# 1          Complimentary Wifi-internet + Basic Cable
# 2  Private outdoor patio. Shared washer/dryer on ...
#
#                                          interaction  \
# 0  Welcome and Orientation. Shared kitchen, garde...
# 1  Available any time for support and problem res...
# 2  I am usually in town.  Guests have a private e...
#
#                                          house_rules  thumbnail_url  \
# 0  No shoes in the house beyond the hall or laund...            NaN
# 1  Can house a couple- bed type is a full size be...            NaN
# 2  This is a quiet neighborhood, and the suite sh...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/529448/3d7...
# 1         NaN  https://a0.muscache.com/im/pictures/121321/2c5...
# 2         NaN  https://a0.muscache.com/im/pictures/08c0f0aa-3...
#
#    xl_picture_url  host_id                                 host_url host_name  \
# 0             NaN     7054   https://www.airbnb.com/users/show/7054   Mei Lin
# 1             NaN    42458  https://www.airbnb.com/users/show/42458      Emey
# 2             NaN    69023  https://www.airbnb.com/users/show/69023     Janet
#
#    host_since                             host_location  \
# 0  2009-01-24      Palo Alto, California, United States
# 1  2009-09-30  Mountain View, California, United States
# 2  2010-01-08        Lynn Haven, Florida, United States
#
#                                           host_about host_response_time  \
# 0  I have lived and worked in Asia, Europe, Austr...     within an hour
# 1  I pride myself on attention to details and cus...     within an hour
# 2  I am a software engineer, recently retired fro...       within a day
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  98%                 t
# 1               100%                  90%                 f
# 2               100%                  50%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/7054/profile_...
# 1  https://a0.muscache.com/im/users/42458/profile...
# 2  https://a0.muscache.com/im/users/69023/profile...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/7054/profile_...          Palo Alto
# 1  https://a0.muscache.com/im/users/42458/profile...        Santa Clara
# 2  https://a0.muscache.com/im/users/69023/profile...          Palo Alto
#
#    host_listings_count  host_total_listings_count  \
# 0                  5.0                        5.0
# 1                 13.0                       13.0
# 2                  2.0                        2.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1                      ['email', 'phone', 'reviews']                    t
# 2               ['email', 'phone', 'reviews', 'kba']                    t
#
#   host_identity_verified                            street  neighbourhood  \
# 0                      f      Palo Alto, CA, United States      Palo Alto
# 1                      f    Santa Clara, CA, United States    Santa Clara
# 2                      t  Mountain View, CA, United States  Mountain View
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed           city state  \
# 0              Palo Alto                           NaN      Palo Alto    CA
# 1            Santa Clara                           NaN    Santa Clara    CA
# 2          Mountain View                           NaN  Mountain View    CA
#
#   zipcode         market     smart_location country_code        country  \
# 0   94301  South Bay, CA      Palo Alto, CA           US  United States
# 1   95051  South Bay, CA    Santa Clara, CA           US  United States
# 2   94041  South Bay, CA  Mountain View, CA           US  United States
#
#    latitude  longitude is_location_exact property_type        room_type  \
# 0  37.43972 -122.15672                 t         Villa     Private room
# 1  37.34342 -121.98829                 t     Apartment  Entire home/apt
# 2  37.38612 -122.07357                 t   Guest suite  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             2        2.0       1.0   1.0  Real Bed
# 1             1        1.0       NaN   1.0  Real Bed
# 2             2        1.0       1.0   1.0  Real Bed
#
#                                            amenities  square_feet   price  \
# 0  {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...          NaN  $90.00
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...        325.0  $85.00
# 2  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $65.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0      $440.00     $1,428.00            $0.00       $35.00                1
# 1          NaN     $2,100.00          $700.00      $250.00                1
# 2    $1,400.00     $2,800.00        $1,000.00          NaN                1
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $45.00               2             365                       2
# 1       $10.00              14             365                      14
# 2        $0.00              30             180                      30
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       2                     365                     365
# 1                      14                     365                     365
# 2                      30                     180                     180
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     2.0                   365.0     2 months ago
# 1                    14.0                   365.0     5 months ago
# 2                    30.0                   180.0      4 weeks ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0                0                0
# 1                t               30               60               90
# 2                t               29               59               89
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                 0            2020-05-30                 75
# 1               179            2020-05-31                  6
# 2               179            2020-05-31                  2
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      0   2009-08-02  2019-01-12                  96.0
# 1                      1   2014-06-15  2019-10-11                  87.0
# 2                      0   2018-11-20  2019-04-27                  90.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                    10.0                       10.0                   10.0
# 2                     8.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                          9.0                     9.0                  9.0
# 2                         10.0                    10.0                 10.0
#
#   requires_license  license       jurisdiction_names instant_bookable  \
# 0                f      NaN            {"PALO ALTO"}                f
# 1                f      NaN          {"SANTA CLARA"}                f
# 2                f      NaN  {"Mountain View"," CA"}                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     moderate
# 1                        f                     moderate
# 2                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                t
# 2                             f                                f
#
#    calculated_host_listings_count  \
# 0                               5
# 1                              12
# 2                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                           12
# 2                                            2
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             5
# 1                                             0
# 2                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.57
# 1                                            0               0.08
# 2                                            0               0.11

# %%
feature_df = airbnb[['id', 'listing_url', 'name']]

# %%
feature_df.head()
# Out:
#       id                         listing_url  \
# 0   4952   https://www.airbnb.com/rooms/4952
# 1  11464  https://www.airbnb.com/rooms/11464
# 2  17884  https://www.airbnb.com/rooms/17884
# 3  21373  https://www.airbnb.com/rooms/21373
# 4  37512  https://www.airbnb.com/rooms/37512
#
#                                   name
# 0    Butterfly Inn - Graceful Living !
# 1    Deluxe Private Studio-custom int.
# 2                 Silicon Valley Suite
# 3  Bonsai Garden Inn in Professorville
# 4    Private  room - Parking 3 carport

# %%
neighbourhoods = pd.read_csv("./airbnb/neighbourhoods.csv")
neighbourhoods.head(100)
# Out:
#     neighbourhood_group         neighbourhood
# 0                   NaN              Campbell
# 1                   NaN             Cupertino
# 2                   NaN                Gilroy
# 3                   NaN             Los Altos
# 4                   NaN       Los Altos Hills
# 5                   NaN             Los Gatos
# 6                   NaN              Milpitas
# 7                   NaN          Monte Sereno
# 8                   NaN           Morgan Hill
# 9                   NaN         Mountain View
# 10                  NaN             Palo Alto
# 11                  NaN              San Jose
# 12                  NaN           Santa Clara
# 13                  NaN              Saratoga
# 14                  NaN             Sunnyvale
# 15                  NaN  Unincorporated Areas

# %%
airbnb.describe(include='all')
# Out:
#                   id                        listing_url     scrape_id  \
# count   7.221000e+03                               7221  7.221000e+03
# unique           NaN                               7221           NaN
# top              NaN  https://www.airbnb.com/rooms/4952           NaN
# freq             NaN                                  1           NaN
# mean    2.623922e+07                                NaN  2.020053e+13
# std     1.236420e+07                                NaN  1.781373e+00
# min     4.952000e+03                                NaN  2.020053e+13
# 25%     1.624242e+07                                NaN  2.020053e+13
# 50%     2.818432e+07                                NaN  2.020053e+13
# 75%     3.749948e+07                                NaN  2.020053e+13
# max     4.359134e+07                                NaN  2.020053e+13
#
#        last_scraped                                              name  \
# count          7221                                              7220
# unique            2                                              7077
# top      2020-05-31  TRIBE ❤️ Deep Cleaned  2BR @ Great Mall Milpitas
# freq           4782                                                21
# mean            NaN                                               NaN
# std             NaN                                               NaN
# min             NaN                                               NaN
# 25%             NaN                                               NaN
# 50%             NaN                                               NaN
# 75%             NaN                                               NaN
# max             NaN                                               NaN
#
#                                                   summary  \
# count                                                6922
# unique                                               6051
# top     The HackerHome Network New to the Valley? Tran...
# freq                                                   44
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     space  \
# count                                                5514
# unique                                               4402
# top     At Zeus, we focus exclusively on 30 day+ stays...
# freq                                                  411
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               description experiences_offered  \
# count                                                6983                7221
# unique                                               6439                   1
# top     Dorm-style house in Silicon Valley. No-host, 5...                none
# freq                                                   20                7221
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#                                     neighborhood_overview  \
# count                                                4544
# unique                                               3508
# top     *Area Highlights* -Located in the Heart of the...
# freq                                                   31
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     notes  \
# count                                                3692
# unique                                               2746
# top     Parking is not included with your stay. Parkin...
# freq                                                   41
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   transit  \
# count                                                4136
# unique                                               3199
# top     This Flat Location is Uber/Lyft Accessible & C...
# freq                                                   67
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    access  \
# count                                                4104
# unique                                               3377
# top     • All utilities are included, including gas, e...
# freq                                                   29
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               interaction  \
# count                                                4253
# unique                                               3165
# top     We're available 24/7 via Text | Email | Emerge...
# freq                                                   64
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               house_rules  thumbnail_url  \
# count                                                4957            0.0
# unique                                               3717            NaN
# top     By reserving your stay with Tribe you hereby a...            NaN
# freq                                                  121            NaN
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#         medium_url                                        picture_url  \
# count          0.0                                               7221
# unique         NaN                                               7018
# top            NaN  https://a0.muscache.com/im/pictures/fab9b586-5...
# freq           NaN                                                 12
# mean           NaN                                                NaN
# std            NaN                                                NaN
# min            NaN                                                NaN
# 25%            NaN                                                NaN
# 50%            NaN                                                NaN
# 75%            NaN                                                NaN
# max            NaN                                                NaN
#
#         xl_picture_url       host_id  \
# count              0.0  7.221000e+03
# unique             NaN           NaN
# top                NaN           NaN
# freq               NaN           NaN
# mean               NaN  8.886443e+07
# std                NaN  9.390593e+07
# min                NaN  7.054000e+03
# 25%                NaN  1.697278e+07
# 50%                NaN  4.800549e+07
# 75%                NaN  1.429331e+08
# max                NaN  3.477992e+08
#
#                                           host_url host_name  host_since  \
# count                                         7221      7220        7220
# unique                                        3533      2102        2084
# top     https://www.airbnb.com/users/show/48005494      Zeus  2015-11-02
# freq                                           411       411         412
# mean                                           NaN       NaN         NaN
# std                                            NaN       NaN         NaN
# min                                            NaN       NaN         NaN
# 25%                                            NaN       NaN         NaN
# 50%                                            NaN       NaN         NaN
# 75%                                            NaN       NaN         NaN
# max                                            NaN       NaN         NaN
#
#                               host_location  \
# count                                  7198
# unique                                  241
# top     San Jose, California, United States
# freq                                   1936
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#                                                host_about host_response_time  \
# count                                                4887               5414
# unique                                               2029                  4
# top     Zeus is reinventing corporate housing. We do t...     within an hour
# freq                                                  411               3993
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# min                                                   NaN                NaN
# 25%                                                   NaN                NaN
# 50%                                                   NaN                NaN
# 75%                                                   NaN                NaN
# max                                                   NaN                NaN
#
#        host_response_rate host_acceptance_rate host_is_superhost  \
# count                5414                 6507              7220
# unique                 43                   77                 2
# top                  100%                 100%                 f
# freq                 4389                 2218              3988
# mean                  NaN                  NaN               NaN
# std                   NaN                  NaN               NaN
# min                   NaN                  NaN               NaN
# 25%                   NaN                  NaN               NaN
# 50%                   NaN                  NaN               NaN
# 75%                   NaN                  NaN               NaN
# max                   NaN                  NaN               NaN
#
#                                        host_thumbnail_url  \
# count                                                7220
# unique                                               3528
# top     https://a0.muscache.com/im/pictures/user/7776f...
# freq                                                  411
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                          host_picture_url host_neighbourhood  \
# count                                                7220               6040
# unique                                               3528                144
# top     https://a0.muscache.com/im/pictures/user/7776f...        Santa Clara
# freq                                                  411                644
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# min                                                   NaN                NaN
# 25%                                                   NaN                NaN
# 50%                                                   NaN                NaN
# 75%                                                   NaN                NaN
# max                                                   NaN                NaN
#
#         host_listings_count  host_total_listings_count  \
# count           7220.000000                7220.000000
# unique                  NaN                        NaN
# top                     NaN                        NaN
# freq                    NaN                        NaN
# mean             139.588504                 139.588504
# std              472.674992                 472.674992
# min                0.000000                   0.000000
# 25%                1.000000                   1.000000
# 50%                3.000000                   3.000000
# 75%               10.000000                  10.000000
# max             2007.000000                2007.000000
#
#                                        host_verifications  \
# count                                                7221
# unique                                                240
# top     ['email', 'phone', 'reviews', 'jumio', 'govern...
# freq                                                  527
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        host_has_profile_pic host_identity_verified  \
# count                  7220                   7220
# unique                    2                      2
# top                       t                      f
# freq                   7215                   4061
# mean                    NaN                    NaN
# std                     NaN                    NaN
# min                     NaN                    NaN
# 25%                     NaN                    NaN
# 50%                     NaN                    NaN
# 75%                     NaN                    NaN
# max                     NaN                    NaN
#
#                              street neighbourhood neighbourhood_cleansed  \
# count                          7221          6738                   7221
# unique                           37            36                     16
# top     San Jose, CA, United States     Palo Alto               San Jose
# freq                           3028           786                   2882
# mean                            NaN           NaN                    NaN
# std                             NaN           NaN                    NaN
# min                             NaN           NaN                    NaN
# 25%                             NaN           NaN                    NaN
# 50%                             NaN           NaN                    NaN
# 75%                             NaN           NaN                    NaN
# max                             NaN           NaN                    NaN
#
#         neighbourhood_group_cleansed      city state zipcode         market  \
# count                            0.0      7220  7220    7166           7210
# unique                           NaN        34     4      82              4
# top                              NaN  San Jose    CA   95112  South Bay, CA
# freq                             NaN      3028  7216     363           5492
# mean                             NaN       NaN   NaN     NaN            NaN
# std                              NaN       NaN   NaN     NaN            NaN
# min                              NaN       NaN   NaN     NaN            NaN
# 25%                              NaN       NaN   NaN     NaN            NaN
# 50%                              NaN       NaN   NaN     NaN            NaN
# 75%                              NaN       NaN   NaN     NaN            NaN
# max                              NaN       NaN   NaN     NaN            NaN
#
#        smart_location country_code        country     latitude    longitude  \
# count            7221         7221           7221  7221.000000  7221.000000
# unique             37            1              1          NaN          NaN
# top      San Jose, CA           US  United States          NaN          NaN
# freq             3028         7221           7221          NaN          NaN
# mean              NaN          NaN            NaN    37.352285  -121.966600
# std               NaN          NaN            NaN     0.064819     0.108587
# min               NaN          NaN            NaN    36.965600  -122.190350
# 25%               NaN          NaN            NaN    37.319770  -122.042450
# 50%               NaN          NaN            NaN    37.358260  -121.961940
# 75%               NaN          NaN            NaN    37.398250  -121.886340
# max               NaN          NaN            NaN    37.462980  -121.380120
#
#        is_location_exact property_type     room_type  accommodates  \
# count               7221          7221          7221   7221.000000
# unique                 2            28             4           NaN
# top                    t         House  Private room           NaN
# freq                6796          3715          3454           NaN
# mean                 NaN           NaN           NaN      3.114804
# std                  NaN           NaN           NaN      2.370579
# min                  NaN           NaN           NaN      1.000000
# 25%                  NaN           NaN           NaN      2.000000
# 50%                  NaN           NaN           NaN      2.000000
# 75%                  NaN           NaN           NaN      4.000000
# max                  NaN           NaN           NaN     16.000000
#
#           bathrooms     bedrooms         beds  bed_type amenities  \
# count   7220.000000  7215.000000  7153.000000      7221      7221
# unique          NaN          NaN          NaN         5      6396
# top             NaN          NaN          NaN  Real Bed        {}
# freq            NaN          NaN          NaN      7156        36
# mean       1.383449     1.421760     1.817000       NaN       NaN
# std        0.688715     0.999833     1.633911       NaN       NaN
# min        0.000000     0.000000     0.000000       NaN       NaN
# 25%        1.000000     1.000000     1.000000       NaN       NaN
# 50%        1.000000     1.000000     1.000000       NaN       NaN
# 75%        2.000000     2.000000     2.000000       NaN       NaN
# max        8.000000     9.000000    54.000000       NaN       NaN
#
#         square_feet    price weekly_price monthly_price security_deposit  \
# count     29.000000     7221          574           592             5764
# unique          NaN      420          234           219               83
# top             NaN  $100.00      $450.00       $800.00            $0.00
# freq            NaN      205           21            28             1863
# mean     691.000000      NaN          NaN           NaN              NaN
# std      735.833492      NaN          NaN           NaN              NaN
# min       50.000000      NaN          NaN           NaN              NaN
# 25%      225.000000      NaN          NaN           NaN              NaN
# 50%      396.000000      NaN          NaN           NaN              NaN
# 75%      950.000000      NaN          NaN           NaN              NaN
# max     3600.000000      NaN          NaN           NaN              NaN
#
#        cleaning_fee  guests_included extra_people  minimum_nights  \
# count          6421      7221.000000         7221     7221.000000
# unique          167              NaN           63             NaN
# top          $50.00              NaN        $0.00             NaN
# freq            459              NaN         3414             NaN
# mean            NaN         1.699349          NaN        9.756959
# std             NaN         1.620945          NaN       34.689846
# min             NaN         1.000000          NaN        1.000000
# 25%             NaN         1.000000          NaN        1.000000
# 50%             NaN         1.000000          NaN        2.000000
# 75%             NaN         2.000000          NaN        7.000000
# max             NaN        16.000000          NaN     1125.000000
#
#         maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# count     7.221000e+03             7221.000000             7221.000000
# unique             NaN                     NaN                     NaN
# top                NaN                     NaN                     NaN
# freq               NaN                     NaN                     NaN
# mean      2.980880e+05                9.142916               14.247888
# std       2.527150e+07               35.027086               63.358607
# min       1.000000e+00                1.000000                1.000000
# 25%       6.000000e+01                1.000000                1.000000
# 50%       1.125000e+03                2.000000                2.000000
# 75%       1.125000e+03                5.000000                7.000000
# max       2.147484e+09             1125.000000             1125.000000
#
#         minimum_maximum_nights  maximum_maximum_nights  \
# count             7.221000e+03            7.221000e+03
# unique                     NaN                     NaN
# top                        NaN                     NaN
# freq                       NaN                     NaN
# mean              2.982325e+05            1.785205e+06
# std               2.527150e+07            6.188084e+07
# min               1.000000e+00            1.000000e+00
# 25%               3.650000e+02            3.650000e+02
# 50%               1.125000e+03            1.125000e+03
# 75%               1.125000e+03            1.125000e+03
# max               2.147484e+09            2.147484e+09
#
#         minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# count              7221.000000            7.221000e+03             7221
# unique                     NaN                     NaN               74
# top                        NaN                     NaN     3 months ago
# freq                       NaN                     NaN             1163
# mean                 13.631505            1.538945e+06              NaN
# std                  61.691820            5.347742e+07              NaN
# min                   1.000000            1.000000e+00              NaN
# 25%                   1.000000            3.650000e+02              NaN
# 50%                   2.000000            1.125000e+03              NaN
# 75%                   7.000000            1.125000e+03              NaN
# max                1125.000000            2.147484e+09              NaN
#
#        has_availability  availability_30  availability_60  availability_90  \
# count              7221      7221.000000      7221.000000      7221.000000
# unique                1              NaN              NaN              NaN
# top                   t              NaN              NaN              NaN
# freq               7221              NaN              NaN              NaN
# mean                NaN        13.689101        30.373494        48.260352
# std                 NaN        13.616884        26.501026        38.981316
# min                 NaN         0.000000         0.000000         0.000000
# 25%                 NaN         0.000000         0.000000         0.000000
# 50%                 NaN        10.000000        30.000000        59.000000
# 75%                 NaN        29.000000        59.000000        89.000000
# max                 NaN        30.000000        60.000000        90.000000
#
#         availability_365 calendar_last_scraped  number_of_reviews  \
# count        7221.000000                  7221        7221.000000
# unique               NaN                     2                NaN
# top                  NaN            2020-05-31                NaN
# freq                 NaN                  4782                NaN
# mean          160.282648                   NaN          29.853760
# std           141.746896                   NaN          51.488761
# min             0.000000                   NaN           0.000000
# 25%             1.000000                   NaN           1.000000
# 50%           136.000000                   NaN          10.000000
# 75%           323.000000                   NaN          35.000000
# max           365.000000                   NaN         488.000000
#
#         number_of_reviews_ltm first_review last_review  review_scores_rating  \
# count             7221.000000         5912        5912           5854.000000
# unique                    NaN         1926         795                   NaN
# top                       NaN   2019-05-10  2020-03-13                   NaN
# freq                      NaN           23         103                   NaN
# mean                 9.369201          NaN         NaN             95.245473
# std                 15.188236          NaN         NaN              7.734005
# min                  0.000000          NaN         NaN             20.000000
# 25%                  0.000000          NaN         NaN             94.000000
# 50%                  3.000000          NaN         NaN             98.000000
# 75%                 12.000000          NaN         NaN            100.000000
# max                154.000000          NaN         NaN            100.000000
#
#         review_scores_accuracy  review_scores_cleanliness  \
# count              5852.000000                5852.000000
# unique                     NaN                        NaN
# top                        NaN                        NaN
# freq                       NaN                        NaN
# mean                  9.723855                   9.572454
# std                   0.741816                   0.848685
# min                   2.000000                   2.000000
# 25%                  10.000000                   9.000000
# 50%                  10.000000                  10.000000
# 75%                  10.000000                  10.000000
# max                  10.000000                  10.000000
#
#         review_scores_checkin  review_scores_communication  \
# count             5851.000000                  5852.000000
# unique                    NaN                          NaN
# top                       NaN                          NaN
# freq                      NaN                          NaN
# mean                 9.815074                     9.793233
# std                  0.641301                     0.691503
# min                  2.000000                     2.000000
# 25%                 10.000000                    10.000000
# 50%                 10.000000                    10.000000
# 75%                 10.000000                    10.000000
# max                 10.000000                    10.000000
#
#         review_scores_location  review_scores_value requires_license  license  \
# count              5851.000000          5851.000000             7221      0.0
# unique                     NaN                  NaN                1      NaN
# top                        NaN                  NaN                f      NaN
# freq                       NaN                  NaN             7221      NaN
# mean                  9.796103             9.527773              NaN      NaN
# std                   0.583498             0.833306              NaN      NaN
# min                   2.000000             2.000000              NaN      NaN
# 25%                  10.000000             9.000000              NaN      NaN
# 50%                  10.000000            10.000000              NaN      NaN
# 75%                  10.000000            10.000000              NaN      NaN
# max                  10.000000            10.000000              NaN      NaN
#
#        jurisdiction_names instant_bookable is_business_travel_ready  \
# count                6242             7221                     7221
# unique                 10                2                        1
# top          {"SAN JOSE"}                f                        f
# freq                 2810             3987                     7221
# mean                  NaN              NaN                      NaN
# std                   NaN              NaN                      NaN
# min                   NaN              NaN                      NaN
# 25%                   NaN              NaN                      NaN
# 50%                   NaN              NaN                      NaN
# 75%                   NaN              NaN                      NaN
# max                   NaN              NaN                      NaN
#
#        cancellation_policy require_guest_profile_picture  \
# count                 7221                          7221
# unique                   4                             2
# top               flexible                             f
# freq                  2817                          6991
# mean                   NaN                           NaN
# std                    NaN                           NaN
# min                    NaN                           NaN
# 25%                    NaN                           NaN
# 50%                    NaN                           NaN
# 75%                    NaN                           NaN
# max                    NaN                           NaN
#
#        require_guest_phone_verification  calculated_host_listings_count  \
# count                              7221                     7221.000000
# unique                                2                             NaN
# top                                   f                             NaN
# freq                               6993                             NaN
# mean                                NaN                       32.048608
# std                                 NaN                       95.159193
# min                                 NaN                        1.000000
# 25%                                 NaN                        1.000000
# 50%                                 NaN                        3.000000
# 75%                                 NaN                        8.000000
# max                                 NaN                      411.000000
#
#         calculated_host_listings_count_entire_homes  \
# count                                   7221.000000
# unique                                          NaN
# top                                             NaN
# freq                                            NaN
# mean                                      28.216729
# std                                       95.714488
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# 75%                                        2.000000
# max                                      411.000000
#
#         calculated_host_listings_count_private_rooms  \
# count                                    7221.000000
# unique                                           NaN
# top                                              NaN
# freq                                             NaN
# mean                                        2.775793
# std                                         6.810433
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         1.000000
# 75%                                         3.000000
# max                                        62.000000
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                   7221.000000        5912.000000
# unique                                          NaN                NaN
# top                                             NaN                NaN
# freq                                            NaN                NaN
# mean                                       1.029359           1.357124
# std                                        5.741521           1.530782
# min                                        0.000000           0.010000
# 25%                                        0.000000           0.320000
# 50%                                        0.000000           0.830000
# 75%                                        0.000000           1.810000
# max                                       48.000000          13.120000

# %%
len(airbnb)
# Out:
# 7221

# %%
airbnb.describe(include='all')
# Out:
#                   id                        listing_url     scrape_id  \
# count   7.221000e+03                               7221  7.221000e+03
# unique           NaN                               7221           NaN
# top              NaN  https://www.airbnb.com/rooms/4952           NaN
# freq             NaN                                  1           NaN
# mean    2.623922e+07                                NaN  2.020053e+13
# std     1.236420e+07                                NaN  1.781373e+00
# min     4.952000e+03                                NaN  2.020053e+13
# 25%     1.624242e+07                                NaN  2.020053e+13
# 50%     2.818432e+07                                NaN  2.020053e+13
# 75%     3.749948e+07                                NaN  2.020053e+13
# max     4.359134e+07                                NaN  2.020053e+13
#
#        last_scraped                                              name  \
# count          7221                                              7220
# unique            2                                              7077
# top      2020-05-31  TRIBE ❤️ Deep Cleaned  2BR @ Great Mall Milpitas
# freq           4782                                                21
# mean            NaN                                               NaN
# std             NaN                                               NaN
# min             NaN                                               NaN
# 25%             NaN                                               NaN
# 50%             NaN                                               NaN
# 75%             NaN                                               NaN
# max             NaN                                               NaN
#
#                                                   summary  \
# count                                                6922
# unique                                               6051
# top     The HackerHome Network New to the Valley? Tran...
# freq                                                   44
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     space  \
# count                                                5514
# unique                                               4402
# top     At Zeus, we focus exclusively on 30 day+ stays...
# freq                                                  411
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               description experiences_offered  \
# count                                                6983                7221
# unique                                               6439                   1
# top     Dorm-style house in Silicon Valley. No-host, 5...                none
# freq                                                   20                7221
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#                                     neighborhood_overview  \
# count                                                4544
# unique                                               3508
# top     *Area Highlights* -Located in the Heart of the...
# freq                                                   31
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     notes  \
# count                                                3692
# unique                                               2746
# top     Parking is not included with your stay. Parkin...
# freq                                                   41
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   transit  \
# count                                                4136
# unique                                               3199
# top     This Flat Location is Uber/Lyft Accessible & C...
# freq                                                   67
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    access  \
# count                                                4104
# unique                                               3377
# top     • All utilities are included, including gas, e...
# freq                                                   29
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               interaction  \
# count                                                4253
# unique                                               3165
# top     We're available 24/7 via Text | Email | Emerge...
# freq                                                   64
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               house_rules  thumbnail_url  \
# count                                                4957            0.0
# unique                                               3717            NaN
# top     By reserving your stay with Tribe you hereby a...            NaN
# freq                                                  121            NaN
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#         medium_url                                        picture_url  \
# count          0.0                                               7221
# unique         NaN                                               7018
# top            NaN  https://a0.muscache.com/im/pictures/fab9b586-5...
# freq           NaN                                                 12
# mean           NaN                                                NaN
# std            NaN                                                NaN
# min            NaN                                                NaN
# 25%            NaN                                                NaN
# 50%            NaN                                                NaN
# 75%            NaN                                                NaN
# max            NaN                                                NaN
#
#         xl_picture_url       host_id  \
# count              0.0  7.221000e+03
# unique             NaN           NaN
# top                NaN           NaN
# freq               NaN           NaN
# mean               NaN  8.886443e+07
# std                NaN  9.390593e+07
# min                NaN  7.054000e+03
# 25%                NaN  1.697278e+07
# 50%                NaN  4.800549e+07
# 75%                NaN  1.429331e+08
# max                NaN  3.477992e+08
#
#                                           host_url host_name  host_since  \
# count                                         7221      7220        7220
# unique                                        3533      2102        2084
# top     https://www.airbnb.com/users/show/48005494      Zeus  2015-11-02
# freq                                           411       411         412
# mean                                           NaN       NaN         NaN
# std                                            NaN       NaN         NaN
# min                                            NaN       NaN         NaN
# 25%                                            NaN       NaN         NaN
# 50%                                            NaN       NaN         NaN
# 75%                                            NaN       NaN         NaN
# max                                            NaN       NaN         NaN
#
#                               host_location  \
# count                                  7198
# unique                                  241
# top     San Jose, California, United States
# freq                                   1936
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#                                                host_about host_response_time  \
# count                                                4887               5414
# unique                                               2029                  4
# top     Zeus is reinventing corporate housing. We do t...     within an hour
# freq                                                  411               3993
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# min                                                   NaN                NaN
# 25%                                                   NaN                NaN
# 50%                                                   NaN                NaN
# 75%                                                   NaN                NaN
# max                                                   NaN                NaN
#
#        host_response_rate host_acceptance_rate host_is_superhost  \
# count                5414                 6507              7220
# unique                 43                   77                 2
# top                  100%                 100%                 f
# freq                 4389                 2218              3988
# mean                  NaN                  NaN               NaN
# std                   NaN                  NaN               NaN
# min                   NaN                  NaN               NaN
# 25%                   NaN                  NaN               NaN
# 50%                   NaN                  NaN               NaN
# 75%                   NaN                  NaN               NaN
# max                   NaN                  NaN               NaN
#
#                                        host_thumbnail_url  \
# count                                                7220
# unique                                               3528
# top     https://a0.muscache.com/im/pictures/user/7776f...
# freq                                                  411
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                          host_picture_url host_neighbourhood  \
# count                                                7220               6040
# unique                                               3528                144
# top     https://a0.muscache.com/im/pictures/user/7776f...        Santa Clara
# freq                                                  411                644
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# min                                                   NaN                NaN
# 25%                                                   NaN                NaN
# 50%                                                   NaN                NaN
# 75%                                                   NaN                NaN
# max                                                   NaN                NaN
#
#         host_listings_count  host_total_listings_count  \
# count           7220.000000                7220.000000
# unique                  NaN                        NaN
# top                     NaN                        NaN
# freq                    NaN                        NaN
# mean             139.588504                 139.588504
# std              472.674992                 472.674992
# min                0.000000                   0.000000
# 25%                1.000000                   1.000000
# 50%                3.000000                   3.000000
# 75%               10.000000                  10.000000
# max             2007.000000                2007.000000
#
#                                        host_verifications  \
# count                                                7221
# unique                                                240
# top     ['email', 'phone', 'reviews', 'jumio', 'govern...
# freq                                                  527
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        host_has_profile_pic host_identity_verified  \
# count                  7220                   7220
# unique                    2                      2
# top                       t                      f
# freq                   7215                   4061
# mean                    NaN                    NaN
# std                     NaN                    NaN
# min                     NaN                    NaN
# 25%                     NaN                    NaN
# 50%                     NaN                    NaN
# 75%                     NaN                    NaN
# max                     NaN                    NaN
#
#                              street neighbourhood neighbourhood_cleansed  \
# count                          7221          6738                   7221
# unique                           37            36                     16
# top     San Jose, CA, United States     Palo Alto               San Jose
# freq                           3028           786                   2882
# mean                            NaN           NaN                    NaN
# std                             NaN           NaN                    NaN
# min                             NaN           NaN                    NaN
# 25%                             NaN           NaN                    NaN
# 50%                             NaN           NaN                    NaN
# 75%                             NaN           NaN                    NaN
# max                             NaN           NaN                    NaN
#
#         neighbourhood_group_cleansed      city state zipcode         market  \
# count                            0.0      7220  7220    7166           7210
# unique                           NaN        34     4      82              4
# top                              NaN  San Jose    CA   95112  South Bay, CA
# freq                             NaN      3028  7216     363           5492
# mean                             NaN       NaN   NaN     NaN            NaN
# std                              NaN       NaN   NaN     NaN            NaN
# min                              NaN       NaN   NaN     NaN            NaN
# 25%                              NaN       NaN   NaN     NaN            NaN
# 50%                              NaN       NaN   NaN     NaN            NaN
# 75%                              NaN       NaN   NaN     NaN            NaN
# max                              NaN       NaN   NaN     NaN            NaN
#
#        smart_location country_code        country     latitude    longitude  \
# count            7221         7221           7221  7221.000000  7221.000000
# unique             37            1              1          NaN          NaN
# top      San Jose, CA           US  United States          NaN          NaN
# freq             3028         7221           7221          NaN          NaN
# mean              NaN          NaN            NaN    37.352285  -121.966600
# std               NaN          NaN            NaN     0.064819     0.108587
# min               NaN          NaN            NaN    36.965600  -122.190350
# 25%               NaN          NaN            NaN    37.319770  -122.042450
# 50%               NaN          NaN            NaN    37.358260  -121.961940
# 75%               NaN          NaN            NaN    37.398250  -121.886340
# max               NaN          NaN            NaN    37.462980  -121.380120
#
#        is_location_exact property_type     room_type  accommodates  \
# count               7221          7221          7221   7221.000000
# unique                 2            28             4           NaN
# top                    t         House  Private room           NaN
# freq                6796          3715          3454           NaN
# mean                 NaN           NaN           NaN      3.114804
# std                  NaN           NaN           NaN      2.370579
# min                  NaN           NaN           NaN      1.000000
# 25%                  NaN           NaN           NaN      2.000000
# 50%                  NaN           NaN           NaN      2.000000
# 75%                  NaN           NaN           NaN      4.000000
# max                  NaN           NaN           NaN     16.000000
#
#           bathrooms     bedrooms         beds  bed_type amenities  \
# count   7220.000000  7215.000000  7153.000000      7221      7221
# unique          NaN          NaN          NaN         5      6396
# top             NaN          NaN          NaN  Real Bed        {}
# freq            NaN          NaN          NaN      7156        36
# mean       1.383449     1.421760     1.817000       NaN       NaN
# std        0.688715     0.999833     1.633911       NaN       NaN
# min        0.000000     0.000000     0.000000       NaN       NaN
# 25%        1.000000     1.000000     1.000000       NaN       NaN
# 50%        1.000000     1.000000     1.000000       NaN       NaN
# 75%        2.000000     2.000000     2.000000       NaN       NaN
# max        8.000000     9.000000    54.000000       NaN       NaN
#
#         square_feet    price weekly_price monthly_price security_deposit  \
# count     29.000000     7221          574           592             5764
# unique          NaN      420          234           219               83
# top             NaN  $100.00      $450.00       $800.00            $0.00
# freq            NaN      205           21            28             1863
# mean     691.000000      NaN          NaN           NaN              NaN
# std      735.833492      NaN          NaN           NaN              NaN
# min       50.000000      NaN          NaN           NaN              NaN
# 25%      225.000000      NaN          NaN           NaN              NaN
# 50%      396.000000      NaN          NaN           NaN              NaN
# 75%      950.000000      NaN          NaN           NaN              NaN
# max     3600.000000      NaN          NaN           NaN              NaN
#
#        cleaning_fee  guests_included extra_people  minimum_nights  \
# count          6421      7221.000000         7221     7221.000000
# unique          167              NaN           63             NaN
# top          $50.00              NaN        $0.00             NaN
# freq            459              NaN         3414             NaN
# mean            NaN         1.699349          NaN        9.756959
# std             NaN         1.620945          NaN       34.689846
# min             NaN         1.000000          NaN        1.000000
# 25%             NaN         1.000000          NaN        1.000000
# 50%             NaN         1.000000          NaN        2.000000
# 75%             NaN         2.000000          NaN        7.000000
# max             NaN        16.000000          NaN     1125.000000
#
#         maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# count     7.221000e+03             7221.000000             7221.000000
# unique             NaN                     NaN                     NaN
# top                NaN                     NaN                     NaN
# freq               NaN                     NaN                     NaN
# mean      2.980880e+05                9.142916               14.247888
# std       2.527150e+07               35.027086               63.358607
# min       1.000000e+00                1.000000                1.000000
# 25%       6.000000e+01                1.000000                1.000000
# 50%       1.125000e+03                2.000000                2.000000
# 75%       1.125000e+03                5.000000                7.000000
# max       2.147484e+09             1125.000000             1125.000000
#
#         minimum_maximum_nights  maximum_maximum_nights  \
# count             7.221000e+03            7.221000e+03
# unique                     NaN                     NaN
# top                        NaN                     NaN
# freq                       NaN                     NaN
# mean              2.982325e+05            1.785205e+06
# std               2.527150e+07            6.188084e+07
# min               1.000000e+00            1.000000e+00
# 25%               3.650000e+02            3.650000e+02
# 50%               1.125000e+03            1.125000e+03
# 75%               1.125000e+03            1.125000e+03
# max               2.147484e+09            2.147484e+09
#
#         minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# count              7221.000000            7.221000e+03             7221
# unique                     NaN                     NaN               74
# top                        NaN                     NaN     3 months ago
# freq                       NaN                     NaN             1163
# mean                 13.631505            1.538945e+06              NaN
# std                  61.691820            5.347742e+07              NaN
# min                   1.000000            1.000000e+00              NaN
# 25%                   1.000000            3.650000e+02              NaN
# 50%                   2.000000            1.125000e+03              NaN
# 75%                   7.000000            1.125000e+03              NaN
# max                1125.000000            2.147484e+09              NaN
#
#        has_availability  availability_30  availability_60  availability_90  \
# count              7221      7221.000000      7221.000000      7221.000000
# unique                1              NaN              NaN              NaN
# top                   t              NaN              NaN              NaN
# freq               7221              NaN              NaN              NaN
# mean                NaN        13.689101        30.373494        48.260352
# std                 NaN        13.616884        26.501026        38.981316
# min                 NaN         0.000000         0.000000         0.000000
# 25%                 NaN         0.000000         0.000000         0.000000
# 50%                 NaN        10.000000        30.000000        59.000000
# 75%                 NaN        29.000000        59.000000        89.000000
# max                 NaN        30.000000        60.000000        90.000000
#
#         availability_365 calendar_last_scraped  number_of_reviews  \
# count        7221.000000                  7221        7221.000000
# unique               NaN                     2                NaN
# top                  NaN            2020-05-31                NaN
# freq                 NaN                  4782                NaN
# mean          160.282648                   NaN          29.853760
# std           141.746896                   NaN          51.488761
# min             0.000000                   NaN           0.000000
# 25%             1.000000                   NaN           1.000000
# 50%           136.000000                   NaN          10.000000
# 75%           323.000000                   NaN          35.000000
# max           365.000000                   NaN         488.000000
#
#         number_of_reviews_ltm first_review last_review  review_scores_rating  \
# count             7221.000000         5912        5912           5854.000000
# unique                    NaN         1926         795                   NaN
# top                       NaN   2019-05-10  2020-03-13                   NaN
# freq                      NaN           23         103                   NaN
# mean                 9.369201          NaN         NaN             95.245473
# std                 15.188236          NaN         NaN              7.734005
# min                  0.000000          NaN         NaN             20.000000
# 25%                  0.000000          NaN         NaN             94.000000
# 50%                  3.000000          NaN         NaN             98.000000
# 75%                 12.000000          NaN         NaN            100.000000
# max                154.000000          NaN         NaN            100.000000
#
#         review_scores_accuracy  review_scores_cleanliness  \
# count              5852.000000                5852.000000
# unique                     NaN                        NaN
# top                        NaN                        NaN
# freq                       NaN                        NaN
# mean                  9.723855                   9.572454
# std                   0.741816                   0.848685
# min                   2.000000                   2.000000
# 25%                  10.000000                   9.000000
# 50%                  10.000000                  10.000000
# 75%                  10.000000                  10.000000
# max                  10.000000                  10.000000
#
#         review_scores_checkin  review_scores_communication  \
# count             5851.000000                  5852.000000
# unique                    NaN                          NaN
# top                       NaN                          NaN
# freq                      NaN                          NaN
# mean                 9.815074                     9.793233
# std                  0.641301                     0.691503
# min                  2.000000                     2.000000
# 25%                 10.000000                    10.000000
# 50%                 10.000000                    10.000000
# 75%                 10.000000                    10.000000
# max                 10.000000                    10.000000
#
#         review_scores_location  review_scores_value requires_license  license  \
# count              5851.000000          5851.000000             7221      0.0
# unique                     NaN                  NaN                1      NaN
# top                        NaN                  NaN                f      NaN
# freq                       NaN                  NaN             7221      NaN
# mean                  9.796103             9.527773              NaN      NaN
# std                   0.583498             0.833306              NaN      NaN
# min                   2.000000             2.000000              NaN      NaN
# 25%                  10.000000             9.000000              NaN      NaN
# 50%                  10.000000            10.000000              NaN      NaN
# 75%                  10.000000            10.000000              NaN      NaN
# max                  10.000000            10.000000              NaN      NaN
#
#        jurisdiction_names instant_bookable is_business_travel_ready  \
# count                6242             7221                     7221
# unique                 10                2                        1
# top          {"SAN JOSE"}                f                        f
# freq                 2810             3987                     7221
# mean                  NaN              NaN                      NaN
# std                   NaN              NaN                      NaN
# min                   NaN              NaN                      NaN
# 25%                   NaN              NaN                      NaN
# 50%                   NaN              NaN                      NaN
# 75%                   NaN              NaN                      NaN
# max                   NaN              NaN                      NaN
#
#        cancellation_policy require_guest_profile_picture  \
# count                 7221                          7221
# unique                   4                             2
# top               flexible                             f
# freq                  2817                          6991
# mean                   NaN                           NaN
# std                    NaN                           NaN
# min                    NaN                           NaN
# 25%                    NaN                           NaN
# 50%                    NaN                           NaN
# 75%                    NaN                           NaN
# max                    NaN                           NaN
#
#        require_guest_phone_verification  calculated_host_listings_count  \
# count                              7221                     7221.000000
# unique                                2                             NaN
# top                                   f                             NaN
# freq                               6993                             NaN
# mean                                NaN                       32.048608
# std                                 NaN                       95.159193
# min                                 NaN                        1.000000
# 25%                                 NaN                        1.000000
# 50%                                 NaN                        3.000000
# 75%                                 NaN                        8.000000
# max                                 NaN                      411.000000
#
#         calculated_host_listings_count_entire_homes  \
# count                                   7221.000000
# unique                                          NaN
# top                                             NaN
# freq                                            NaN
# mean                                      28.216729
# std                                       95.714488
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# 75%                                        2.000000
# max                                      411.000000
#
#         calculated_host_listings_count_private_rooms  \
# count                                    7221.000000
# unique                                           NaN
# top                                              NaN
# freq                                             NaN
# mean                                        2.775793
# std                                         6.810433
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         1.000000
# 75%                                         3.000000
# max                                        62.000000
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                   7221.000000        5912.000000
# unique                                          NaN                NaN
# top                                             NaN                NaN
# freq                                            NaN                NaN
# mean                                       1.029359           1.357124
# std                                        5.741521           1.530782
# min                                        0.000000           0.010000
# 25%                                        0.000000           0.320000
# 50%                                        0.000000           0.830000
# 75%                                        0.000000           1.810000
# max                                       48.000000          13.120000

# %%
airbnb['host_tenure_year']= (pd.Timestamp.now() - pd.to_datetime(airbnb['host_since'], errors='coerce')).astype("timedelta64[Y]").astype(int, errors='ignore')
airbnb['host_tenure_year'] = airbnb['host_tenure_year'].fillna(0)
airbnb['host_tenure_year'] .isnull().sum()
# Out:
# 0

# %%
feature_df=pd.concat([feature_df, airbnb['host_tenure_year'].fillna(0)], axis=1)

# %%
type(airbnb['host_tenure_year'])
feature_df.head()
# Out:
#       id                         listing_url  \
# 0   4952   https://www.airbnb.com/rooms/4952
# 1  11464  https://www.airbnb.com/rooms/11464
# 2  17884  https://www.airbnb.com/rooms/17884
# 3  21373  https://www.airbnb.com/rooms/21373
# 4  37512  https://www.airbnb.com/rooms/37512
#
#                                   name  host_tenure_year
# 0    Butterfly Inn - Graceful Living !              13.0
# 1    Deluxe Private Studio-custom int.              12.0
# 2                 Silicon Valley Suite              12.0
# 3  Bonsai Garden Inn in Professorville              13.0
# 4    Private  room - Parking 3 carport              11.0

# %%
airbnb['host_tenure_year'].value_counts().sort_values()
# Out:
# 0.0        1
# 13.0       5
# 12.0      67
# 11.0      75
# 1.0       78
# 10.0     301
# 9.0      454
# 8.0      599
# 2.0      645
# 4.0      685
# 3.0      772
# 5.0      817
# 7.0     1015
# 6.0     1707
# Name: host_tenure_year, dtype: int64

# %%
airbnb.host_response_time.value_counts()
# Out:
# within an hour        3993
# within a few hours     862
# within a day           411
# a few days or more     148
# Name: host_response_time, dtype: int64

# %%
len(airbnb)
# Out:
# 7221

# %%
#checking type of every column in the dataset
airbnb.dtypes
# Out:
# id                                                int64
# listing_url                                      object
# scrape_id                                         int64
# last_scraped                                     object
# name                                             object
# summary                                          object
# space                                            object
# description                                      object
# experiences_offered                              object
# neighborhood_overview                            object
# notes                                            object
# transit                                          object
# access                                           object
# interaction                                      object
# house_rules                                      object
# thumbnail_url                                   float64
# medium_url                                      float64
# picture_url                                      object
# xl_picture_url                                  float64
# host_id                                           int64
# host_url                                         object
# host_name                                        object
# host_since                                       object
# host_location                                    object
# host_about                                       object
# host_response_time                               object
# host_response_rate                               object
# host_acceptance_rate                             object
# host_is_superhost                                object
# host_thumbnail_url                               object
# host_picture_url                                 object
# host_neighbourhood                               object
# host_listings_count                             float64
# host_total_listings_count                       float64
# host_verifications                               object
# host_has_profile_pic                             object
# host_identity_verified                           object
# street                                           object
# neighbourhood                                    object
# neighbourhood_cleansed                           object
# neighbourhood_group_cleansed                    float64
# city                                             object
# state                                            object
# zipcode                                          object
# market                                           object
# smart_location                                   object
# country_code                                     object
# country                                          object
# latitude                                        float64
# longitude                                       float64
# is_location_exact                                object
# property_type                                    object
# room_type                                        object
# accommodates                                      int64
# bathrooms                                       float64
# bedrooms                                        float64
# beds                                            float64
# bed_type                                         object
# amenities                                        object
# square_feet                                     float64
# price                                            object
# weekly_price                                     object
# monthly_price                                    object
# security_deposit                                 object
# cleaning_fee                                     object
# guests_included                                   int64
# extra_people                                     object
# minimum_nights                                    int64
# maximum_nights                                    int64
# minimum_minimum_nights                            int64
# maximum_minimum_nights                            int64
# minimum_maximum_nights                            int64
# maximum_maximum_nights                            int64
# minimum_nights_avg_ntm                          float64
# maximum_nights_avg_ntm                          float64
# calendar_updated                                 object
# has_availability                                 object
# availability_30                                   int64
# availability_60                                   int64
# availability_90                                   int64
# availability_365                                  int64
# calendar_last_scraped                            object
# number_of_reviews                                 int64
# number_of_reviews_ltm                             int64
# first_review                                     object
# last_review                                      object
# review_scores_rating                            float64
# review_scores_accuracy                          float64
# review_scores_cleanliness                       float64
# review_scores_checkin                           float64
# review_scores_communication                     float64
# review_scores_location                          float64
# review_scores_value                             float64
# requires_license                                 object
# license                                         float64
# jurisdiction_names                               object
# instant_bookable                                 object
# is_business_travel_ready                         object
# cancellation_policy                              object
# require_guest_profile_picture                    object
# require_guest_phone_verification                 object
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# host_tenure_year                                float64
# dtype: object

# %%
#.sort_values(ascending=True)
percent_missing = airbnb.isnull().sum()* 100 /len(airbnb)
missing_value_df = pd.DataFrame({'column_name': airbnb.columns,
                                 'percent_missing': percent_missing}).sort_values(by='percent_missing',ascending =False)
missing_value_df
# Out:
#                                                                                column_name  \
# neighbourhood_group_cleansed                                  neighbourhood_group_cleansed
# license                                                                            license
# xl_picture_url                                                              xl_picture_url
# medium_url                                                                      medium_url
# thumbnail_url                                                                thumbnail_url
# square_feet                                                                    square_feet
# weekly_price                                                                  weekly_price
# monthly_price                                                                monthly_price
# notes                                                                                notes
# access                                                                              access
# transit                                                                            transit
# interaction                                                                    interaction
# neighborhood_overview                                                neighborhood_overview
# host_about                                                                      host_about
# house_rules                                                                    house_rules
# host_response_time                                                      host_response_time
# host_response_rate                                                      host_response_rate
# space                                                                                space
# security_deposit                                                          security_deposit
# review_scores_checkin                                                review_scores_checkin
# review_scores_location                                              review_scores_location
# review_scores_value                                                    review_scores_value
# review_scores_cleanliness                                        review_scores_cleanliness
# review_scores_accuracy                                              review_scores_accuracy
# review_scores_communication                                    review_scores_communication
# review_scores_rating                                                  review_scores_rating
# last_review                                                                    last_review
# reviews_per_month                                                        reviews_per_month
# first_review                                                                  first_review
# host_neighbourhood                                                      host_neighbourhood
# jurisdiction_names                                                      jurisdiction_names
# cleaning_fee                                                                  cleaning_fee
# host_acceptance_rate                                                  host_acceptance_rate
# neighbourhood                                                                neighbourhood
# summary                                                                            summary
# description                                                                    description
# beds                                                                                  beds
# zipcode                                                                            zipcode
# host_location                                                                host_location
# market                                                                              market
# bedrooms                                                                          bedrooms
# host_thumbnail_url                                                      host_thumbnail_url
# name                                                                                  name
# bathrooms                                                                        bathrooms
# host_name                                                                        host_name
# host_since                                                                      host_since
# host_picture_url                                                          host_picture_url
# state                                                                                state
# city                                                                                  city
# host_is_superhost                                                        host_is_superhost
# host_identity_verified                                              host_identity_verified
# host_has_profile_pic                                                  host_has_profile_pic
# host_total_listings_count                                        host_total_listings_count
# host_listings_count                                                    host_listings_count
# calendar_last_scraped                                                calendar_last_scraped
# availability_365                                                          availability_365
# availability_90                                                            availability_90
# availability_60                                                            availability_60
# number_of_reviews_ltm                                                number_of_reviews_ltm
# number_of_reviews                                                        number_of_reviews
# availability_30                                                            availability_30
# id                                                                                      id
# cancellation_policy                                                    cancellation_policy
# requires_license                                                          requires_license
# instant_bookable                                                          instant_bookable
# is_business_travel_ready                                          is_business_travel_ready
# calendar_updated                                                          calendar_updated
# require_guest_profile_picture                                require_guest_profile_picture
# require_guest_phone_verification                          require_guest_phone_verification
# calculated_host_listings_count                              calculated_host_listings_count
# calculated_host_listings_count_entire_homes    calculated_host_listings_count_entire_homes
# calculated_host_listings_count_private_rooms  calculated_host_listings_count_private_rooms
# calculated_host_listings_count_shared_rooms    calculated_host_listings_count_shared_rooms
# has_availability                                                          has_availability
# accommodates                                                                  accommodates
# maximum_nights_avg_ntm                                              maximum_nights_avg_ntm
# minimum_nights_avg_ntm                                              minimum_nights_avg_ntm
# scrape_id                                                                        scrape_id
# last_scraped                                                                  last_scraped
# experiences_offered                                                    experiences_offered
# picture_url                                                                    picture_url
# host_id                                                                            host_id
# host_url                                                                          host_url
# host_verifications                                                      host_verifications
# street                                                                              street
# neighbourhood_cleansed                                              neighbourhood_cleansed
# smart_location                                                              smart_location
# country_code                                                                  country_code
# country                                                                            country
# latitude                                                                          latitude
# longitude                                                                        longitude
# is_location_exact                                                        is_location_exact
# property_type                                                                property_type
# room_type                                                                        room_type
# listing_url                                                                    listing_url
# bed_type                                                                          bed_type
# amenities                                                                        amenities
# price                                                                                price
# guests_included                                                            guests_included
# extra_people                                                                  extra_people
# minimum_nights                                                              minimum_nights
# maximum_nights                                                              maximum_nights
# minimum_minimum_nights                                              minimum_minimum_nights
# maximum_minimum_nights                                              maximum_minimum_nights
# minimum_maximum_nights                                              minimum_maximum_nights
# maximum_maximum_nights                                              maximum_maximum_nights
# host_tenure_year                                                          host_tenure_year
#
#                                               percent_missing
# neighbourhood_group_cleansed                       100.000000
# license                                            100.000000
# xl_picture_url                                     100.000000
# medium_url                                         100.000000
# thumbnail_url                                      100.000000
# square_feet                                         99.598394
# weekly_price                                        92.050962
# monthly_price                                       91.801690
# notes                                               48.871347
# access                                              43.165767
# transit                                             42.722615
# interaction                                         41.102340
# neighborhood_overview                               37.072428
# host_about                                          32.322393
# house_rules                                         31.352998
# host_response_time                                  25.024235
# host_response_rate                                  25.024235
# space                                               23.639385
# security_deposit                                    20.177261
# review_scores_checkin                               18.972441
# review_scores_location                              18.972441
# review_scores_value                                 18.972441
# review_scores_cleanliness                           18.958593
# review_scores_accuracy                              18.958593
# review_scores_communication                         18.958593
# review_scores_rating                                18.930896
# last_review                                         18.127683
# reviews_per_month                                   18.127683
# first_review                                        18.127683
# host_neighbourhood                                  16.355075
# jurisdiction_names                                  13.557679
# cleaning_fee                                        11.078798
# host_acceptance_rate                                 9.887827
# neighbourhood                                        6.688824
# summary                                              4.140701
# description                                          3.295942
# beds                                                 0.941698
# zipcode                                              0.761667
# host_location                                        0.318515
# market                                               0.152333
# bedrooms                                             0.083091
# host_thumbnail_url                                   0.013848
# name                                                 0.013848
# bathrooms                                            0.013848
# host_name                                            0.013848
# host_since                                           0.013848
# host_picture_url                                     0.013848
# state                                                0.013848
# city                                                 0.013848
# host_is_superhost                                    0.013848
# host_identity_verified                               0.013848
# host_has_profile_pic                                 0.013848
# host_total_listings_count                            0.013848
# host_listings_count                                  0.013848
# calendar_last_scraped                                0.000000
# availability_365                                     0.000000
# availability_90                                      0.000000
# availability_60                                      0.000000
# number_of_reviews_ltm                                0.000000
# number_of_reviews                                    0.000000
# availability_30                                      0.000000
# id                                                   0.000000
# cancellation_policy                                  0.000000
# requires_license                                     0.000000
# instant_bookable                                     0.000000
# is_business_travel_ready                             0.000000
# calendar_updated                                     0.000000
# require_guest_profile_picture                        0.000000
# require_guest_phone_verification                     0.000000
# calculated_host_listings_count                       0.000000
# calculated_host_listings_count_entire_homes          0.000000
# calculated_host_listings_count_private_rooms         0.000000
# calculated_host_listings_count_shared_rooms          0.000000
# has_availability                                     0.000000
# accommodates                                         0.000000
# maximum_nights_avg_ntm                               0.000000
# minimum_nights_avg_ntm                               0.000000
# scrape_id                                            0.000000
# last_scraped                                         0.000000
# experiences_offered                                  0.000000
# picture_url                                          0.000000
# host_id                                              0.000000
# host_url                                             0.000000
# host_verifications                                   0.000000
# street                                               0.000000
# neighbourhood_cleansed                               0.000000
# smart_location                                       0.000000
# country_code                                         0.000000
# country                                              0.000000
# latitude                                             0.000000
# longitude                                            0.000000
# is_location_exact                                    0.000000
# property_type                                        0.000000
# room_type                                            0.000000
# listing_url                                          0.000000
# bed_type                                             0.000000
# amenities                                            0.000000
# price                                                0.000000
# guests_included                                      0.000000
# extra_people                                         0.000000
# minimum_nights                                       0.000000
# maximum_nights                                       0.000000
# minimum_minimum_nights                               0.000000
# maximum_minimum_nights                               0.000000
# minimum_maximum_nights                               0.000000
# maximum_maximum_nights                               0.000000
# host_tenure_year                                     0.000000

# %%
# find missing values and single value columns & url in data:
#[i for i in airbnb.columns if "url" in i]
del_cols = []

for col in airbnb.columns:
    if airbnb[col].isna().all():
        del_cols.append(col)
    elif airbnb[col].nunique() == 1:
        del_cols.append(col)
    elif "url" in col:
        del_cols.append(col)

del_cols
# Out:
# ['listing_url',
#  'scrape_id',
#  'experiences_offered',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_url',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'neighbourhood_group_cleansed',
#  'country_code',
#  'country',
#  'has_availability',
#  'requires_license',
#  'license',
#  'is_business_travel_ready']

# %%
airbnb = airbnb.drop(del_cols, axis=1)

# %%
#airbnb.columns
cat_features = airbnb.select_dtypes(include=['object']).columns
cat_features
# Out:
# Index(['last_scraped', 'name', 'summary', 'space', 'description',
#        'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
#        'house_rules', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_neighbourhood', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed', 'city', 'state', 'zipcode',
#        'market', 'smart_location', 'is_location_exact', 'property_type',
#        'room_type', 'bed_type', 'amenities', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'extra_people',
#        'calendar_updated', 'calendar_last_scraped', 'first_review',
#        'last_review', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification'],
#       dtype='object')

# %%
cat_cols = []
for col in cat_features:
    list_unique = (col, len(airbnb[col].unique()))
    print(col)
    print(airbnb[col].value_counts(normalize=True).loc[lambda x : x>0.2])
    cat_cols.append(list_unique)
    #print(list_unique)

#output = sorted(cat_cols, key=lambda x: x[-1])
#output
# Out:
# last_scraped
# 2020-05-31    0.662235
# 2020-05-30    0.337765
# Name: last_scraped, dtype: float64
# name
# Series([], Name: name, dtype: float64)
# summary
# Series([], Name: summary, dtype: float64)
# space
# Series([], Name: space, dtype: float64)
# description
# Series([], Name: description, dtype: float64)
# neighborhood_overview
# Series([], Name: neighborhood_overview, dtype: float64)
# notes
# Series([], Name: notes, dtype: float64)
# transit
# Series([], Name: transit, dtype: float64)
# access
# Series([], Name: access, dtype: float64)
# interaction
# Series([], Name: interaction, dtype: float64)
# house_rules
# Series([], Name: house_rules, dtype: float64)
# host_name
# Series([], Name: host_name, dtype: float64)
# host_since
# Series([], Name: host_since, dtype: float64)
# host_location
# San Jose, California, United States    0.268964
# Name: host_location, dtype: float64
# host_about
# Series([], Name: host_about, dtype: float64)
# host_response_time
# within an hour    0.737532
# Name: host_response_time, dtype: float64
# host_response_rate
# 100%    0.810676
# Name: host_response_rate, dtype: float64
# host_acceptance_rate
# 100%    0.340864
# Name: host_acceptance_rate, dtype: float64
# host_is_superhost
# f    0.552355
# t    0.447645
# Name: host_is_superhost, dtype: float64
# host_neighbourhood
# Series([], Name: host_neighbourhood, dtype: float64)
# host_verifications
# Series([], Name: host_verifications, dtype: float64)
# host_has_profile_pic
# t    0.999307
# Name: host_has_profile_pic, dtype: float64
# host_identity_verified
# f    0.562465
# t    0.437535
# Name: host_identity_verified, dtype: float64
# street
# San Jose, CA, United States    0.419333
# Name: street, dtype: float64
# neighbourhood
# Series([], Name: neighbourhood, dtype: float64)
# neighbourhood_cleansed
# San Jose    0.399114
# Name: neighbourhood_cleansed, dtype: float64
# city
# San Jose    0.419391
# Name: city, dtype: float64
# state
# CA    0.999446
# Name: state, dtype: float64
# zipcode
# Series([], Name: zipcode, dtype: float64)
# market
# South Bay, CA    0.761720
# South Bay CA     0.223578
# Name: market, dtype: float64
# smart_location
# San Jose, CA    0.419333
# Name: smart_location, dtype: float64
# is_location_exact
# t    0.941144
# Name: is_location_exact, dtype: float64
# property_type
# House    0.514472
# Name: property_type, dtype: float64
# room_type
# Private room       0.478327
# Entire home/apt    0.475142
# Name: room_type, dtype: float64
# bed_type
# Real Bed    0.990998
# Name: bed_type, dtype: float64
# amenities
# Series([], Name: amenities, dtype: float64)
# price
# Series([], Name: price, dtype: float64)
# weekly_price
# Series([], Name: weekly_price, dtype: float64)
# monthly_price
# Series([], Name: monthly_price, dtype: float64)
# security_deposit
# $0.00    0.323213
# Name: security_deposit, dtype: float64
# cleaning_fee
# Series([], Name: cleaning_fee, dtype: float64)
# extra_people
# $0.00    0.472788
# Name: extra_people, dtype: float64
# calendar_updated
# Series([], Name: calendar_updated, dtype: float64)
# calendar_last_scraped
# 2020-05-31    0.662235
# 2020-05-30    0.337765
# Name: calendar_last_scraped, dtype: float64
# first_review
# Series([], Name: first_review, dtype: float64)
# last_review
# Series([], Name: last_review, dtype: float64)
# jurisdiction_names
# {"SAN JOSE"}    0.450176
# Name: jurisdiction_names, dtype: float64
# instant_bookable
# f    0.55214
# t    0.44786
# Name: instant_bookable, dtype: float64
# cancellation_policy
# flexible                       0.390112
# moderate                       0.315469
# strict_14_with_grace_period    0.294281
# Name: cancellation_policy, dtype: float64
# require_guest_profile_picture
# f    0.968148
# Name: require_guest_profile_picture, dtype: float64
# require_guest_phone_verification
# f    0.968425
# Name: require_guest_phone_verification, dtype: float64

# %% [markdown]
# host_response_time
# within an hour    0.737532
# property_type
# House    0.514472
#
# host_response_rate
# 100%    0.810676
#
# host_acceptance_rate
# 100%    0.340864
#
# host_is_superhost
# f    0.552355
# t    0.447645
#
# host_identity_verified
# f    0.562465
# t    0.437535
#
# room_type
# Private room       0.478327
# Entire home/apt    0.475142
#
# extra_people
# $0.00    0.472788
#
# cancellation_policy
# flexible                       0.390112
# moderate                       0.315469
# strict_14_with_grace_period    0.294281
#
# instant_bookable
# f    0.55214
# t    0.44786
#
# require_guest_profile_picture
# f    0.968148
#
# require_guest_phone_verification
# f    0.968425

# %%
feature_df['host_response_in_1hr'] = airbnb['host_response_time'].apply(lambda x: int(x=='within an hour') if isinstance(x, str) else 0)
feature_df['host_response_rate100']= airbnb['host_response_rate'].apply(lambda x: int(x=='100%') if isinstance(x, str) else 0)
feature_df['host_acceptance_rate100']=airbnb['host_acceptance_rate'].apply(lambda x: int(x=='100%') if isinstance(x, str) else 0)
feature_df['host_is_superhost'] = airbnb['host_is_superhost'].apply(lambda x: int(x=='t') if isinstance(x, str) else 0)
feature_df['host_identity_verified']= airbnb['host_identity_verified'].apply(lambda x: int(x=='t') if isinstance(x, str) else 0)
feature_df['room_type_private_room']= airbnb['room_type'].apply(lambda x: int(x=='Private room') if isinstance(x, str) else 0)
feature_df['room_type_entire_home']=airbnb['room_type'].apply(lambda x: int(x=='Entire home/apt') if isinstance(x, str) else 0)
feature_df['charge_extra_people_fee']=airbnb['extra_people'].apply(lambda x: int(x!='$0.00') if isinstance(x, str) else 0)

feature_df['cancellation_policy_flexible']= airbnb['cancellation_policy'].apply(lambda x: int(x=='flexible') if isinstance(x, str) else 0)
feature_df['cancellation_policy_moderate']=airbnb['cancellation_policy'].apply(lambda x: int(x=='moderate') if isinstance(x, str) else 0)
feature_df['cancellation_policy_strict']=airbnb['cancellation_policy'].apply(lambda x: int(x=='strict_14_with_grace_period') if isinstance(x, str) else 0)
feature_df['instant_bookable']=airbnb['instant_bookable'].apply(lambda x: int(x=='t') if isinstance(x, str) else 0)

# %%
feature_df.head()
# Out:
#       id                         listing_url  \
# 0   4952   https://www.airbnb.com/rooms/4952
# 1  11464  https://www.airbnb.com/rooms/11464
# 2  17884  https://www.airbnb.com/rooms/17884
# 3  21373  https://www.airbnb.com/rooms/21373
# 4  37512  https://www.airbnb.com/rooms/37512
#
#                                   name  host_tenure_year  \
# 0    Butterfly Inn - Graceful Living !              13.0
# 1    Deluxe Private Studio-custom int.              12.0
# 2                 Silicon Valley Suite              12.0
# 3  Bonsai Garden Inn in Professorville              13.0
# 4    Private  room - Parking 3 carport              11.0
#
#    host_response_in_1hr  host_response_rate100  host_acceptance_rate100  \
# 0                     1                      1                        0
# 1                     1                      1                        0
# 2                     0                      1                        0
# 3                     1                      1                        0
# 4                     0                      1                        1
#
#    host_is_superhost  host_identity_verified  room_type_private_room  \
# 0                  1                       0                       1
# 1                  0                       0                       0
# 2                  0                       1                       0
# 3                  1                       0                       1
# 4                  1                       1                       1
#
#    room_type_entire_home  charge_extra_people_fee  \
# 0                      0                        1
# 1                      1                        1
# 2                      1                        0
# 3                      0                        1
# 4                      0                        0
#
#    cancellation_policy_flexible  cancellation_policy_moderate  \
# 0                             0                             1
# 1                             0                             1
# 2                             0                             0
# 3                             0                             1
# 4                             0                             1
#
#    cancellation_policy_strict  instant_bookable
# 0                           0                 0
# 1                           0                 0
# 2                           1                 0
# 3                           0                 0
# 4                           0                 0

# %%
numeric_features = airbnb.select_dtypes(include=['int64', 'float64']).columns
airbnb[numeric_features].describe()
# Out:
#                  id       host_id  host_listings_count  \
# count  7.221000e+03  7.221000e+03          7220.000000
# mean   2.623922e+07  8.886443e+07           139.588504
# std    1.236420e+07  9.390593e+07           472.674992
# min    4.952000e+03  7.054000e+03             0.000000
# 25%    1.624242e+07  1.697278e+07             1.000000
# 50%    2.818432e+07  4.800549e+07             3.000000
# 75%    3.749948e+07  1.429331e+08            10.000000
# max    4.359134e+07  3.477992e+08          2007.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                7220.000000  7221.000000  7221.000000   7221.000000
# mean                  139.588504    37.352285  -121.966600      3.114804
# std                   472.674992     0.064819     0.108587      2.370579
# min                     0.000000    36.965600  -122.190350      1.000000
# 25%                     1.000000    37.319770  -122.042450      2.000000
# 50%                     3.000000    37.358260  -121.961940      2.000000
# 75%                    10.000000    37.398250  -121.886340      4.000000
# max                  2007.000000    37.462980  -121.380120     16.000000
#
#          bathrooms     bedrooms         beds  square_feet  guests_included  \
# count  7220.000000  7215.000000  7153.000000    29.000000      7221.000000
# mean      1.383449     1.421760     1.817000   691.000000         1.699349
# std       0.688715     0.999833     1.633911   735.833492         1.620945
# min       0.000000     0.000000     0.000000    50.000000         1.000000
# 25%       1.000000     1.000000     1.000000   225.000000         1.000000
# 50%       1.000000     1.000000     1.000000   396.000000         1.000000
# 75%       2.000000     2.000000     2.000000   950.000000         2.000000
# max       8.000000     9.000000    54.000000  3600.000000        16.000000
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# count     7221.000000    7.221000e+03             7221.000000
# mean         9.756959    2.980880e+05                9.142916
# std         34.689846    2.527150e+07               35.027086
# min          1.000000    1.000000e+00                1.000000
# 25%          1.000000    6.000000e+01                1.000000
# 50%          2.000000    1.125000e+03                2.000000
# 75%          7.000000    1.125000e+03                5.000000
# max       1125.000000    2.147484e+09             1125.000000
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# count             7221.000000            7.221000e+03            7.221000e+03
# mean                14.247888            2.982325e+05            1.785205e+06
# std                 63.358607            2.527150e+07            6.188084e+07
# min                  1.000000            1.000000e+00            1.000000e+00
# 25%                  1.000000            3.650000e+02            3.650000e+02
# 50%                  2.000000            1.125000e+03            1.125000e+03
# 75%                  7.000000            1.125000e+03            1.125000e+03
# max               1125.000000            2.147484e+09            2.147484e+09
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  availability_30  \
# count             7221.000000            7.221000e+03      7221.000000
# mean                13.631505            1.538945e+06        13.689101
# std                 61.691820            5.347742e+07        13.616884
# min                  1.000000            1.000000e+00         0.000000
# 25%                  1.000000            3.650000e+02         0.000000
# 50%                  2.000000            1.125000e+03        10.000000
# 75%                  7.000000            1.125000e+03        29.000000
# max               1125.000000            2.147484e+09        30.000000
#
#        availability_60  availability_90  availability_365  number_of_reviews  \
# count      7221.000000      7221.000000       7221.000000        7221.000000
# mean         30.373494        48.260352        160.282648          29.853760
# std          26.501026        38.981316        141.746896          51.488761
# min           0.000000         0.000000          0.000000           0.000000
# 25%           0.000000         0.000000          1.000000           1.000000
# 50%          30.000000        59.000000        136.000000          10.000000
# 75%          59.000000        89.000000        323.000000          35.000000
# max          60.000000        90.000000        365.000000         488.000000
#
#        number_of_reviews_ltm  review_scores_rating  review_scores_accuracy  \
# count            7221.000000           5854.000000             5852.000000
# mean                9.369201             95.245473                9.723855
# std                15.188236              7.734005                0.741816
# min                 0.000000             20.000000                2.000000
# 25%                 0.000000             94.000000               10.000000
# 50%                 3.000000             98.000000               10.000000
# 75%                12.000000            100.000000               10.000000
# max               154.000000            100.000000               10.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                5852.000000            5851.000000
# mean                    9.572454               9.815074
# std                     0.848685               0.641301
# min                     2.000000               2.000000
# 25%                     9.000000              10.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                  5852.000000             5851.000000
# mean                      9.793233                9.796103
# std                       0.691503                0.583498
# min                       2.000000                2.000000
# 25%                      10.000000               10.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  calculated_host_listings_count  \
# count          5851.000000                     7221.000000
# mean              9.527773                       32.048608
# std               0.833306                       95.159193
# min               2.000000                        1.000000
# 25%               9.000000                        1.000000
# 50%              10.000000                        3.000000
# 75%              10.000000                        8.000000
# max              10.000000                      411.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  7221.000000
# mean                                     28.216729
# std                                      95.714488
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                     411.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   7221.000000
# mean                                       2.775793
# std                                        6.810433
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# 75%                                        3.000000
# max                                       62.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# count                                  7221.000000        5912.000000
# mean                                      1.029359           1.357124
# std                                       5.741521           1.530782
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.320000
# 50%                                       0.000000           0.830000
# 75%                                       0.000000           1.810000
# max                                      48.000000          13.120000
#
#        host_tenure_year
# count        7221.00000
# mean            5.73854
# std             2.32898
# min             0.00000
# 25%             4.00000
# 50%             6.00000
# 75%             7.00000
# max            13.00000

# %% [markdown]
# # Clean price

# %%
## apply function to multiple columns 
def price_cov(x):
    return x.str.replace('$', '').str.replace(',', '').astype(float)

price_colname =['price','security_deposit','cleaning_fee','monthly_price','weekly_price']
airbnb[price_colname] = airbnb[price_colname].apply(price_cov, axis=1)
# Out:
# /var/folders/dv/qnpc2tm905n3c2nrmq03c65w0000gn/T/ipykernel_19582/1456624900.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   return x.str.replace('$', '').str.replace(',', '').astype(float)

# %%
airbnb[price_colname].head()
# Out:
#    price  security_deposit  cleaning_fee  monthly_price  weekly_price
# 0   90.0               0.0          35.0         1428.0         440.0
# 1   85.0             700.0         250.0         2100.0           NaN
# 2   65.0            1000.0           NaN         2800.0        1400.0
# 3   99.0               0.0          35.0         2000.0         600.0
# 4   52.0               NaN           NaN         1386.0         393.0

# %%
## missing value inputation 
## monthly_price weekly_price
price_complete =airbnb[airbnb['monthly_price'].notnull() & airbnb['weekly_price'].notnull()][['monthly_price','weekly_price','price','cleaning_fee','security_deposit']]
price_complete.sort_values(by='price')
# create columes weekly_special_price monthly_special_price 

price_complete['weekly_special_price'] = price_complete['price']*7- price_complete['weekly_price']
price_complete['monthly_special_price'] = price_complete['price']*31- price_complete['monthly_price']

price_complete.fillna(0, inplace=True)

# %%
price_complete.head(10)
# Out:
#     monthly_price  weekly_price  price  cleaning_fee  security_deposit  \
# 0          1428.0         440.0   90.0          35.0               0.0
# 2          2800.0        1400.0   65.0           0.0            1000.0
# 3          2000.0         600.0   99.0          35.0               0.0
# 4          1386.0         393.0   52.0           0.0               0.0
# 5          2400.0         875.0  110.0          35.0             100.0
# 6          1450.0         450.0   60.0          20.0             100.0
# 7          2200.0         800.0  125.0          35.0             100.0
# 9          1950.0         700.0  115.0          35.0               0.0
# 10         2150.0         675.0   95.0          30.0               0.0
# 11         3699.0        1099.0  189.0           0.0             500.0
#
#     weekly_special_price  monthly_special_price
# 0                  190.0                 1362.0
# 2                 -945.0                 -785.0
# 3                   93.0                 1069.0
# 4                  -29.0                  226.0
# 5                 -105.0                 1010.0
# 6                  -30.0                  410.0
# 7                   75.0                 1675.0
# 9                  105.0                 1615.0
# 10                 -10.0                  795.0
# 11                 224.0                 2160.0

# %%
## append selected price_colname to feature_df
feature_df=pd.concat([feature_df, airbnb[['price','security_deposit','cleaning_fee']].fillna(0)], axis=1)

# %%
feature_df=pd.concat([feature_df, price_complete[['weekly_special_price','monthly_special_price']]], axis=1).fillna(0)
feature_df.head()
# Out:
#       id                         listing_url  \
# 0   4952   https://www.airbnb.com/rooms/4952
# 1  11464  https://www.airbnb.com/rooms/11464
# 2  17884  https://www.airbnb.com/rooms/17884
# 3  21373  https://www.airbnb.com/rooms/21373
# 4  37512  https://www.airbnb.com/rooms/37512
#
#                                   name  host_tenure_year  \
# 0    Butterfly Inn - Graceful Living !              13.0
# 1    Deluxe Private Studio-custom int.              12.0
# 2                 Silicon Valley Suite              12.0
# 3  Bonsai Garden Inn in Professorville              13.0
# 4    Private  room - Parking 3 carport              11.0
#
#    host_response_in_1hr  host_response_rate100  host_acceptance_rate100  \
# 0                     1                      1                        0
# 1                     1                      1                        0
# 2                     0                      1                        0
# 3                     1                      1                        0
# 4                     0                      1                        1
#
#    host_is_superhost  host_identity_verified  room_type_private_room  \
# 0                  1                       0                       1
# 1                  0                       0                       0
# 2                  0                       1                       0
# 3                  1                       0                       1
# 4                  1                       1                       1
#
#    room_type_entire_home  charge_extra_people_fee  \
# 0                      0                        1
# 1                      1                        1
# 2                      1                        0
# 3                      0                        1
# 4                      0                        0
#
#    cancellation_policy_flexible  cancellation_policy_moderate  \
# 0                             0                             1
# 1                             0                             1
# 2                             0                             0
# 3                             0                             1
# 4                             0                             1
#
#    cancellation_policy_strict  instant_bookable  price  security_deposit  \
# 0                           0                 0   90.0               0.0
# 1                           0                 0   85.0             700.0
# 2                           1                 0   65.0            1000.0
# 3                           0                 0   99.0               0.0
# 4                           0                 0   52.0               0.0
#
#    cleaning_fee  weekly_special_price  monthly_special_price
# 0          35.0                 190.0                 1362.0
# 1         250.0                   0.0                    0.0
# 2           0.0                -945.0                 -785.0
# 3          35.0                  93.0                 1069.0
# 4           0.0                 -29.0                  226.0

# %%
len(feature_df)
# Out:
# 7221

# %% [markdown]
# # Clean location

# %%
airbnb[['street','neighbourhood','neighbourhood_cleansed','city','state','zipcode','market','smart_location','latitude','longitude','is_location_exact']].head(10)
# Out:
#                              street   neighbourhood neighbourhood_cleansed  \
# 0      Palo Alto, CA, United States       Palo Alto              Palo Alto
# 1    Santa Clara, CA, United States     Santa Clara            Santa Clara
# 2  Mountain View, CA, United States   Mountain View          Mountain View
# 3      Palo Alto, CA, United States       Palo Alto              Palo Alto
# 4       San Jose, CA, United States  South San Jose               San Jose
# 5      Palo Alto, CA, United States       Palo Alto              Palo Alto
# 6       San Jose, CA, United States     Santa Clara               San Jose
# 7      Palo Alto, CA, United States       Palo Alto              Palo Alto
# 8       San Jose, CA, United States  South San Jose               San Jose
# 9      Palo Alto, CA, United States       Palo Alto              Palo Alto
#
#             city state zipcode         market     smart_location  latitude  \
# 0      Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA  37.43972
# 1    Santa Clara    CA   95051  South Bay, CA    Santa Clara, CA  37.34342
# 2  Mountain View    CA   94041  South Bay, CA  Mountain View, CA  37.38612
# 3      Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA  37.44001
# 4       San Jose    CA   95111  South Bay, CA       San Jose, CA  37.30598
# 5      Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA  37.45356
# 6       San Jose    CA   95117  South Bay, CA       San Jose, CA  37.32654
# 7      Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA  37.45348
# 8       San Jose    CA   95111  South Bay, CA       San Jose, CA  37.30521
# 9      Palo Alto    CA   94301  South Bay, CA      Palo Alto, CA  37.43925
#
#    longitude is_location_exact
# 0 -122.15672                 t
# 1 -121.98829                 t
# 2 -122.07357                 t
# 3 -122.15667                 t
# 4 -121.84036                 t
# 5 -122.13733                 t
# 6 -121.94955                 t
# 7 -122.13714                 t
# 8 -121.84149                 t
# 9 -122.15617                 t

# %%
np.sort(airbnb.neighbourhood_cleansed.unique()).tolist()
# Out:
# ['Campbell',
#  'Cupertino',
#  'Gilroy',
#  'Los Altos',
#  'Los Altos Hills',
#  'Los Gatos',
#  'Milpitas',
#  'Monte Sereno',
#  'Morgan Hill',
#  'Mountain View',
#  'Palo Alto',
#  'San Jose',
#  'Santa Clara',
#  'Saratoga',
#  'Sunnyvale',
#  'Unincorporated Areas']

# %%
airbnb.market.unique().tolist()
# Out:
# ['South Bay, CA', 'Monterey Region', 'Other (Domestic)', 'South Bay CA', nan]

# %%
neighbourhoods.neighbourhood.tolist()
# Out:
# ['Campbell',
#  'Cupertino',
#  'Gilroy',
#  'Los Altos',
#  'Los Altos Hills',
#  'Los Gatos',
#  'Milpitas',
#  'Monte Sereno',
#  'Morgan Hill',
#  'Mountain View',
#  'Palo Alto',
#  'San Jose',
#  'Santa Clara',
#  'Saratoga',
#  'Sunnyvale',
#  'Unincorporated Areas']

# %%
feature_df['neighbourhood_cleansed']=airbnb.neighbourhood_cleansed
feature_df.head()
# Out:
#       id                         listing_url  \
# 0   4952   https://www.airbnb.com/rooms/4952
# 1  11464  https://www.airbnb.com/rooms/11464
# 2  17884  https://www.airbnb.com/rooms/17884
# 3  21373  https://www.airbnb.com/rooms/21373
# 4  37512  https://www.airbnb.com/rooms/37512
#
#                                   name  host_tenure_year  \
# 0    Butterfly Inn - Graceful Living !              13.0
# 1    Deluxe Private Studio-custom int.              12.0
# 2                 Silicon Valley Suite              12.0
# 3  Bonsai Garden Inn in Professorville              13.0
# 4    Private  room - Parking 3 carport              11.0
#
#    host_response_in_1hr  host_response_rate100  host_acceptance_rate100  \
# 0                     1                      1                        0
# 1                     1                      1                        0
# 2                     0                      1                        0
# 3                     1                      1                        0
# 4                     0                      1                        1
#
#    host_is_superhost  host_identity_verified  room_type_private_room  \
# 0                  1                       0                       1
# 1                  0                       0                       0
# 2                  0                       1                       0
# 3                  1                       0                       1
# 4                  1                       1                       1
#
#    room_type_entire_home  charge_extra_people_fee  \
# 0                      0                        1
# 1                      1                        1
# 2                      1                        0
# 3                      0                        1
# 4                      0                        0
#
#    cancellation_policy_flexible  cancellation_policy_moderate  \
# 0                             0                             1
# 1                             0                             1
# 2                             0                             0
# 3                             0                             1
# 4                             0                             1
#
#    cancellation_policy_strict  instant_bookable  price  security_deposit  \
# 0                           0                 0   90.0               0.0
# 1                           0                 0   85.0             700.0
# 2                           1                 0   65.0            1000.0
# 3                           0                 0   99.0               0.0
# 4                           0                 0   52.0               0.0
#
#    cleaning_fee  weekly_special_price  monthly_special_price  \
# 0          35.0                 190.0                 1362.0
# 1         250.0                   0.0                    0.0
# 2           0.0                -945.0                 -785.0
# 3          35.0                  93.0                 1069.0
# 4           0.0                 -29.0                  226.0
#
#   neighbourhood_cleansed
# 0              Palo Alto
# 1            Santa Clara
# 2          Mountain View
# 3              Palo Alto
# 4               San Jose

# %% [markdown]
# # Clean room type

# %%
room_colname=['property_type',
'room_type',
'accommodates',
'bathrooms',
'bedrooms',
'beds',
'bed_type',
'amenities',
'square_feet']
airbnb[room_colname].head(10)
# Out:
#   property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0         Villa     Private room             2        2.0       1.0   1.0
# 1     Apartment  Entire home/apt             1        1.0       NaN   1.0
# 2   Guest suite  Entire home/apt             2        1.0       1.0   1.0
# 3         Villa     Private room             1        2.0       1.0   1.0
# 4      Bungalow     Private room             2        1.0       1.0   1.0
# 5         House     Private room             2        1.0       1.0   1.0
# 6         House     Private room             1        1.0       1.0   1.0
# 7         House     Private room             2        1.0       1.0   1.0
# 8      Bungalow     Private room             2        1.0       1.0   1.0
# 9         Villa     Private room             2        2.0       1.0   4.0
#
#    bed_type                                          amenities  square_feet
# 0  Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...          NaN
# 1  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...        325.0
# 2  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN
# 3  Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...          NaN
# 4  Real Bed  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...          NaN
# 5  Real Bed  {TV,"Cable TV",Internet,Wifi,"Pets live on thi...          NaN
# 6  Real Bed  {TV,Wifi,"Free parking on premises","Pets live...          NaN
# 7  Real Bed  {Internet,Wifi,"Free parking on premises","Pet...          NaN
# 8     Futon  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...          NaN
# 9  Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,"Indoor f...        100.0

# %%
numeric_features = airbnb.select_dtypes(
    include=['int64', 'float64', 'float32', 'int32'])
nominal_features = airbnb.select_dtypes(include=['object'])

for item in room_colname:
    print(item)
    print(airbnb[item].unique())
# Out:
# property_type
# ['Villa' 'Apartment' 'Guest suite' 'Bungalow' 'House' 'Guesthouse' 'Loft'
#  'Other' 'Condominium' 'Townhouse' 'Cottage' 'Bed and breakfast' 'Cabin'
#  'Camper/RV' 'Tiny house' 'Serviced apartment' 'Treehouse' 'Tent' 'Train'
#  'Barn' 'Yurt' 'Boutique hotel' 'Lighthouse' 'Farm stay' 'Campsite'
#  'Earth house' 'Aparthotel' 'Chalet']
# room_type
# ['Private room' 'Entire home/apt' 'Shared room' 'Hotel room']
# accommodates
# [ 2  1  4  3 16  6 12 10  8  5  7 14 13  9 15 11]
# bathrooms
# [2.  1.  0.5 1.5 3.  0.  2.5 4.5 nan 3.5 4.  6.  5.5 5.  6.5 8. ]
# bedrooms
# [ 1. nan  2.  5.  3.  8.  4.  0.  7.  6.  9.]
# beds
# [ 1.  4.  2.  3. 11.  8.  7.  0. 12.  5.  6. nan 10.  9. 17. 26. 13. 15.
#  16. 20. 54.]
# bed_type
# ['Real Bed' 'Futon' 'Pull-out Sofa' 'Airbed' 'Couch']
# amenities
# ['{TV,"Cable TV",Internet,Wifi,Kitchen,Heating,Washer,Dryer,"Smoke alarm","Carbon monoxide alarm","First aid kit","Safety card","Fire extinguisher",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer",Iron,"Laptop-friendly workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50","Private entrance","Hot water","Bed linens","Extra pillows and blankets",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Oven,Stove,"Patio or balcony","Garden or backyard","Long term stays allowed","Host greets you"}'
#  '{TV,"Cable TV",Internet,Wifi,"Air conditioning",Pool,Kitchen,"Free parking on premises","Pets allowed","Pets live on this property",Dog(s),Cat(s),"Free street parking",Heating,Washer,Dryer,"Smoke alarm","Carbon monoxide alarm","Fire extinguisher",Hangers,"Hair dryer",Iron,"Laptop-friendly workspace","Self check-in","Building staff","Hot water",Microwave,"Coffee maker",Refrigerator,"Dishes and silverware","Cooking basics",Oven,Stove,"Single level home"}'
#  '{TV,"Cable TV",Internet,Wifi,"Air conditioning","Free parking on premises","Pets live on this property",Dog(s),Cat(s),"Free street parking",Heating,Washer,Dryer,"Smoke alarm","Carbon monoxide alarm",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer",Iron,"Laptop-friendly workspace","Self check-in",Keypad,"Hot water",Microwave,Refrigerator,"Dishes and silverware","Luggage dropoff allowed","Long term stays allowed"}'
#  ...
#  '{TV,Wifi,Kitchen,"Free parking on premises",Washer,Dryer,"Smoke alarm","Carbon monoxide alarm","First aid kit","Fire extinguisher",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer","Laptop-friendly workspace","Bed linens",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Oven,Stove,"Single level home","Patio or balcony","Garden or backyard","Long term stays allowed","Bread maker"}'
#  '{TV,Wifi,"Air conditioning",Kitchen,"Free parking on premises","Indoor fireplace",Heating,Washer,Dryer,"Smoke alarm","Carbon monoxide alarm","Fire extinguisher",Essentials,"Lock on bedroom door",Hangers,"Laptop-friendly workspace","Private entrance"}'
#  '{TV,Wifi,"Air conditioning",Kitchen,"Free parking on premises",Heating,Washer,Dryer,"Smoke alarm","Carbon monoxide alarm",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop-friendly workspace","Self check-in",Lockbox,"Private entrance",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Oven,Stove,"Garden or backyard"}']
# square_feet
# [  nan  325.  100.   50. 1560.  200.  396. 3600. 1400.  800.  600.  500.
#  1510.  225.  803.  950. 1100.  300.  110. 1150.  120. 1500.  130.  250.
#   260.]

# %%
nominal_features = airbnb[room_colname].select_dtypes(include=['object'])

# %%
nominal_features.head()
# Out:
#   property_type        room_type  bed_type  \
# 0         Villa     Private room  Real Bed
# 1     Apartment  Entire home/apt  Real Bed
# 2   Guest suite  Entire home/apt  Real Bed
# 3         Villa     Private room  Real Bed
# 4      Bungalow     Private room  Real Bed
#
#                                            amenities
# 0  {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 2  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 3  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...
# 4  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...

# %%
# Cat_features.head()
# pd.get_dummies(data,
#                       columns=[
#                           'host_is_superhost', 'host_identity_verified',
#                           'instant_bookable', 'cancellation_policy',
#                           'room_type'
#                       ],
#                       prefix=[
#                           'Superhost', 'Host verified', 'Instantbook',
#                           'Cancellation', 'Room type'
#                       ],
#                       dtype='int64')

# %%
#transform into lower case and export
airbnb['amenities'].str.lower().to_csv("amenities.csv")

# %% [markdown]
# # Create Dummy Variable for top 50 amenities

# %% [markdown]
# [Where Condition Reference](https://towardsdatascience.com/3-methods-to-create-conditional-columns-with-python-pandas-and-numpy-a6cd4be9da53)

# %%
results = Counter()
amenities = airbnb['amenities'].str.lower()
amenities.str.strip('{}')\
               .str.replace('"', '')\
               .str.lstrip('\"')\
               .str.rstrip('\"')\
               .str.split(',')\
               .apply(results.update)
sub_df = pd.DataFrame(results.most_common(50), columns=['amenities', 'count'])
sub_df['ratio'] = round(sub_df['count'] / len(amenities), 4)
sub_df.sort_values(by=['count'], ascending=False)
# Out:
#                      amenities  count   ratio
# 0                         wifi   7071  0.9792
# 1                   essentials   6904  0.9561
# 2                      heating   6824  0.9450
# 3                  smoke alarm   6794  0.9409
# 4                      hangers   6480  0.8974
# 5                      shampoo   6271  0.8684
# 6        carbon monoxide alarm   6178  0.8556
# 7    laptop-friendly workspace   5998  0.8306
# 8                   hair dryer   5997  0.8305
# 9                      kitchen   5890  0.8157
# 10                      washer   5817  0.8056
# 11                       dryer   5785  0.8011
# 12                        iron   5711  0.7909
# 13                   hot water   5280  0.7312
# 14    free parking on premises   5277  0.7308
# 15                          tv   5203  0.7205
# 16            air conditioning   4565  0.6322
# 17                refrigerator   4561  0.6316
# 18                   microwave   4541  0.6289
# 19       dishes and silverware   4139  0.5732
# 20         free street parking   4043  0.5599
# 21           fire extinguisher   4040  0.5595
# 22                coffee maker   3907  0.5411
# 23                  bed linens   3710  0.5138
# 24        lock on bedroom door   3677  0.5092
# 25               first aid kit   3668  0.5080
# 26                       stove   3455  0.4785
# 27              cooking basics   3447  0.4774
# 28                        oven   3434  0.4756
# 29               self check-in   3257  0.4510
# 30            private entrance   3052  0.4227
# 31  extra pillows and blankets   3024  0.4188
# 32     long term stays allowed   2851  0.3948
# 33                  dishwasher   2829  0.3918
# 34          garden or backyard   2437  0.3375
# 35            patio or balcony   2291  0.3173
# 36                    cable tv   2228  0.3085
# 37     luggage dropoff allowed   1839  0.2547
# 38                    internet   1838  0.2545
# 39           single level home   1512  0.2094
# 40                        pool   1437  0.1990
# 41         family/kid friendly   1429  0.1979
# 42            indoor fireplace   1345  0.1863
# 43                      keypad   1286  0.1781
# 44         private living room   1203  0.1666
# 45                     lockbox   1197  0.1658
# 46                     bathtub   1070  0.1482
# 47                pets allowed   1040  0.1440
# 48                   bbq grill   1028  0.1424
# 49                         gym   1008  0.1396

# %%
airbnb['amenities']= airbnb['amenities'].str.lower()
for item in sub_df.amenities.tolist():
    feature_df[item.replace(" ","_")] = airbnb['amenities'].apply(lambda x: int(item in x) if isinstance(x, str) else 0)

# %%
#airbnb['amenities']= airbnb['amenities'].str.lower()
#type(airbnb['amenities'][1])
#feature_df["wifi"] = np.where("wifi" in airbnb['amenities'],1, 0)

feature_df["wifi"].sum()
feature_df["wifi"].describe()
# Out:
# count    7221.000000
# mean        0.979366
# std         0.142166
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: wifi, dtype: float64

# %%
# 'tv' in airbnb['amenities'].str.lower()[1]
# for item in sub_df.amenities.tolist():
#     print (item)
#     print (item in airbnb['amenities'][1])

# %%
feature_df.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'name',
#  'host_tenure_year',
#  'host_response_in_1hr',
#  'host_response_rate100',
#  'host_acceptance_rate100',
#  'host_is_superhost',
#  'host_identity_verified',
#  'room_type_private_room',
#  'room_type_entire_home',
#  'charge_extra_people_fee',
#  'cancellation_policy_flexible',
#  'cancellation_policy_moderate',
#  'cancellation_policy_strict',
#  'instant_bookable',
#  'price',
#  'security_deposit',
#  'cleaning_fee',
#  'weekly_special_price',
#  'monthly_special_price',
#  'neighbourhood_cleansed',
#  'wifi',
#  'essentials',
#  'heating',
#  'smoke_alarm',
#  'hangers',
#  'shampoo',
#  'carbon_monoxide_alarm',
#  'laptop-friendly_workspace',
#  'hair_dryer',
#  'kitchen',
#  'washer',
#  'dryer',
#  'iron',
#  'hot_water',
#  'free_parking_on_premises',
#  'tv',
#  'air_conditioning',
#  'refrigerator',
#  'microwave',
#  'dishes_and_silverware',
#  'free_street_parking',
#  'fire_extinguisher',
#  'coffee_maker',
#  'bed_linens',
#  'lock_on_bedroom_door',
#  'first_aid_kit',
#  'stove',
#  'cooking_basics',
#  'oven',
#  'self_check-in',
#  'private_entrance',
#  'extra_pillows_and_blankets',
#  'long_term_stays_allowed',
#  'dishwasher',
#  'garden_or_backyard',
#  'patio_or_balcony',
#  'cable_tv',
#  'luggage_dropoff_allowed',
#  'internet',
#  'single_level_home',
#  'pool',
#  'family/kid_friendly',
#  'indoor_fireplace',
#  'keypad',
#  'private_living_room',
#  'lockbox',
#  'bathtub',
#  'pets_allowed',
#  'bbq_grill',
#  'gym']

# %% [markdown]
# ## Visualization

# %%
###pairplot##
sns.set(color_codes=True)
sns.set(style="white", palette="muted")
df = feature_df.drop('id',axis = 1)
df = df.drop('listing_url',axis = 1)
fig = plt.figure(figsize = [20,15])
ax = fig.gca()
df.hist(ax = ax, bins = 50)
plt.show()
# Out:
# /var/folders/dv/qnpc2tm905n3c2nrmq03c65w0000gn/T/ipykernel_19582/3623399652.py:8: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax = ax, bins = 50)

# %%
df_corr = df._get_numeric_data().astype(float).corr()

# f,ax = plt.subplots(figsize= (20,20))
# sns.heatmap(df.corr(), annot = True, linewidths=0.5, fmt = '.1f', ax=ax, cmap = 'winter')
# plt.show()
_, ax = plt.subplots(figsize=(25, 25))

sns.heatmap(df_corr,
            square=True,
            cmap='RdBu_r',
            linewidths=.5,
            annot=True,
            fmt='.2f',ax=ax).figure.tight_layout()

plt.show()

# %%
# filter the correlation matrix with threshold

filtered_df = df_corr[((df_corr >= .5) | (df_corr <= -.5)) & (df_corr !=1)].dropna(how="all")

_, ax = plt.subplots(figsize = (20,20))

sns.heatmap(filtered_df,
            square=True,
            cmap='RdBu_r',
            linewidths=.5,
            annot=True,
            fmt='.2f',
            ax=ax)

plt.show()

# %% [markdown]
# # Text Normalization
# Ref: [code](https://www.kaggle.com/peterwittek/wordclouds-of-titles-and-abstracts-with-n-grams)

# %%
def get_bitrigrams(full_text, threshold=30):
    if isinstance(full_text, str):
        text = full_text
    else:
        text = " ".join(full_text)
    bigram_measures = BigramAssocMeasures()
    trigram_measures = TrigramAssocMeasures()
    finder = BigramCollocationFinder.from_words(text.split())
    finder.apply_freq_filter(3)
    bigrams = {" ".join(words): "_".join(words)
               for words in finder.above_score(bigram_measures.likelihood_ratio, threshold)}
    finder = TrigramCollocationFinder.from_words(text.split())
    finder.apply_freq_filter(3)
    trigrams = {" ".join(words): "_".join(words)
                for words in finder.above_score(trigram_measures.likelihood_ratio, threshold)}
    return bigrams, trigrams


def replace_bitrigrams(text, bigrams, trigrams):
    if isinstance(text, str):
        texts = [text]
    else:
        texts = text
    new_texts = []
    for t in texts:
        t_new = t
        for k, v in trigrams.items():
            t_new = t_new.replace(k, v)
        for k, v in bigrams.items():
            t_new = t_new.replace(" " + k + " ", " " + v + " ")
        new_texts.append(t_new)
    if len(new_texts) == 1:
        return new_texts[0]
    else:
        return new_texts

    
def process_text(text, lemmatizer, translate_table, stopwords):
    processed_text = ""
    for sentence in sent_tokenize(text):
        tagged_sentence = pos_tag(word_tokenize(sentence.translate(translate_table)))
        for word, tag in tagged_sentence:
            word = word.lower()
            if word not in stopwords:
                if tag[0] != 'V':
                    processed_text += lemmatizer.lemmatize(word) + " "
    return processed_text


def get_all_processed_texts(texts, lemmatizer, translate_table, stopwords):
    processed_texts = []
    for index, doc in enumerate(texts):
        processed_texts.append(process_text(doc, wordnet_lemmatizer, translate_table, stop))
    bigrams, trigrams = get_bitrigrams(processed_texts)
    very_processed_texts = replace_bitrigrams(processed_texts, bigrams, trigrams)
    return " ".join(very_processed_texts)

# %%
# wordcloud = WordCloud(background_color="white").\
#     generate(get_all_processed_texts(records, wordnet_lemmatizer))
# plt.figure(figsize=(15, 10))
# plt.axis("off")
# plt.imshow(wordcloud)

# %%
# records = airbnb['amenities'].str.lower()
# wordnet_lemmatizer = WordNetLemmatizer()
# stop = set(stopwords.words('english'))
# translate_table = dict((ord(char), " ") for char in string.punctuation)

# %%
# amenitieslist =[]
# for itemlist in records:
#     amenitieslist.extend(itemlist.replace('"',' ').replace('{','').replace('}','').split(','))
# amenitiesdic = WordCloud().process_text(' '.join(amenitieslist))

# sorted([(value,key) for (key,value) in amenitiesdic.items()], reverse=True)

# %% [markdown]
# [(6794, 'smoke alarm'),
#  (6214, 'essentials shampoo'),
#  (6178, 'monoxide alarm'),
#  (6178, 'carbon monoxide'),
#  (6153, 'alarm carbon'),
#  (5998, 'laptop friendly'),
#  (5998, 'friendly workspace'),
#  (5997, 'hair dryer'),
#  (5768, 'washer dryer'),
#  (5739, 'hangers hair'),
#  (5537, 'dryer smoke'),
#  (5344, 'dryer iron'),
#  (5311, 'hot water'),
#  (5277, 'free parking'),
#  (5121, 'iron laptop'),
#  (5083, 'kitchen free'),
#  (4571, 'air conditioning'),
#  (4512, 'wifi air'),
#  (4285, 'heating washer'),
#  (4043, 'street parking'),
#  (4043, 'free street'),
#  (4040, 'fire extinguisher'),
#  (3913, 'extinguisher essentials'),
#  (3907, 'coffee maker'),
#  (3752, 'microwave coffee'),
#  (3749, 'maker refrigerator'),
#  (3710, 'bed linens'),
#  (3677, 'bedroom door'),
#  (3668, 'first aid'),
#  (3668, 'aid kit'),
#  (3642, 'alarm first'),
#  (3623, 'tv wifi'),
#  (3447, 'cooking basics'),
#  (3433, 'water bed'),
#  (3357, 'silverware cooking'),
#  (3308, 'shampoo lock'),
#  (3257, 'self check'),
#  (3201, 'oven stove'),
#  (3180, 'door hangers'),
#  (3083, 'basics oven'),
#  (3052, 'private entrance'),

# %%
# numeric_features = data.select_dtypes(
#     include=['int64', 'float64', 'float32', 'int32'])
# nominal_features = data.select_dtypes(include=['object'])

# %% [markdown]
# ![](http://)

# %%
# #loop and get the unique value for each object column 
# display(HTML(airbnb[room_colname].select_dtypes(include=['object']).T.apply(lambda x: x.unique(), axis=1).to_frame().to_html()))

# %% [markdown]
# # Clean Review
# Last Review to date

# %%
feature_df=pd.concat([feature_df, airbnb.loc[:, airbnb.columns.str.startswith("review")].fillna(0)], axis=1)

# %%
feature_df=feature_df.head()

# %%
# feature_df.to_csv('/cleaned_dataset.csv')

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor

# %%
feature_df.select_dtypes(include=['object']).columns
# Out:
# Index(['listing_url', 'name', 'neighbourhood_cleansed'], dtype='object')

# %%
feature_df["neighbourhood_cleansed"].head()
# Out:
# 0        Palo Alto
# 1      Santa Clara
# 2    Mountain View
# 3        Palo Alto
# 4         San Jose
# Name: neighbourhood_cleansed, dtype: object

# %%
feature_df2= pd.get_dummies(feature_df, columns=["neighbourhood_cleansed"], prefix=["neighbourhood_is"])

# %%
# Declare feature vector and target variable
X = feature_df2.drop(['id','price','listing_url', 'name'], axis = 1)
y = feature_df2['price']

# %%
# Normalize feature vector
X2 = StandardScaler().fit_transform(X)

# %%
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size = 0.30, random_state = 0)

# %%
# instantiate the classifier with n_estimators = 100
clf = RandomForestClassifier(n_estimators=100, random_state=0)

# %%
# fit the classifier to the training set
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# predict on the test set
y_pred = clf.predict(X_test)

# %%
# visualize feature importance

plt.figure(num=None, figsize=(10,8), dpi=80, facecolor='w', edgecolor='k')

feat_importances = pd.Series(clf.feature_importances_, index= X.columns)

feat_importances.nlargest(15).sort_values(ascending=True).plot(kind='barh')
# Out:
# <AxesSubplot:>
